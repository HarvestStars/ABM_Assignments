# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Xiaoxuan Zhang"

# %% [markdown]
# # Agent Based Modeling - Mesa
#
# "[Mesa](https://mesa.readthedocs.io/en/stable/index.html) is an agent-based modeling framework in Python. Mesa allows users to quickly create agent-based models using built-in core components (such as spatial grids and agent schedulers) or customized implementations, visualize them using a browser-based interface, and analyze their results using Python’s data analysis tools."
#
# _This notebook is based on and uses parts of texts from the Mesa docs._
#
# ### Discretised Lotka Volterra
# In this notebook we aim to familiarise you with Mesa and its Object Oriented Programming approach to agent-based models. This will be done through implementation of a simplified preditor-prey model (discretised Lotka Volterra).
#
# If you are not yet comfortable with Object Oriented Programming or need a refresher, please visit [this page](https://python.swaroopch.com/oop.html).
#
# We will create a version of the "sheep-wolf" model wherein wolves and sheep wander randomly around the landscape. To allow the population to grow, each wolf or sheep has a fixed probability of reproducing at each timestep. In this simplified version, sheep do not have to eat, and only die when eaten by a wolf. Wolves, however, have a probability of dying. This produces interesting population dynamics, but creates a model that is ultimately unstable.
#
# To do this we need the following:
# - **Agents:** the predators and preys
# - **Environment:** an area in which the predators and prey can move around and interact
# - **Model:** the controller that links the environment and the agents
#
# We've already implemented the model and the environment is already implemented by Mesa, but it is up to you to implement the Agents!

# %%
from IPython.display import clear_output
import mesa
#import ipynb
clear_output(wait=True)
print("Everything imported!")
# Out:
# Everything imported!

# %% [markdown]
# ### Testing
# Since testing each of the methods that you will create seperately might be difficult, we provide you with a very minimal model that will be used during the testing phase. Later in this notebook we will introduce you to the model that has been implemented in `model.py`.

# %%
from mesa import Model
from mesa.space import MultiGrid

class TestModel(Model):
    def __init__(self, width, height):
        self.height = width
        self.width = height
        
        self.grid = MultiGrid(self.width, self.height, torus=True)
        
        self.n_agents = 0
        self.agents = []

    
    def new_agent(self, agent_type, pos):
        '''
        Method that enables us to add agents of a given type.
        '''
        self.n_agents += 1
        
        # Create a new agent of the given type
        new_agent = agent_type(self.n_agents, self, pos)
        
        # Place the agent on the grid
        self.grid.place_agent(new_agent, pos)
        
        # And add the agent to the model so we can track it
        self.agents.append(new_agent)
        
    def remove_agent(self, agent):
        '''
        Method that enables us to remove passed agents.
        '''
        self.n_agents -= 1
        
        # Remove agent from grid
        self.grid.remove_agent(agent)
        
        # Remove agent from model
        self.agents.remove(agent)
        
    def step(self):
        '''
        Method that steps every agent. 
        
        Prevents applying step on new agents by creating a local list.
        '''
        for agent in list(self.agents):
            agent.step()

# %% [markdown]
# ### Agents - Random walker
# As both the sheep and the wolves will walk around randomly, we will first implement a `RandomWalker` class. We can then re-use (inherit) this class when making our `Wolf` and `Sheep` classes. Below you can find the framework for the class, but you will have to implement the `random_move()` method. This method should get the neighbouring cells (Moore's neighbourhood), select one, and move the agent to this cell.
#
# Find the following functions through the provided link and find out which inputs they need:
#   - [`MultiGrid.get_neighborhood()`](https://mesa.readthedocs.io/en/stable/apis/space.html#mesa.space.MultiGrid.get_neighborhood)
#  - [`MultiGrid.move_agent()`](https://mesa.readthedocs.io/en/stable/apis/space.html#mesa.space.MultiGrid.move_agent)
#
# Keep in mind that the `model` that is passed when the RandomWalker is initialised contains the grid. It is accessable through `self.model.grid` in the `random_move` function.

# %%
from mesa import Agent
import random

class RandomWalker(Agent):
    def __init__(self, unique_id, model : Model, pos):
        super().__init__(unique_id, model)

        self.pos = pos

    def random_move(self):
        ''' 
        This method should get the neighbouring cells (Moore's neighbourhood), select one, and move the agent to this cell.
        '''
        # Get the neighbours of the agent
        print(f"Agent {self.unique_id} at {self.pos} is moving.")
        neighbours_cells = self.model.grid.get_neighborhood(self.pos, moore=True, include_center=False, radius=1)
        # print(f"Neighbour cells space of agent {self.unique_id} at {self.pos}: {neighbours_cells}")

        # If there are no neighbours, we cannot move
        if not neighbours_cells:
            print(f"Agent {self.unique_id} at {self.pos} has no neighbours to move to.")
            return
        
        # Randomly select a neighbour to move to
        new_pos = random.choice(neighbours_cells)
        
        # Move the agent to the new position
        self.model.grid.move_agent(self, new_pos)
        self.pos = new_pos
        print(f"Agent {self.unique_id} moved to {self.pos}")

# %%
tester = TestModel(10, 10)

# Create a RandomWalker, so that we can call the random_move() method
start_position = (5, 5)
tester.new_agent(RandomWalker, start_position)

# Create a reference, so that we can properly test
walker = tester.agents[0]
print(f"type of walker: {type(walker)}")

# Check movement
walker.random_move()
assert walker.pos != (5, 5), "The walker has not moved!"
assert abs(walker.pos[0] - 5) <= 1 and abs(walker.pos[1] - 5) <= 1, "The walker has moved more than 1 square"
# Out:
# type of walker: <class '__main__.RandomWalker'>
# Agent 1 at (5, 5) is moving.
# Agent 1 moved to (5, 6)

# %% [markdown]
# ### Agents - Sheep
# As described above, to allow the population to grow, each wolf or sheep has a fixed probability of reproducing at each timestep. Sheep do not have to eat, and only die when eaten by a wolf. We have again provided you with the framework for this class, but you will have to implement the `step()` method. This method should move the Sheep using the `random_move()` method implemented earlier, then conditionally reproduce. You can use the 'new_agent()' method implemented in model to create new sheep.
#
# Attributes/methods you might need:
#  - `self.random_move()`
#  - `self.model.new_agent()`
#  - `self.model.sheep_reproduction_chance`

# %%
class Sheep(RandomWalker):
    def __init__(self, unique_id, model, pos):
        super().__init__(unique_id, model, pos)

    def step(self):
        '''
        This method should move the Sheep using the `random_move()` method implemented earlier, then conditionally reproduce.
        '''
        # Step 1: move the sheep randomly
        self.random_move()

        # Step 2: reproduction (probabilistic)
        if random.random() < self.model.sheep_reproduction_chance:
            # get the neighboring cells of the sheep
            neighbor_cells = self.model.grid.get_neighborhood(
                self.pos,
                moore=True,
                include_center=False,
                radius=1
            )

            # # Find the occupied positions among these cells
            # occupied_positions = [agent.pos for agent in self.model.grid.get_neighbors(
            #     self.pos,
            #     moore=True,
            #     include_center=False,
            #     radius=1
            # )]

            # # Remove occupied positions from all cells
            # empty_positions = [cell for cell in neighbor_cells if cell not in occupied_positions]

            # # If there are empty spaces to reproduce, randomly select one
            # if empty_positions:
            #     new_pos = random.choice(empty_positions)
            #     self.model.new_agent(Sheep, new_pos)  # model.new_agent is used to create a new Sheep agent
            #     print(f"Sheep {self.unique_id} reproduced at {new_pos}")

            new_pos = random.choice(neighbor_cells)
            self.model.new_agent(Sheep, new_pos)  # model.new_agent is used to create a new Sheep agent
            print(f"Sheep {self.unique_id} reproduced at {new_pos}")

# %%
tester = TestModel(10, 10)
tester.sheep_reproduction_chance = 1

# Create a Sheep 
start_position = (5, 5)
tester.new_agent(Sheep, start_position)

# Create a reference, so that we can properly test
sheep = tester.agents[0]

# Check movement
tester.step()
assert sheep.pos != (5, 5), "The sheep has not moved!"
assert abs(sheep.pos[0] - 5) <= 1 and abs(sheep.pos[1] - 5) <= 1, "The sheep has moved more than 1 square!"

# Check fertility
assert tester.n_agents == 2, "Your sheep is infertile!"
tester.sheep_reproduction_chance = 0
tester.step()
assert tester.n_agents == 2, "Your sheep are too fertile!"

# Check if the random_move function was used
old_pos = sheep.pos
sheep.random_move = lambda: False
tester.step()
assert old_pos == sheep.pos, "You didn't use the random_move() function!"
# Out:
# Agent 1 at (5, 5) is moving.
# Agent 1 moved to (5, 4)
# Sheep 1 reproduced at (6, 5)
# Agent 1 at (5, 4) is moving.
# Agent 1 moved to (4, 5)
# Agent 2 at (6, 5) is moving.
# Agent 2 moved to (7, 5)
# Agent 2 at (7, 5) is moving.
# Agent 2 moved to (6, 6)

# %%
class Wolf(RandomWalker):
    def __init__(self, unique_id, model, pos):
        super().__init__(unique_id, model, pos)

    def step(self):
        '''
        This method should move the wolf, then check for sheep on its location, 
        eat one sheep if it is available and reproduce, and finally, conditionally die.
        '''
        # Step 1: randomly move the wolf
        self.random_move()

        # Step 2: check for sheep and eat one if available
        cellmates = self.model.grid.get_cell_list_contents([self.pos])
        sheep_here = [agent for agent in cellmates if isinstance(agent, Sheep)]

        if sheep_here:
            # Step 2.1: eat one sheep
            sheep_to_eat = random.choice(sheep_here)
            self.model.remove_agent(sheep_to_eat)
            print(f"Wolf {self.unique_id} ate Sheep {sheep_to_eat.unique_id} at {self.pos}")

            # Step 2.2: reproduction
            neighbor_cells = self.model.grid.get_neighborhood(
                self.pos,
                moore=True,
                include_center=False,
                radius=1
            )

            # occupied_positions = [agent.pos for agent in self.model.grid.get_neighbors(
            #     self.pos,
            #     moore=True,
            #     include_center=False,
            #     radius=1
            # )]
            # empty_positions = [cell for cell in neighbor_cells if cell not in occupied_positions]

            # if empty_positions:
            #     new_pos = random.choice(empty_positions)
            #     self.model.new_agent(Wolf, new_pos)
            #     print(f"Wolf {self.unique_id} reproduced at {new_pos}")

            if neighbor_cells:
                new_pos = random.choice(neighbor_cells)
                self.model.new_agent(Wolf, new_pos)
                print(f"Wolf {self.unique_id} reproduced at {new_pos}")
            
        # Step 3: conditionally die
        if random.random() < self.model.wolf_death_chance:
            print(f"Wolf {self.unique_id} died at {self.pos}")
            self.model.remove_agent(self)

# %%
tester = TestModel(10, 10)
tester.wolf_death_chance = 0

# Create a Wolf 
start_position = (5, 5)
tester.new_agent(Wolf, start_position)

# Create a reference, so that we can properly test
wolf = tester.agents[0]

# Check movement
tester.step()
assert wolf.pos != (5, 5), "The wolf has not moved!"
assert abs(wolf.pos[0] - 5) <= 1 and abs(wolf.pos[1] - 5) <= 1, "The wolf has moved more than 1 square!"

# Check death rates
assert tester.n_agents == 1, "Your wolf died!"
tester.wolf_death_chance = 1
tester.step()
assert tester.n_agents == 0, "Your wolf is invincible!"

# Create another model so that we can be sure the wolf eats the sheep
tester = TestModel(1, 1)
tester.wolf_death_chance = 0
tester.sheep_reproduction_chance = 0

# Create a Sheep and a Wolf
start_position = (0, 0)
tester.new_agent(Sheep, start_position)
tester.new_agent(Wolf, start_position)

# Check if the sheep was eaten
tester.step()
assert type(tester.agents[0]) is not Sheep, "The sheep has not been eaten!"
# Out:
# Agent 1 at (5, 5) is moving.
# Agent 1 moved to (5, 6)
# Agent 1 at (5, 6) is moving.
# Agent 1 moved to (6, 7)
# Wolf 1 died at (6, 7)
# Agent 1 at (0, 0) is moving.
# Agent 1 at (0, 0) has no neighbours to move to.
# Agent 2 at (0, 0) is moving.
# Agent 2 at (0, 0) has no neighbours to move to.
# Wolf 2 ate Sheep 1 at (0, 0)

# %% [markdown]
# ### The model
# Now that you have implemented the agents, we will introduce you to the model. The model links the agents to the environment and provides methods that make interactions with the model easy. It uses the `DataCollector` class, which we will explain later, and the `RandomActivation` class. The `RandomActivation` class is a scheduler that iterates through each of the agents randomly and uses its `step()` method. We have seperated the Sheep scheduler from the Wolf scheduler to prevent what is called a ["race-condition"](https://en.wikipedia.org/wiki/Race_condition) wherein a Sheep gets eaten before it is its turn to `step()`.
#
# At the time of writing of this notebook, there are 4 different schedulers available in Mesa:
# - `BaseScheduler`: This is a scheduler that activates agents one at a time, in the order they were added.
# - `RandomActivation`: Activates each agent once per step, in random order, with the order reshuffled every step.
# - `SimultaneousActivation`: Activates all agents simultaneously.
# - `StagedActivation`: Allows agent activation to be divided into several stages instead of a single `step` method.
#
# Check out [the docs](https://mesa.readthedocs.io/en/stable/tutorials/intro_tutorial.html#adding-the-scheduler) to learn more.

# %%
import random

from mesa import Model
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector
from mesa.time import RandomActivation

class WolfSheep(Model):
    '''
    Wolf-Sheep Predation Model
    '''
    
    def __init__(self, height=20, width=20,
                 initial_sheep=100, initial_wolves=30,
                 sheep_reproduction_chance=0.05, wolf_death_chance=0.05):

        super().__init__()

        self.height = height
        self.width = width
        self.initial_sheep = initial_sheep
        self.initial_wolves = initial_wolves
        self.sheep_reproduction_chance = sheep_reproduction_chance
        self.wolf_death_chance = wolf_death_chance

        # Add a schedule for sheep and wolves seperately to prevent race-conditions
        self.schedule_Sheep = RandomActivation(self)
        self.schedule_Wolf = RandomActivation(self)

        self.grid = MultiGrid(self.width, self.height, torus=True)
        self.datacollector = DataCollector(
             {"Sheep": lambda m: self.schedule_Sheep.get_agent_count(),
              "Wolves": lambda m: self.schedule_Wolf.get_agent_count()})

        # Create sheep and wolves
        self.init_population(Sheep, self.initial_sheep)
        self.init_population(Wolf, self.initial_wolves)

        # This is required for the datacollector to work
        self.running = True
        self.datacollector.collect(self)

    def init_population(self, agent_type, n):
        '''
        Method that provides an easy way of making a bunch of agents at once.
        '''
        for i in range(n):
            x = random.randrange(self.width)
            y = random.randrange(self.height)

            self.new_agent(agent_type, (x, y))

    def new_agent(self, agent_type, pos):
        '''
        Method that creates a new agent, and adds it to the correct scheduler.
        '''
        agent = agent_type(self.next_id(), self, pos)

        self.grid.place_agent(agent, pos)
        getattr(self, f'schedule_{agent_type.__name__}').add(agent)

    def remove_agent(self, agent):
        '''
        Method that removes an agent from the grid and the correct scheduler.
        '''
        self.grid.remove_agent(agent)
        getattr(self, f'schedule_{type(agent).__name__}').remove(agent)

    def step(self):
        '''
        Method that calls the step method for each of the sheep, and then for each of the wolves.
        '''
        self.schedule_Sheep.step()
        self.schedule_Wolf.step()

        # Save the statistics
        self.datacollector.collect(self)

    def run_model(self, step_count=200):
        '''
        Method that runs the model for a specific amount of steps.
        '''
        for i in range(step_count):
            self.step()

# %% [markdown]
# You might have noticed that we are using a so called `MultiGrid`. Again, [Mesa provides us with multiple different types of environments](https://mesa.readthedocs.io/en/latest/tutorials/intro_tutorial.html#adding-space) for the agents to exist in:
# - `ContinuousSpace`: Each agent can have an arbitrary position.
# - `SingleGrid`: Grid where each cell contains at most one object.
# - `MultiGrid`: Grid where each cell can contain more than one object.
# - `HexGrid`: extends the grid to handle hexagonal neighbors.
# - `NetworkGrid`: Network where each node contains zero or more agents.
#
# We are using `MultiGrid` as we want multiple agents to be able to be in one cell.
#
# Running the model is now as simple as:

# %%
model = WolfSheep()
model.run_model()
# Out:
# Agent 82 at (8, 0) is moving.
# Agent 82 moved to (7, 19)
# Agent 95 at (17, 0) is moving.
# Agent 95 moved to (17, 19)
# Agent 55 at (9, 10) is moving.
# Agent 55 moved to (10, 11)
# Agent 7 at (13, 10) is moving.
# Agent 7 moved to (13, 11)
# Agent 32 at (4, 2) is moving.
# Agent 32 moved to (4, 3)
# Agent 53 at (3, 6) is moving.
# Agent 53 moved to (3, 7)
# Agent 2 at (5, 6) is moving.
# Agent 2 moved to (4, 7)
# Agent 36 at (10, 0) is moving.
# Agent 36 moved to (10, 1)
# Agent 15 at (10, 5) is moving.
# Agent 15 moved to (11, 5)
# Agent 84 at (15, 1) is moving.
# Agent 84 moved to (16, 0)
# Agent 10 at (3, 6) is moving.
# Agent 10 moved to (4, 6)
# Agent 38 at (2, 7) is moving.
# Agent 38 moved to (3, 6)
# Agent 59 at (1, 13) is moving.
# Agent 59 moved to (0, 13)
# Agent 98 at (2, 9) is moving.
# Agent 98 moved to (3, 10)
# Agent 99 at (1, 11) is moving.
# Agent 99 moved to (1, 12)
# Agent 97 at (7, 4) is moving.
# Agent 97 moved to (8, 3)
# Agent 69 at (8, 11) is moving.
# Agent 69 moved to (8, 10)
# Agent 75 at (4, 15) is moving.
# Agent 75 moved to (5, 15)
# Agent 49 at (18, 19) is moving.
# Agent 49 moved to (18, 18)
# Agent 39 at (8, 10) is moving.
# Agent 39 moved to (8, 9)
# Agent 50 at (15, 2) is moving.
# Agent 50 moved to (14, 3)
# Agent 94 at (0, 11) is moving.
# Agent 94 moved to (0, 12)
# Agent 70 at (7, 12) is moving.
# Agent 70 moved to (7, 13)
# Agent 51 at (4, 1) is moving.
# Agent 51 moved to (3, 0)
# Agent 22 at (9, 6) is moving.
# Agent 22 moved to (8, 6)
# Agent 85 at (4, 9) is moving.
# Agent 85 moved to (4, 8)
# Agent 62 at (16, 1) is moving.
# Agent 62 moved to (15, 2)
# Agent 48 at (7, 6) is moving.
# Agent 48 moved to (7, 5)
# Agent 6 at (12, 14) is moving.
# Agent 6 moved to (11, 13)
# Agent 14 at (15, 11) is moving.
# Agent 14 moved to (16, 11)
# Agent 77 at (8, 13) is moving.
# Agent 77 moved to (7, 13)
# Agent 58 at (9, 2) is moving.
# Agent 58 moved to (8, 3)
# Sheep 58 reproduced at (8, 2)
# Agent 9 at (11, 4) is moving.
# Agent 9 moved to (11, 3)
# Agent 45 at (14, 6) is moving.
# Agent 45 moved to (15, 7)
# Agent 29 at (14, 3) is moving.
# Agent 29 moved to (15, 3)
# Agent 23 at (3, 2) is moving.
# Agent 23 moved to (3, 3)
# Agent 96 at (18, 16) is moving.
# Agent 96 moved to (19, 16)
# Sheep 96 reproduced at (0, 15)
# Agent 87 at (19, 16) is moving.
# Agent 87 moved to (18, 16)
# Agent 28 at (16, 8) is moving.
# Agent 28 moved to (15, 9)
# Agent 42 at (1, 11) is moving.
# Agent 42 moved to (2, 11)
# Agent 33 at (2, 19) is moving.
# Agent 33 moved to (3, 19)
# Agent 11 at (13, 3) is moving.
# Agent 11 moved to (14, 2)
# Agent 71 at (5, 17) is moving.
# Agent 71 moved to (4, 17)
# Agent 66 at (15, 19) is moving.
# Agent 66 moved to (14, 18)
# Agent 60 at (11, 19) is moving.
# Agent 60 moved to (12, 19)
# Sheep 60 reproduced at (13, 18)
# Agent 88 at (14, 17) is moving.
# Agent 88 moved to (14, 16)
# Agent 83 at (18, 0) is moving.
# Agent 83 moved to (19, 1)
# Sheep 83 reproduced at (18, 1)
# Agent 30 at (7, 18) is moving.
# Agent 30 moved to (7, 19)
# Agent 34 at (2, 4) is moving.
# Agent 34 moved to (2, 5)
# Agent 67 at (7, 15) is moving.
# Agent 67 moved to (8, 16)
# Agent 16 at (11, 11) is moving.
# Agent 16 moved to (12, 10)
# Agent 90 at (5, 16) is moving.
# Agent 90 moved to (6, 15)
# Agent 5 at (15, 2) is moving.
# Agent 5 moved to (16, 2)
# Agent 86 at (19, 10) is moving.
# Agent 86 moved to (19, 9)
# Agent 52 at (14, 1) is moving.
# Agent 52 moved to (15, 0)
# Agent 31 at (12, 15) is moving.
# Agent 31 moved to (12, 16)
# Agent 89 at (5, 19) is moving.
# Agent 89 moved to (4, 19)
# Agent 80 at (5, 10) is moving.
# Agent 80 moved to (6, 11)
# Agent 8 at (7, 3) is moving.
# Agent 8 moved to (8, 2)
# Sheep 8 reproduced at (9, 2)
# Agent 72 at (9, 18) is moving.
# Agent 72 moved to (10, 19)
# Agent 92 at (16, 14) is moving.
# Agent 92 moved to (17, 13)
# Agent 100 at (17, 14) is moving.
# Agent 100 moved to (16, 13)
# Agent 25 at (16, 12) is moving.
# Agent 25 moved to (16, 11)
# Agent 91 at (7, 4) is moving.
# Agent 91 moved to (7, 3)
# Agent 40 at (19, 5) is moving.
# Agent 40 moved to (19, 6)
# Agent 78 at (0, 10) is moving.
# Agent 78 moved to (19, 10)
# Agent 61 at (0, 6) is moving.
# Agent 61 moved to (1, 6)
# Agent 63 at (10, 7) is moving.
# Agent 63 moved to (10, 6)
# Agent 27 at (5, 17) is moving.
# Agent 27 moved to (4, 18)
# Agent 4 at (2, 19) is moving.
# Agent 4 moved to (1, 18)
# Agent 68 at (12, 15) is moving.
# Agent 68 moved to (13, 16)
# Agent 3 at (12, 8) is moving.
# Agent 3 moved to (13, 8)
# Agent 35 at (4, 11) is moving.
# Agent 35 moved to (3, 10)
# Agent 18 at (16, 10) is moving.
# Agent 18 moved to (16, 11)
# Agent 64 at (12, 16) is moving.
# Agent 64 moved to (11, 17)
# Agent 81 at (17, 6) is moving.
# Agent 81 moved to (17, 7)
# Agent 1 at (5, 1) is moving.
# Agent 1 moved to (6, 2)
# Agent 17 at (3, 15) is moving.
# Agent 17 moved to (2, 15)
# Agent 19 at (11, 4) is moving.
# Agent 19 moved to (12, 3)
# Sheep 19 reproduced at (11, 2)
# Agent 76 at (15, 9) is moving.
# Agent 76 moved to (15, 10)
# Agent 73 at (9, 12) is moving.
# Agent 73 moved to (9, 11)
# Agent 13 at (4, 0) is moving.
# Agent 13 moved to (5, 19)
# Agent 46 at (8, 3) is moving.
# Agent 46 moved to (7, 2)
# Agent 74 at (19, 17) is moving.
# Agent 74 moved to (0, 18)
# Sheep 74 reproduced at (19, 17)
# Agent 37 at (15, 11) is moving.
# Agent 37 moved to (14, 10)
# Agent 43 at (9, 14) is moving.
# Agent 43 moved to (10, 13)
# Agent 12 at (10, 2) is moving.
# Agent 12 moved to (9, 3)
# Agent 54 at (3, 12) is moving.
# Agent 54 moved to (2, 13)
# Agent 26 at (19, 9) is moving.
# Agent 26 moved to (18, 10)
# Agent 93 at (7, 17) is moving.
# Agent 93 moved to (6, 18)
# Agent 57 at (6, 17) is moving.
# Agent 57 moved to (7, 16)
# Agent 24 at (5, 6) is moving.
# Agent 24 moved to (4, 5)
# Agent 47 at (7, 11) is moving.
# Agent 47 moved to (6, 10)
# Agent 79 at (7, 11) is moving.
# Agent 79 moved to (8, 12)
# Agent 21 at (17, 17) is moving.
# Agent 21 moved to (18, 18)
# Agent 20 at (7, 6) is moving.
# Agent 20 moved to (6, 7)
# Agent 41 at (0, 1) is moving.
# Agent 41 moved to (1, 1)
# Agent 44 at (16, 12) is moving.
# Agent 44 moved to (17, 13)
# Agent 65 at (9, 13) is moving.
# Agent 65 moved to (10, 14)
# Agent 56 at (12, 11) is moving.
# Agent 56 moved to (13, 12)
# Agent 112 at (5, 16) is moving.
# Agent 112 moved to (4, 16)
# Agent 111 at (8, 10) is moving.
# Agent 111 moved to (8, 9)
# Wolf 111 ate Sheep 39 at (8, 9)
# Wolf 111 reproduced at (9, 8)
# Agent 129 at (17, 13) is moving.
# Agent 129 moved to (18, 12)
# Agent 119 at (13, 14) is moving.
# Agent 119 moved to (13, 13)
# Agent 110 at (7, 6) is moving.
# Agent 110 moved to (8, 6)
# Wolf 110 ate Sheep 22 at (8, 6)
# Wolf 110 reproduced at (9, 6)
# Agent 130 at (5, 3) is moving.
# Agent 130 moved to (6, 2)
# Wolf 130 ate Sheep 1 at (6, 2)
# Wolf 130 reproduced at (5, 3)
# Agent 118 at (19, 4) is moving.
# Agent 118 moved to (0, 5)
# Agent 122 at (16, 7) is moving.
# Agent 122 moved to (15, 8)
# Agent 101 at (16, 19) is moving.
# Agent 101 moved to (16, 0)
# Wolf 101 ate Sheep 84 at (16, 0)
# Wolf 101 reproduced at (17, 19)
# Agent 103 at (18, 18) is moving.
# Agent 103 moved to (19, 18)
# Agent 124 at (13, 3) is moving.
# Agent 124 moved to (13, 2)
# Agent 107 at (7, 9) is moving.
# Agent 107 moved to (6, 10)
# Wolf 107 ate Sheep 47 at (6, 10)
# Wolf 107 reproduced at (5, 10)
# Agent 104 at (8, 17) is moving.
# Agent 104 moved to (7, 18)
# Agent 120 at (9, 13) is moving.
# Agent 120 moved to (9, 14)
# Agent 121 at (4, 1) is moving.
# Agent 121 moved to (3, 0)
# Wolf 121 ate Sheep 51 at (3, 0)
# Wolf 121 reproduced at (2, 0)
# Agent 102 at (5, 2) is moving.
# Agent 102 moved to (5, 1)
# Agent 113 at (7, 15) is moving.
# Agent 113 moved to (6, 14)
# Agent 125 at (6, 4) is moving.
# Agent 125 moved to (6, 5)
# Agent 117 at (19, 2) is moving.
# Agent 117 moved to (18, 1)
# Wolf 117 ate Sheep 134 at (18, 1)
# Wolf 117 reproduced at (18, 2)
# Agent 126 at (15, 1) is moving.
# Agent 126 moved to (14, 1)
# Agent 115 at (13, 16) is moving.
# Agent 115 moved to (14, 17)
# Agent 127 at (17, 5) is moving.
# Agent 127 moved to (16, 6)
# Agent 128 at (13, 15) is moving.
# Agent 128 moved to (13, 14)
# Agent 106 at (7, 4) is moving.
# Agent 106 moved to (6, 5)
# Agent 114 at (4, 2) is moving.
# Agent 114 moved to (4, 3)
# Wolf 114 ate Sheep 32 at (4, 3)
# Wolf 114 reproduced at (3, 2)
# Agent 108 at (10, 2) is moving.
# Agent 108 moved to (9, 2)
# Wolf 108 ate Sheep 135 at (9, 2)
# Wolf 108 reproduced at (8, 3)
# Agent 109 at (5, 10) is moving.
# Agent 109 moved to (6, 11)
# Wolf 109 ate Sheep 80 at (6, 11)
# Wolf 109 reproduced at (7, 11)
# Agent 105 at (12, 19) is moving.
# Agent 105 moved to (11, 0)
# Agent 123 at (7, 19) is moving.
# Agent 123 moved to (6, 19)
# Agent 116 at (9, 17) is moving.
# Agent 116 moved to (8, 17)
# Agent 61 at (1, 6) is moving.
# Agent 61 moved to (1, 7)
# Sheep 61 reproduced at (2, 8)
# Agent 6 at (11, 13) is moving.
# Agent 6 moved to (12, 14)
# Agent 49 at (18, 18) is moving.
# Agent 49 moved to (18, 19)
# Agent 38 at (3, 6) is moving.
# Agent 38 moved to (4, 5)
# Agent 82 at (7, 19) is moving.
# Agent 82 moved to (6, 19)
# Agent 136 at (11, 2) is moving.
# Agent 136 moved to (12, 2)
# Agent 2 at (4, 7) is moving.
# Agent 2 moved to (4, 8)
# Agent 131 at (8, 2) is moving.
# Agent 131 moved to (7, 2)
# Agent 97 at (8, 3) is moving.
# Agent 97 moved to (9, 4)
# Agent 86 at (19, 9) is moving.
# Agent 86 moved to (18, 10)
# Agent 23 at (3, 3) is moving.
# Agent 23 moved to (3, 4)
# Agent 56 at (13, 12) is moving.
# Agent 56 moved to (13, 13)
# Agent 91 at (7, 3) is moving.
# Agent 91 moved to (7, 4)
# Agent 72 at (10, 19) is moving.
# Agent 72 moved to (9, 0)
# Agent 67 at (8, 16) is moving.
# Agent 67 moved to (7, 16)
# Agent 44 at (17, 13) is moving.
# Agent 44 moved to (16, 13)
# Agent 45 at (15, 7) is moving.
# Agent 45 moved to (15, 6)
# Agent 85 at (4, 8) is moving.
# Agent 85 moved to (5, 7)
# Agent 3 at (13, 8) is moving.
# Agent 3 moved to (13, 7)
# Agent 100 at (16, 13) is moving.
# Agent 100 moved to (17, 14)
# Agent 14 at (16, 11) is moving.
# Agent 14 moved to (17, 12)
# Agent 13 at (5, 19) is moving.
# Agent 13 moved to (6, 0)
# Agent 57 at (7, 16) is moving.
# Agent 57 moved to (7, 15)
# Agent 79 at (8, 12) is moving.
# Agent 79 moved to (9, 13)
# Agent 8 at (8, 2) is moving.
# Agent 8 moved to (9, 3)
# Agent 24 at (4, 5) is moving.
# Agent 24 moved to (4, 4)
# Agent 50 at (14, 3) is moving.
# Agent 50 moved to (14, 4)
# Agent 12 at (9, 3) is moving.
# Agent 12 moved to (9, 4)
# Agent 36 at (10, 1) is moving.
# Agent 36 moved to (11, 2)
# Agent 11 at (14, 2) is moving.
# Agent 11 moved to (15, 3)
# Agent 88 at (14, 16) is moving.
# Agent 88 moved to (14, 15)
# Agent 69 at (8, 10) is moving.
# Agent 69 moved to (7, 9)
# Agent 17 at (2, 15) is moving.
# Agent 17 moved to (2, 14)
# Agent 37 at (14, 10) is moving.
# Agent 37 moved to (14, 9)
# Agent 87 at (18, 16) is moving.
# Agent 87 moved to (19, 15)
# Agent 71 at (4, 17) is moving.
# Agent 71 moved to (5, 18)
# Agent 65 at (10, 14) is moving.
# Agent 65 moved to (10, 15)
# Agent 9 at (11, 3) is moving.
# Agent 9 moved to (10, 4)
# Agent 30 at (7, 19) is moving.
# Agent 30 moved to (8, 19)
# Agent 21 at (18, 18) is moving.
# Agent 21 moved to (19, 17)
# Sheep 21 reproduced at (0, 16)
# Agent 41 at (1, 1) is moving.
# Agent 41 moved to (0, 0)
# Agent 62 at (15, 2) is moving.
# Agent 62 moved to (15, 3)
# Agent 59 at (0, 13) is moving.
# Agent 59 moved to (19, 12)
# Agent 33 at (3, 19) is moving.
# Agent 33 moved to (2, 18)
# Agent 78 at (19, 10) is moving.
# Agent 78 moved to (0, 10)
# Agent 92 at (17, 13) is moving.
# Agent 92 moved to (16, 14)
# Agent 95 at (17, 19) is moving.
# Agent 95 moved to (16, 0)
# Agent 31 at (12, 16) is moving.
# Agent 31 moved to (12, 15)
# Agent 132 at (0, 15) is moving.
# Agent 132 moved to (0, 16)
# Sheep 132 reproduced at (19, 15)
# Agent 40 at (19, 6) is moving.
# Agent 40 moved to (0, 6)
# Agent 4 at (1, 18) is moving.
# Agent 4 moved to (1, 19)
# Agent 16 at (12, 10) is moving.
# Agent 16 moved to (11, 9)
# Agent 34 at (2, 5) is moving.
# Agent 34 moved to (2, 4)
# Agent 60 at (12, 19) is moving.
# Agent 60 moved to (13, 19)
# Sheep 60 reproduced at (13, 18)
# Agent 55 at (10, 11) is moving.
# Agent 55 moved to (11, 10)
# Agent 81 at (17, 7) is moving.
# Agent 81 moved to (18, 8)
# Agent 25 at (16, 11) is moving.
# Agent 25 moved to (15, 12)
# Agent 63 at (10, 6) is moving.
# Agent 63 moved to (9, 5)
# Agent 98 at (3, 10) is moving.
# Agent 98 moved to (4, 10)
# Agent 137 at (19, 17) is moving.
# Agent 137 moved to (18, 17)
# Agent 96 at (19, 16) is moving.
# Agent 96 moved to (18, 15)
# Agent 64 at (11, 17) is moving.
# Agent 64 moved to (10, 16)
# Agent 68 at (13, 16) is moving.
# Agent 68 moved to (13, 15)
# Agent 19 at (12, 3) is moving.
# Agent 19 moved to (11, 2)
# Agent 20 at (6, 7) is moving.
# Agent 20 moved to (5, 8)
# Agent 28 at (15, 9) is moving.
# Agent 28 moved to (14, 9)
# Agent 43 at (10, 13) is moving.
# Agent 43 moved to (10, 12)
# Agent 52 at (15, 0) is moving.
# Agent 52 moved to (16, 0)
# Agent 75 at (5, 15) is moving.
# Agent 75 moved to (6, 15)
# Agent 76 at (15, 10) is moving.
# Agent 76 moved to (14, 9)
# Agent 48 at (7, 5) is moving.
# Agent 48 moved to (6, 5)
# Agent 42 at (2, 11) is moving.
# Agent 42 moved to (2, 12)
# Agent 83 at (19, 1) is moving.
# Agent 83 moved to (18, 0)
# Agent 70 at (7, 13) is moving.
# Agent 70 moved to (6, 12)
# Agent 93 at (6, 18) is moving.
# Agent 93 moved to (7, 19)
# Agent 46 at (7, 2) is moving.
# Agent 46 moved to (8, 2)
# Agent 54 at (2, 13) is moving.
# Agent 54 moved to (1, 13)
# Agent 10 at (4, 6) is moving.
# Agent 10 moved to (3, 7)
# Agent 15 at (11, 5) is moving.
# Agent 15 moved to (10, 6)
# Agent 133 at (13, 18) is moving.
# Agent 133 moved to (12, 19)
# Agent 53 at (3, 7) is moving.
# Agent 53 moved to (4, 8)
# Agent 29 at (15, 3) is moving.
# Agent 29 moved to (15, 2)
# Agent 74 at (0, 18) is moving.
# Agent 74 moved to (1, 18)
# Agent 77 at (7, 13) is moving.
# Agent 77 moved to (7, 12)
# Agent 35 at (3, 10) is moving.
# Agent 35 moved to (2, 11)
# Agent 73 at (9, 11) is moving.
# Agent 73 moved to (10, 11)
# Sheep 73 reproduced at (9, 12)
# Agent 66 at (14, 18) is moving.
# Agent 66 moved to (15, 19)
# Agent 7 at (13, 11) is moving.
# Agent 7 moved to (12, 11)
# Agent 18 at (16, 11) is moving.
# Agent 18 moved to (17, 11)
# Agent 27 at (4, 18) is moving.
# Agent 27 moved to (5, 19)
# Agent 26 at (18, 10) is moving.
# Agent 26 moved to (17, 11)
# Agent 94 at (0, 12) is moving.
# Agent 94 moved to (19, 13)
# Agent 89 at (4, 19) is moving.
# Agent 89 moved to (4, 18)
# Agent 90 at (6, 15) is moving.
# Agent 90 moved to (5, 14)
# Agent 58 at (8, 3) is moving.
# Agent 58 moved to (7, 4)
# Agent 5 at (16, 2) is moving.
# Agent 5 moved to (17, 3)
# Agent 99 at (1, 12) is moving.
# Agent 99 moved to (0, 12)
# Agent 144 at (18, 2) is moving.
# Agent 144 moved to (19, 1)
# Agent 113 at (6, 14) is moving.
# Agent 113 moved to (7, 14)
# Agent 125 at (6, 5) is moving.
# Agent 125 moved to (7, 4)
# Wolf 125 ate Sheep 58 at (7, 4)
# Wolf 125 reproduced at (8, 3)
# Agent 142 at (5, 10) is moving.
# Agent 142 moved to (6, 11)
# Agent 141 at (17, 19) is moving.
# Agent 141 moved to (17, 0)
# Agent 145 at (3, 2) is moving.
# Agent 145 moved to (4, 3)
# Agent 117 at (18, 1) is moving.
# Agent 117 moved to (18, 2)
# Agent 104 at (7, 18) is moving.
# Agent 104 moved to (7, 19)
# Wolf 104 ate Sheep 93 at (7, 19)
# Wolf 104 reproduced at (7, 18)
# Agent 127 at (16, 6) is moving.
# Agent 127 moved to (15, 7)
# Agent 130 at (6, 2) is moving.
# Agent 130 moved to (6, 3)
# Agent 138 at (9, 8) is moving.
# Agent 138 moved to (10, 7)
# Agent 140 at (5, 3) is moving.
# Agent 140 moved to (6, 3)
# Agent 126 at (14, 1) is moving.
# Agent 126 moved to (14, 0)
# Wolf 126 died at (14, 0)
# Agent 105 at (11, 0) is moving.
# Agent 105 moved to (12, 0)
# Agent 129 at (18, 12) is moving.
# Agent 129 moved to (19, 13)
# Wolf 129 ate Sheep 94 at (19, 13)
# Wolf 129 reproduced at (0, 14)
# Agent 121 at (3, 0) is moving.
# Agent 121 moved to (2, 0)
# Agent 102 at (5, 1) is moving.
# Agent 102 moved to (6, 0)
# Wolf 102 ate Sheep 13 at (6, 0)
# Wolf 102 reproduced at (7, 19)
# Agent 128 at (13, 14) is moving.
# Agent 128 moved to (14, 15)
# Wolf 128 ate Sheep 88 at (14, 15)
# Wolf 128 reproduced at (13, 15)
# Wolf 128 died at (14, 15)
# Agent 118 at (0, 5) is moving.
# Agent 118 moved to (1, 6)
# Agent 110 at (8, 6) is moving.
# Agent 110 moved to (9, 6)
# Agent 139 at (9, 6) is moving.
# Agent 139 moved to (8, 6)
# Agent 143 at (2, 0) is moving.
# Agent 143 moved to (1, 1)
# Agent 111 at (8, 9) is moving.
# Agent 111 moved to (9, 9)
# Agent 120 at (9, 14) is moving.
# Agent 120 moved to (10, 13)
# Agent 124 at (13, 2) is moving.
# Agent 124 moved to (13, 3)
# Agent 114 at (4, 3) is moving.
# Agent 114 moved to (3, 2)
# Agent 112 at (4, 16) is moving.
# Agent 112 moved to (5, 17)
# Agent 106 at (6, 5) is moving.
# Agent 106 moved to (5, 5)
# Agent 119 at (13, 13) is moving.
# Agent 119 moved to (14, 12)
# Agent 147 at (7, 11) is moving.
# Agent 147 moved to (6, 11)
# Agent 122 at (15, 8) is moving.
# Agent 122 moved to (15, 9)
# Agent 101 at (16, 0) is moving.
# Agent 101 moved to (16, 1)
# Agent 146 at (8, 3) is moving.
# Agent 146 moved to (7, 3)
# Agent 109 at (6, 11) is moving.
# Agent 109 moved to (5, 12)
# Agent 115 at (14, 17) is moving.
# Agent 115 moved to (15, 16)
# Agent 108 at (9, 2) is moving.
# Agent 108 moved to (8, 2)
# Wolf 108 ate Sheep 46 at (8, 2)
# Wolf 108 reproduced at (8, 3)
# Agent 123 at (6, 19) is moving.
# Agent 123 moved to (5, 0)
# Agent 103 at (19, 18) is moving.
# Agent 103 moved to (19, 19)
# Agent 107 at (6, 10) is moving.
# Agent 107 moved to (6, 11)
# Agent 116 at (8, 17) is moving.
# Agent 116 moved to (8, 18)
# Agent 92 at (16, 14) is moving.
# Agent 92 moved to (15, 15)
# Agent 16 at (11, 9) is moving.
# Agent 16 moved to (10, 8)
# Agent 21 at (19, 17) is moving.
# Agent 21 moved to (0, 17)
# Agent 3 at (13, 7) is moving.
# Agent 3 moved to (14, 8)
# Sheep 3 reproduced at (13, 8)
# Agent 18 at (17, 11) is moving.
# Agent 18 moved to (18, 11)
# Agent 89 at (4, 18) is moving.
# Agent 89 moved to (4, 19)
# Agent 49 at (18, 19) is moving.
# Agent 49 moved to (18, 18)
# Agent 82 at (6, 19) is moving.
# Agent 82 moved to (7, 0)
# Agent 150 at (19, 15) is moving.
# Agent 150 moved to (0, 14)
# Agent 131 at (7, 2) is moving.
# Agent 131 moved to (6, 3)
# Agent 151 at (13, 18) is moving.
# Agent 151 moved to (14, 17)
# Agent 4 at (1, 19) is moving.
# Agent 4 moved to (1, 0)
# Agent 57 at (7, 15) is moving.
# Agent 57 moved to (6, 14)
# Agent 79 at (9, 13) is moving.
# Agent 79 moved to (9, 12)
# Agent 99 at (0, 12) is moving.
# Agent 99 moved to (1, 13)
# Agent 5 at (17, 3) is moving.
# Agent 5 moved to (16, 3)
# Agent 85 at (5, 7) is moving.
# Agent 85 moved to (4, 6)
# Agent 70 at (6, 12) is moving.
# Agent 70 moved to (6, 11)
# Agent 27 at (5, 19) is moving.
# Agent 27 moved to (5, 0)
# Agent 67 at (7, 16) is moving.
# Agent 67 moved to (8, 17)
# Agent 76 at (14, 9) is moving.
# Agent 76 moved to (15, 9)
# Agent 6 at (12, 14) is moving.
# Agent 6 moved to (13, 15)
# Agent 34 at (2, 4) is moving.
# Agent 34 moved to (3, 4)
# Agent 81 at (18, 8) is moving.
# Agent 81 moved to (19, 9)
# Agent 44 at (16, 13) is moving.
# Agent 44 moved to (15, 13)
# Agent 23 at (3, 4) is moving.
# Agent 23 moved to (2, 4)
# Agent 73 at (10, 11) is moving.
# Agent 73 moved to (11, 11)
# Agent 72 at (9, 0) is moving.
# Agent 72 moved to (8, 0)
# Agent 56 at (13, 13) is moving.
# Agent 56 moved to (13, 14)
# Agent 53 at (4, 8) is moving.
# Agent 53 moved to (4, 9)
# Agent 29 at (15, 2) is moving.
# Agent 29 moved to (14, 2)
# Agent 65 at (10, 15) is moving.
# Agent 65 moved to (11, 15)
# Agent 63 at (9, 5) is moving.
# Agent 63 moved to (9, 6)
# Agent 66 at (15, 19) is moving.
# Agent 66 moved to (16, 19)
# Agent 97 at (9, 4) is moving.
# Agent 97 moved to (10, 4)
# Agent 64 at (10, 16) is moving.
# Agent 64 moved to (9, 17)
# Agent 40 at (0, 6) is moving.
# Agent 40 moved to (1, 6)
# Agent 90 at (5, 14) is moving.
# Agent 90 moved to (6, 14)
# Agent 8 at (9, 3) is moving.
# Agent 8 moved to (8, 3)
# Agent 26 at (17, 11) is moving.
# Agent 26 moved to (16, 10)
# Sheep 26 reproduced at (15, 9)
# Agent 83 at (18, 0) is moving.
# Agent 83 moved to (18, 1)
# Agent 52 at (16, 0) is moving.
# Agent 52 moved to (16, 1)
# Agent 60 at (13, 19) is moving.
# Agent 60 moved to (12, 18)
# Agent 19 at (11, 2) is moving.
# Agent 19 moved to (10, 1)
# Agent 11 at (15, 3) is moving.
# Agent 11 moved to (14, 2)
# Agent 77 at (7, 12) is moving.
# Agent 77 moved to (6, 11)
# Agent 43 at (10, 12) is moving.
# Agent 43 moved to (10, 11)
# Agent 9 at (10, 4) is moving.
# Agent 9 moved to (9, 4)
# Agent 54 at (1, 13) is moving.
# Agent 54 moved to (2, 12)
# Agent 98 at (4, 10) is moving.
# Agent 98 moved to (4, 9)
# Agent 2 at (4, 8) is moving.
# Agent 2 moved to (3, 9)
# Agent 69 at (7, 9) is moving.
# Agent 69 moved to (8, 9)
# Agent 148 at (2, 8) is moving.
# Agent 148 moved to (3, 8)
# Agent 96 at (18, 15) is moving.
# Agent 96 moved to (17, 14)
# Agent 24 at (4, 4) is moving.
# Agent 24 moved to (3, 3)
# Agent 33 at (2, 18) is moving.
# Agent 33 moved to (1, 18)
# Agent 35 at (2, 11) is moving.
# Agent 35 moved to (1, 12)
# Agent 7 at (12, 11) is moving.
# Agent 7 moved to (12, 10)
# Agent 62 at (15, 3) is moving.
# Agent 62 moved to (15, 4)
# Agent 50 at (14, 4) is moving.
# Agent 50 moved to (15, 3)
# Agent 59 at (19, 12) is moving.
# Agent 59 moved to (18, 12)
# Agent 100 at (17, 14) is moving.
# Agent 100 moved to (17, 15)
# Agent 86 at (18, 10) is moving.
# Agent 86 moved to (17, 10)
# Agent 48 at (6, 5) is moving.
# Agent 48 moved to (5, 5)
# Agent 28 at (14, 9) is moving.
# Agent 28 moved to (13, 10)
# Agent 91 at (7, 4) is moving.
# Agent 91 moved to (7, 5)
# Agent 55 at (11, 10) is moving.
# Agent 55 moved to (12, 9)
# Agent 10 at (3, 7) is moving.
# Agent 10 moved to (3, 6)
# Agent 15 at (10, 6) is moving.
# Agent 15 moved to (11, 5)
# Agent 14 at (17, 12) is moving.
# Agent 14 moved to (17, 11)
# Agent 37 at (14, 9) is moving.
# Agent 37 moved to (13, 8)
# Agent 152 at (9, 12) is moving.
# Agent 152 moved to (10, 13)
# Agent 132 at (0, 16) is moving.
# Agent 132 moved to (19, 17)
# Agent 41 at (0, 0) is moving.
# Agent 41 moved to (19, 1)
# Agent 78 at (0, 10) is moving.
# Agent 78 moved to (0, 11)
# Agent 136 at (12, 2) is moving.
# Agent 136 moved to (11, 2)
# Agent 25 at (15, 12) is moving.
# Agent 25 moved to (16, 12)
# Agent 61 at (1, 7) is moving.
# Agent 61 moved to (2, 8)
# Agent 87 at (19, 15) is moving.
# Agent 87 moved to (0, 16)
# Agent 31 at (12, 15) is moving.
# Agent 31 moved to (11, 15)
# Agent 68 at (13, 15) is moving.
# Agent 68 moved to (12, 16)
# Agent 36 at (11, 2) is moving.
# Agent 36 moved to (12, 2)
# Agent 75 at (6, 15) is moving.
# Agent 75 moved to (6, 16)
# Agent 149 at (0, 16) is moving.
# Agent 149 moved to (1, 16)
# Agent 71 at (5, 18) is moving.
# Agent 71 moved to (4, 19)
# Agent 137 at (18, 17) is moving.
# Agent 137 moved to (17, 17)
# Agent 20 at (5, 8) is moving.
# Agent 20 moved to (4, 8)
# Agent 12 at (9, 4) is moving.
# Agent 12 moved to (10, 3)
# Agent 17 at (2, 14) is moving.
# Agent 17 moved to (2, 15)
# Agent 38 at (4, 5) is moving.
# Agent 38 moved to (5, 4)
# Agent 30 at (8, 19) is moving.
# Agent 30 moved to (9, 18)
# Agent 42 at (2, 12) is moving.
# Agent 42 moved to (2, 11)
# Agent 74 at (1, 18) is moving.
# Agent 74 moved to (1, 19)
# Agent 45 at (15, 6) is moving.
# Agent 45 moved to (14, 7)
# Agent 133 at (12, 19) is moving.
# Agent 133 moved to (12, 18)
# Agent 95 at (16, 0) is moving.
# Agent 95 moved to (17, 19)
# Agent 107 at (6, 11) is moving.
# Agent 107 moved to (5, 12)
# Agent 125 at (7, 4) is moving.
# Agent 125 moved to (7, 5)
# Wolf 125 ate Sheep 91 at (7, 5)
# Wolf 125 reproduced at (7, 6)
# Agent 145 at (4, 3) is moving.
# Agent 145 moved to (4, 4)
# Wolf 145 died at (4, 4)
# Agent 121 at (2, 0) is moving.
# Agent 121 moved to (1, 0)
# Wolf 121 ate Sheep 4 at (1, 0)
# Wolf 121 reproduced at (1, 19)
# Agent 108 at (8, 2) is moving.
# Agent 108 moved to (8, 3)
# Wolf 108 ate Sheep 8 at (8, 3)
# Wolf 108 reproduced at (9, 4)
# Agent 118 at (1, 6) is moving.
# Agent 118 moved to (2, 5)
# Agent 155 at (0, 14) is moving.
# Agent 155 moved to (0, 15)
# Agent 144 at (19, 1) is moving.
# Agent 144 moved to (18, 2)
# Agent 119 at (14, 12) is moving.
# Agent 119 moved to (13, 13)
# Agent 123 at (5, 0) is moving.
# Agent 123 moved to (5, 1)
# Agent 141 at (17, 0) is moving.
# Agent 141 moved to (16, 0)
# Agent 124 at (13, 3) is moving.
# Agent 124 moved to (14, 2)
# Wolf 124 ate Sheep 11 at (14, 2)
# Wolf 124 reproduced at (14, 1)
# Wolf 124 died at (14, 2)
# Agent 143 at (1, 1) is moving.
# Agent 143 moved to (0, 2)
# Agent 139 at (8, 6) is moving.
# Agent 139 moved to (9, 5)
# Agent 142 at (6, 11) is moving.
# Agent 142 moved to (6, 12)
# Agent 114 at (3, 2) is moving.
# Agent 114 moved to (4, 2)
# Agent 103 at (19, 19) is moving.
# Agent 103 moved to (0, 19)
# Agent 127 at (15, 7) is moving.
# Agent 127 moved to (14, 7)
# Wolf 127 ate Sheep 45 at (14, 7)
# Wolf 127 reproduced at (13, 8)
# Agent 101 at (16, 1) is moving.
# Agent 101 moved to (16, 2)
# Agent 138 at (10, 7) is moving.
# Agent 138 moved to (10, 6)
# Agent 106 at (5, 5) is moving.
# Agent 106 moved to (6, 4)
# Agent 117 at (18, 2) is moving.
# Agent 117 moved to (17, 3)
# Wolf 117 died at (17, 3)
# Agent 129 at (19, 13) is moving.
# Agent 129 moved to (18, 13)
# Agent 153 at (8, 3) is moving.
# Agent 153 moved to (8, 4)
# Agent 157 at (13, 15) is moving.
# Agent 157 moved to (13, 16)
# Agent 140 at (6, 3) is moving.
# Agent 140 moved to (6, 2)
# Agent 105 at (12, 0) is moving.
# Agent 105 moved to (12, 1)
# Agent 130 at (6, 3) is moving.
# Agent 130 moved to (6, 4)
# Agent 109 at (5, 12) is moving.
# Agent 109 moved to (4, 13)
# Agent 158 at (8, 3) is moving.
# Agent 158 moved to (9, 4)
# Wolf 158 ate Sheep 9 at (9, 4)
# Wolf 158 reproduced at (8, 5)
# Agent 146 at (7, 3) is moving.
# Agent 146 moved to (6, 4)
# Agent 110 at (9, 6) is moving.
# Agent 110 moved to (10, 6)
# Agent 112 at (5, 17) is moving.
# Agent 112 moved to (6, 16)
# Wolf 112 ate Sheep 75 at (6, 16)
# Wolf 112 reproduced at (7, 16)
# Agent 116 at (8, 18) is moving.
# Agent 116 moved to (8, 19)
# Agent 102 at (6, 0) is moving.
# Agent 102 moved to (7, 1)
# Agent 154 at (7, 18) is moving.
# Agent 154 moved to (8, 18)
# Agent 104 at (7, 19) is moving.
# Agent 104 moved to (6, 19)
# Agent 115 at (15, 16) is moving.
# Agent 115 moved to (15, 15)
# Wolf 115 ate Sheep 92 at (15, 15)
# Wolf 115 reproduced at (16, 14)
# Agent 120 at (10, 13) is moving.
# Agent 120 moved to (9, 13)
# Agent 147 at (6, 11) is moving.
# Agent 147 moved to (5, 11)
# Agent 113 at (7, 14) is moving.
# Agent 113 moved to (7, 15)
# Agent 156 at (7, 19) is moving.
# Agent 156 moved to (6, 18)
# Agent 111 at (9, 9) is moving.
# Agent 111 moved to (10, 10)
# Agent 122 at (15, 9) is moving.
# Agent 122 moved to (15, 10)
# Agent 20 at (4, 8) is moving.
# Agent 20 moved to (4, 9)
# Agent 98 at (4, 9) is moving.
# Agent 98 moved to (5, 9)
# Agent 59 at (18, 12) is moving.
# Agent 59 moved to (19, 11)
# Agent 40 at (1, 6) is moving.
# Agent 40 moved to (0, 7)
# Agent 6 at (13, 15) is moving.
# Agent 6 moved to (12, 15)
# Agent 25 at (16, 12) is moving.
# Agent 25 moved to (17, 13)
# Sheep 25 reproduced at (18, 13)
# Agent 44 at (15, 13) is moving.
# Agent 44 moved to (14, 12)
# Agent 97 at (10, 4) is moving.
# Agent 97 moved to (11, 3)
# Agent 21 at (0, 17) is moving.
# Agent 21 moved to (1, 17)
# Sheep 21 reproduced at (1, 18)
# Agent 34 at (3, 4) is moving.
# Agent 34 moved to (2, 5)
# Agent 50 at (15, 3) is moving.
# Agent 50 moved to (16, 3)
# Agent 100 at (17, 15) is moving.
# Agent 100 moved to (18, 14)
# Agent 48 at (5, 5) is moving.
# Agent 48 moved to (6, 4)
# Agent 72 at (8, 0) is moving.
# Agent 72 moved to (8, 19)
# Agent 78 at (0, 11) is moving.
# Agent 78 moved to (1, 10)
# Agent 90 at (6, 14) is moving.
# Agent 90 moved to (6, 15)
# Agent 159 at (13, 8) is moving.
# Agent 159 moved to (13, 7)
# Agent 52 at (16, 1) is moving.
# Agent 52 moved to (16, 2)
# Sheep 52 reproduced at (16, 1)
# Agent 131 at (6, 3) is moving.
# Agent 131 moved to (7, 4)
# Sheep 131 reproduced at (8, 5)
# Agent 152 at (10, 13) is moving.
# Agent 152 moved to (11, 14)
# Agent 149 at (1, 16) is moving.
# Agent 149 moved to (2, 16)
# Agent 3 at (14, 8) is moving.
# Agent 3 moved to (14, 7)
# Agent 56 at (13, 14) is moving.
# Agent 56 moved to (12, 15)
# Agent 43 at (10, 11) is moving.
# Agent 43 moved to (11, 10)
# Agent 17 at (2, 15) is moving.
# Agent 17 moved to (1, 16)
# Agent 74 at (1, 19) is moving.
# Agent 74 moved to (2, 19)
# Agent 65 at (11, 15) is moving.
# Agent 65 moved to (11, 16)
# Agent 19 at (10, 1) is moving.
# Agent 19 moved to (9, 0)
# Sheep 19 reproduced at (9, 19)
# Agent 133 at (12, 18) is moving.
# Agent 133 moved to (13, 17)
# Agent 33 at (1, 18) is moving.
# Agent 33 moved to (0, 18)
# Agent 55 at (12, 9) is moving.
# Agent 55 moved to (11, 9)
# Agent 41 at (19, 1) is moving.
# Agent 41 moved to (0, 2)
# Agent 73 at (11, 11) is moving.
# Agent 73 moved to (12, 11)
# Agent 89 at (4, 19) is moving.
# Agent 89 moved to (3, 18)
# Agent 79 at (9, 12) is moving.
# Agent 79 moved to (10, 12)
# Sheep 79 reproduced at (10, 11)
# Agent 35 at (1, 12) is moving.
# Agent 35 moved to (1, 11)
# Sheep 35 reproduced at (1, 10)
# Agent 99 at (1, 13) is moving.
# Agent 99 moved to (2, 12)
# Agent 53 at (4, 9) is moving.
# Agent 53 moved to (3, 10)
# Agent 29 at (14, 2) is moving.
# Agent 29 moved to (13, 3)
# Agent 26 at (16, 10) is moving.
# Agent 26 moved to (16, 9)
# Agent 96 at (17, 14) is moving.
# Agent 96 moved to (18, 14)
# Agent 68 at (12, 16) is moving.
# Agent 68 moved to (11, 15)
# Agent 18 at (18, 11) is moving.
# Agent 18 moved to (18, 12)
# Agent 60 at (12, 18) is moving.
# Agent 60 moved to (13, 19)
# Agent 12 at (10, 3) is moving.
# Agent 12 moved to (9, 2)
# Agent 87 at (0, 16) is moving.
# Agent 87 moved to (19, 16)
# Agent 61 at (2, 8) is moving.
# Agent 61 moved to (1, 9)
# Agent 57 at (6, 14) is moving.
# Agent 57 moved to (7, 15)
# Agent 27 at (5, 0) is moving.
# Agent 27 moved to (6, 19)
# Agent 2 at (3, 9) is moving.
# Agent 2 moved to (2, 10)
# Agent 23 at (2, 4) is moving.
# Agent 23 moved to (3, 4)
# Agent 15 at (11, 5) is moving.
# Agent 15 moved to (11, 4)
# Agent 16 at (10, 8) is moving.
# Agent 16 moved to (10, 7)
# Agent 49 at (18, 18) is moving.
# Agent 49 moved to (17, 18)
# Sheep 49 reproduced at (18, 19)
# Agent 14 at (17, 11) is moving.
# Agent 14 moved to (17, 10)
# Agent 148 at (3, 8) is moving.
# Agent 148 moved to (4, 7)
# Agent 37 at (13, 8) is moving.
# Agent 37 moved to (12, 9)
# Sheep 37 reproduced at (12, 8)
# Agent 42 at (2, 11) is moving.
# Agent 42 moved to (3, 12)
# Agent 86 at (17, 10) is moving.
# Agent 86 moved to (18, 10)
# Agent 71 at (4, 19) is moving.
# Agent 71 moved to (3, 19)
# Agent 30 at (9, 18) is moving.
# Agent 30 moved to (10, 18)
# Agent 150 at (0, 14) is moving.
# Agent 150 moved to (19, 14)
# Agent 7 at (12, 10) is moving.
# Agent 7 moved to (12, 11)
# Agent 31 at (11, 15) is moving.
# Agent 31 moved to (10, 14)
# Agent 28 at (13, 10) is moving.
# Agent 28 moved to (12, 11)
# Agent 10 at (3, 6) is moving.
# Agent 10 moved to (3, 7)
# Agent 95 at (17, 19) is moving.
# Agent 95 moved to (18, 18)
# Agent 54 at (2, 12) is moving.
# Agent 54 moved to (1, 12)
# Agent 132 at (19, 17) is moving.
# Agent 132 moved to (0, 17)
# Sheep 132 reproduced at (19, 16)
# Agent 66 at (16, 19) is moving.
# Agent 66 moved to (16, 18)
# Agent 160 at (15, 9) is moving.
# Agent 160 moved to (15, 10)
# Agent 151 at (14, 17) is moving.
# Agent 151 moved to (14, 18)
# Agent 137 at (17, 17) is moving.
# Agent 137 moved to (18, 18)
# Agent 5 at (16, 3) is moving.
# Agent 5 moved to (17, 2)
# Agent 24 at (3, 3) is moving.
# Agent 24 moved to (4, 2)
# Agent 70 at (6, 11) is moving.
# Agent 70 moved to (7, 11)
# Agent 69 at (8, 9) is moving.
# Agent 69 moved to (7, 8)
# Agent 36 at (12, 2) is moving.
# Agent 36 moved to (11, 2)
# Agent 83 at (18, 1) is moving.
# Agent 83 moved to (18, 0)
# Agent 85 at (4, 6) is moving.
# Agent 85 moved to (3, 7)
# Agent 62 at (15, 4) is moving.
# Agent 62 moved to (16, 4)
# Agent 67 at (8, 17) is moving.
# Agent 67 moved to (9, 16)
# Agent 64 at (9, 17) is moving.
# Agent 64 moved to (8, 17)
# Agent 81 at (19, 9) is moving.
# Agent 81 moved to (0, 8)
# Agent 38 at (5, 4) is moving.
# Agent 38 moved to (5, 5)
# Agent 82 at (7, 0) is moving.
# Agent 82 moved to (7, 19)
# Agent 136 at (11, 2) is moving.
# Agent 136 moved to (12, 1)
# Agent 76 at (15, 9) is moving.
# Agent 76 moved to (16, 10)
# Agent 63 at (9, 6) is moving.
# Agent 63 moved to (10, 7)
# Agent 77 at (6, 11) is moving.
# Agent 77 moved to (5, 10)
# Agent 129 at (18, 13) is moving.
# Agent 129 moved to (19, 13)
# Agent 166 at (8, 5) is moving.
# Agent 166 moved to (9, 6)
# Agent 123 at (5, 1) is moving.
# Agent 123 moved to (6, 0)
# Agent 165 at (13, 8) is moving.
# Agent 165 moved to (13, 7)
# Wolf 165 ate Sheep 159 at (13, 7)
# Wolf 165 reproduced at (14, 6)
# Agent 168 at (16, 14) is moving.
# Agent 168 moved to (17, 15)
# Agent 138 at (10, 6) is moving.
# Agent 138 moved to (11, 5)
# Agent 112 at (6, 16) is moving.
# Agent 112 moved to (6, 17)
# Agent 125 at (7, 5) is moving.
# Agent 125 moved to (8, 6)
# Agent 141 at (16, 0) is moving.
# Agent 141 moved to (17, 0)
# Agent 144 at (18, 2) is moving.
# Agent 144 moved to (17, 1)
# Agent 102 at (7, 1) is moving.
# Agent 102 moved to (7, 0)
# Agent 146 at (6, 4) is moving.
# Agent 146 moved to (5, 5)
# Wolf 146 ate Sheep 38 at (5, 5)
# Wolf 146 reproduced at (6, 6)
# Agent 111 at (10, 10) is moving.
# Agent 111 moved to (9, 11)
# Agent 130 at (6, 4) is moving.
# Agent 130 moved to (6, 3)
# Agent 127 at (14, 7) is moving.
# Agent 127 moved to (15, 7)
# Agent 162 at (1, 19) is moving.
# Agent 162 moved to (0, 18)
# Wolf 162 ate Sheep 33 at (0, 18)
# Wolf 162 reproduced at (19, 18)
# Agent 153 at (8, 4) is moving.
# Agent 153 moved to (7, 5)
# Agent 101 at (16, 2) is moving.
# Agent 101 moved to (15, 3)
# Agent 155 at (0, 15) is moving.
# Agent 155 moved to (19, 16)
# Wolf 155 ate Sheep 178 at (19, 16)
# Wolf 155 reproduced at (19, 17)
# Agent 113 at (7, 15) is moving.
# Agent 113 moved to (6, 16)
# Agent 156 at (6, 18) is moving.
# Agent 156 moved to (5, 18)
# Agent 107 at (5, 12) is moving.
# Agent 107 moved to (5, 13)
# Agent 161 at (7, 6) is moving.
# Agent 161 moved to (7, 7)
# Agent 142 at (6, 12) is moving.
# Agent 142 moved to (7, 11)
# Wolf 142 ate Sheep 70 at (7, 11)
# Wolf 142 reproduced at (7, 12)
# Agent 115 at (15, 15) is moving.
# Agent 115 moved to (14, 15)
# Agent 147 at (5, 11) is moving.
# Agent 147 moved to (4, 10)
# Agent 105 at (12, 1) is moving.
# Agent 105 moved to (12, 2)
# Agent 103 at (0, 19) is moving.
# Agent 103 moved to (19, 19)
# Agent 114 at (4, 2) is moving.
# Agent 114 moved to (3, 2)
# Agent 157 at (13, 16) is moving.
# Agent 157 moved to (12, 17)
# Agent 109 at (4, 13) is moving.
# Agent 109 moved to (3, 12)
# Wolf 109 ate Sheep 42 at (3, 12)
# Wolf 109 reproduced at (2, 12)
# Agent 108 at (8, 3) is moving.
# Agent 108 moved to (9, 3)
# Agent 140 at (6, 2) is moving.
# Agent 140 moved to (6, 1)
# Agent 119 at (13, 13) is moving.
# Agent 119 moved to (12, 13)
# Agent 158 at (9, 4) is moving.
# Agent 158 moved to (8, 4)
# Wolf 158 died at (8, 4)
# Agent 163 at (9, 4) is moving.
# Agent 163 moved to (10, 4)
# Agent 121 at (1, 0) is moving.
# Agent 121 moved to (0, 1)
# Agent 116 at (8, 19) is moving.
# Agent 116 moved to (8, 0)
# Agent 154 at (8, 18) is moving.
# Agent 154 moved to (9, 18)
# Agent 110 at (10, 6) is moving.
# Agent 110 moved to (9, 5)
# Agent 118 at (2, 5) is moving.
# Agent 118 moved to (1, 5)
# Agent 106 at (6, 4) is moving.
# Agent 106 moved to (5, 3)
# Agent 104 at (6, 19) is moving.
# Agent 104 moved to (6, 0)
# Agent 120 at (9, 13) is moving.
# Agent 120 moved to (8, 12)
# Agent 167 at (7, 16) is moving.
# Agent 167 moved to (6, 17)
# Agent 143 at (0, 2) is moving.
# Agent 143 moved to (1, 1)
# Wolf 143 died at (1, 1)
# Agent 122 at (15, 10) is moving.
# Agent 122 moved to (16, 11)
# Agent 164 at (14, 1) is moving.
# Agent 164 moved to (13, 1)
# Agent 139 at (9, 5) is moving.
# Agent 139 moved to (9, 6)
# Agent 173 at (9, 19) is moving.
# Agent 173 moved to (9, 0)
# Agent 81 at (0, 8) is moving.
# Agent 81 moved to (1, 8)
# Agent 14 at (17, 10) is moving.
# Agent 14 moved to (18, 10)
# Agent 29 at (13, 3) is moving.
# Agent 29 moved to (12, 2)
# Agent 74 at (2, 19) is moving.
# Agent 74 moved to (3, 19)
# Agent 85 at (3, 7) is moving.
# Agent 85 moved to (3, 8)
# Agent 59 at (19, 11) is moving.
# Agent 59 moved to (18, 10)
# Agent 61 at (1, 9) is moving.
# Agent 61 moved to (2, 9)
# Agent 100 at (18, 14) is moving.
# Agent 100 moved to (19, 15)
# Agent 67 at (9, 16) is moving.
# Agent 67 moved to (8, 15)
# Agent 99 at (2, 12) is moving.
# Agent 99 moved to (1, 11)
# Agent 137 at (18, 18) is moving.
# Agent 137 moved to (19, 17)
# Agent 66 at (16, 18) is moving.
# Agent 66 moved to (17, 19)
# Agent 17 at (1, 16) is moving.
# Agent 17 moved to (0, 17)
# Agent 73 at (12, 11) is moving.
# Agent 73 moved to (11, 10)
# Agent 56 at (12, 15) is moving.
# Agent 56 moved to (11, 14)
# Agent 12 at (9, 2) is moving.
# Agent 12 moved to (10, 3)
# Agent 54 at (1, 12) is moving.
# Agent 54 moved to (2, 11)
# Agent 31 at (10, 14) is moving.
# Agent 31 moved to (10, 13)
# Agent 95 at (18, 18) is moving.
# Agent 95 moved to (18, 19)
# Agent 133 at (13, 17) is moving.
# Agent 133 moved to (12, 16)
# Agent 68 at (11, 15) is moving.
# Agent 68 moved to (12, 14)
# Agent 40 at (0, 7) is moving.
# Agent 40 moved to (19, 6)
# Agent 131 at (7, 4) is moving.
# Agent 131 moved to (7, 3)
# Agent 49 at (17, 18) is moving.
# Agent 49 moved to (18, 19)
# Agent 79 at (10, 12) is moving.
# Agent 79 moved to (10, 11)
# Agent 3 at (14, 7) is moving.
# Agent 3 moved to (14, 8)
# Agent 25 at (17, 13) is moving.
# Agent 25 moved to (17, 12)
# Agent 52 at (16, 2) is moving.
# Agent 52 moved to (16, 1)
# Agent 27 at (6, 19) is moving.
# Agent 27 moved to (6, 0)
# Agent 50 at (16, 3) is moving.
# Agent 50 moved to (16, 2)
# Agent 152 at (11, 14) is moving.
# Agent 152 moved to (12, 15)
# Agent 34 at (2, 5) is moving.
# Agent 34 moved to (1, 6)
# Agent 2 at (2, 10) is moving.
# Agent 2 moved to (3, 9)
# Agent 82 at (7, 19) is moving.
# Agent 82 moved to (6, 19)
# Agent 148 at (4, 7) is moving.
# Agent 148 moved to (3, 8)
# Agent 37 at (12, 9) is moving.
# Agent 37 moved to (13, 9)
# Agent 76 at (16, 10) is moving.
# Agent 76 moved to (17, 11)
# Agent 151 at (14, 18) is moving.
# Agent 151 moved to (14, 17)
# Agent 78 at (1, 10) is moving.
# Agent 78 moved to (2, 10)
# Sheep 78 reproduced at (1, 11)
# Agent 5 at (17, 2) is moving.
# Agent 5 moved to (18, 3)
# Agent 30 at (10, 18) is moving.
# Agent 30 moved to (9, 17)
# Agent 63 at (10, 7) is moving.
# Agent 63 moved to (10, 8)
# Agent 89 at (3, 18) is moving.
# Agent 89 moved to (3, 19)
# Agent 26 at (16, 9) is moving.
# Agent 26 moved to (17, 10)
# Agent 96 at (18, 14) is moving.
# Agent 96 moved to (19, 15)
# Agent 132 at (0, 17) is moving.
# Agent 132 moved to (19, 18)
# Agent 19 at (9, 0) is moving.
# Agent 19 moved to (9, 19)
# Agent 172 at (8, 5) is moving.
# Agent 172 moved to (7, 6)
# Agent 24 at (4, 2) is moving.
# Agent 24 moved to (4, 3)
# Sheep 24 reproduced at (5, 4)
# Agent 149 at (2, 16) is moving.
# Agent 149 moved to (2, 17)
# Agent 77 at (5, 10) is moving.
# Agent 77 moved to (4, 11)
# Agent 60 at (13, 19) is moving.
# Agent 60 moved to (12, 0)
# Agent 136 at (12, 1) is moving.
# Agent 136 moved to (12, 0)
# Agent 176 at (18, 19) is moving.
# Agent 176 moved to (18, 0)
# Agent 150 at (19, 14) is moving.
# Agent 150 moved to (18, 14)
# Agent 57 at (7, 15) is moving.
# Agent 57 moved to (8, 16)
# Sheep 57 reproduced at (8, 15)
# Agent 170 at (1, 18) is moving.
# Agent 170 moved to (0, 18)
# Agent 43 at (11, 10) is moving.
# Agent 43 moved to (11, 9)
# Agent 90 at (6, 15) is moving.
# Agent 90 moved to (6, 16)
# Agent 64 at (8, 17) is moving.
# Agent 64 moved to (7, 18)
# Agent 53 at (3, 10) is moving.
# Agent 53 moved to (4, 11)
# Agent 71 at (3, 19) is moving.
# Agent 71 moved to (2, 19)
# Agent 55 at (11, 9) is moving.
# Agent 55 moved to (10, 9)
# Agent 41 at (0, 2) is moving.
# Agent 41 moved to (19, 1)
# Agent 28 at (12, 11) is moving.
# Agent 28 moved to (13, 12)
# Agent 44 at (14, 12) is moving.
# Agent 44 moved to (13, 12)
# Agent 175 at (1, 10) is moving.
# Agent 175 moved to (2, 9)
# Agent 35 at (1, 11) is moving.
# Agent 35 moved to (1, 10)
# Agent 69 at (7, 8) is moving.
# Agent 69 moved to (7, 7)
# Agent 86 at (18, 10) is moving.
# Agent 86 moved to (18, 9)
# Sheep 86 reproduced at (19, 8)
# Agent 7 at (12, 11) is moving.
# Agent 7 moved to (13, 10)
# Agent 15 at (11, 4) is moving.
# Agent 15 moved to (12, 5)
# Agent 23 at (3, 4) is moving.
# Agent 23 moved to (4, 4)
# Agent 97 at (11, 3) is moving.
# Agent 97 moved to (10, 2)
# Agent 16 at (10, 7) is moving.
# Agent 16 moved to (11, 6)
# Agent 18 at (18, 12) is moving.
# Agent 18 moved to (17, 13)
# Agent 83 at (18, 0) is moving.
# Agent 83 moved to (17, 1)
# Agent 72 at (8, 19) is moving.
# Agent 72 moved to (9, 0)
# Agent 169 at (18, 13) is moving.
# Agent 169 moved to (17, 14)
# Agent 160 at (15, 10) is moving.
# Agent 160 moved to (15, 11)
# Agent 10 at (3, 7) is moving.
# Agent 10 moved to (4, 7)
# Agent 98 at (5, 9) is moving.
# Agent 98 moved to (5, 8)
# Agent 36 at (11, 2) is moving.
# Agent 36 moved to (12, 1)
# Agent 171 at (16, 1) is moving.
# Agent 171 moved to (17, 2)
# Agent 6 at (12, 15) is moving.
# Agent 6 moved to (13, 14)
# Agent 21 at (1, 17) is moving.
# Agent 21 moved to (1, 18)
# Agent 177 at (12, 8) is moving.
# Agent 177 moved to (11, 8)
# Agent 87 at (19, 16) is moving.
# Agent 87 moved to (0, 16)
# Sheep 87 reproduced at (0, 15)
# Agent 48 at (6, 4) is moving.
# Agent 48 moved to (5, 4)
# Agent 174 at (10, 11) is moving.
# Agent 174 moved to (9, 10)
# Agent 20 at (4, 9) is moving.
# Agent 20 moved to (4, 8)
# Agent 65 at (11, 16) is moving.
# Agent 65 moved to (11, 15)
# Agent 62 at (16, 4) is moving.
# Agent 62 moved to (15, 3)
# Agent 105 at (12, 2) is moving.
# Agent 105 moved to (11, 1)
# Agent 168 at (17, 15) is moving.
# Agent 168 moved to (16, 16)
# Agent 140 at (6, 1) is moving.
# Agent 140 moved to (6, 0)
# Wolf 140 ate Sheep 27 at (6, 0)
# Wolf 140 reproduced at (6, 19)
# Agent 155 at (19, 16) is moving.
# Agent 155 moved to (19, 15)
# Wolf 155 ate Sheep 96 at (19, 15)
# Wolf 155 reproduced at (0, 15)
# Agent 104 at (6, 0) is moving.
# Agent 104 moved to (7, 19)
# Agent 113 at (6, 16) is moving.
# Agent 113 moved to (7, 17)
# Agent 154 at (9, 18) is moving.
# Agent 154 moved to (10, 18)
# Agent 123 at (6, 0) is moving.
# Agent 123 moved to (7, 0)
# Agent 141 at (17, 0) is moving.
# Agent 141 moved to (17, 19)
# Wolf 141 ate Sheep 66 at (17, 19)
# Wolf 141 reproduced at (17, 18)
# Agent 166 at (9, 6) is moving.
# Agent 166 moved to (8, 7)
# Agent 122 at (16, 11) is moving.
# Agent 122 moved to (15, 11)
# Wolf 122 ate Sheep 160 at (15, 11)
# Wolf 122 reproduced at (14, 11)
# Agent 106 at (5, 3) is moving.
# Agent 106 moved to (5, 4)
# Wolf 106 ate Sheep 186 at (5, 4)
# Wolf 106 reproduced at (4, 5)
# Agent 116 at (8, 0) is moving.
# Agent 116 moved to (9, 0)
# Wolf 116 ate Sheep 173 at (9, 0)
# Wolf 116 reproduced at (9, 1)
# Agent 179 at (14, 6) is moving.
# Agent 179 moved to (13, 5)
# Agent 112 at (6, 17) is moving.
# Agent 112 moved to (7, 16)
# Agent 165 at (13, 7) is moving.
# Agent 165 moved to (12, 7)
# Agent 180 at (6, 6) is moving.
# Agent 180 moved to (5, 7)
# Agent 153 at (7, 5) is moving.
# Agent 153 moved to (7, 4)
# Agent 163 at (10, 4) is moving.
# Agent 163 moved to (10, 5)
# Agent 120 at (8, 12) is moving.
# Agent 120 moved to (7, 12)
# Agent 121 at (0, 1) is moving.
# Agent 121 moved to (0, 0)
# Agent 156 at (5, 18) is moving.
# Agent 156 moved to (6, 18)
# Agent 181 at (19, 18) is moving.
# Agent 181 moved to (18, 17)
# Agent 183 at (7, 12) is moving.
# Agent 183 moved to (8, 11)
# Agent 101 at (15, 3) is moving.
# Agent 101 moved to (15, 2)
# Agent 144 at (17, 1) is moving.
# Agent 144 moved to (16, 2)
# Wolf 144 ate Sheep 50 at (16, 2)
# Wolf 144 reproduced at (17, 1)
# Agent 157 at (12, 17) is moving.
# Agent 157 moved to (12, 18)
# Agent 129 at (19, 13) is moving.
# Agent 129 moved to (18, 12)
# Agent 127 at (15, 7) is moving.
# Agent 127 moved to (15, 8)
# Agent 162 at (0, 18) is moving.
# Agent 162 moved to (19, 17)
# Wolf 162 ate Sheep 137 at (19, 17)
# Wolf 162 reproduced at (18, 17)
# Agent 182 at (19, 17) is moving.
# Agent 182 moved to (0, 17)
# Wolf 182 ate Sheep 17 at (0, 17)
# Wolf 182 reproduced at (0, 16)
# Agent 110 at (9, 5) is moving.
# Agent 110 moved to (10, 6)
# Agent 108 at (9, 3) is moving.
# Agent 108 moved to (10, 4)
# Agent 109 at (3, 12) is moving.
# Agent 109 moved to (4, 11)
# Wolf 109 ate Sheep 53 at (4, 11)
# Wolf 109 reproduced at (4, 12)
# Agent 139 at (9, 6) is moving.
# Agent 139 moved to (8, 6)
# Agent 147 at (4, 10) is moving.
# Agent 147 moved to (3, 10)
# Agent 138 at (11, 5) is moving.
# Agent 138 moved to (10, 4)
# Agent 118 at (1, 5) is moving.
# Agent 118 moved to (2, 5)
# Agent 107 at (5, 13) is moving.
# Agent 107 moved to (5, 12)
# Agent 130 at (6, 3) is moving.
# Agent 130 moved to (5, 4)
# Wolf 130 ate Sheep 48 at (5, 4)
# Wolf 130 reproduced at (4, 4)
# Agent 146 at (5, 5) is moving.
# Agent 146 moved to (4, 4)
# Wolf 146 ate Sheep 23 at (4, 4)
# Wolf 146 reproduced at (4, 5)
# Agent 184 at (2, 12) is moving.
# Agent 184 moved to (1, 13)
# Agent 164 at (13, 1) is moving.
# Agent 164 moved to (13, 2)
# Wolf 164 died at (13, 2)
# Agent 114 at (3, 2) is moving.
# Agent 114 moved to (2, 2)
# Agent 125 at (8, 6) is moving.
# Agent 125 moved to (7, 7)
# Wolf 125 ate Sheep 69 at (7, 7)
# Wolf 125 reproduced at (7, 8)
# Agent 142 at (7, 11) is moving.
# Agent 142 moved to (8, 12)
# Agent 119 at (12, 13) is moving.
# Agent 119 moved to (11, 13)
# Agent 167 at (6, 17) is moving.
# Agent 167 moved to (5, 17)
# Agent 102 at (7, 0) is moving.
# Agent 102 moved to (7, 1)
# Agent 111 at (9, 11) is moving.
# Agent 111 moved to (10, 12)
# Agent 103 at (19, 19) is moving.
# Agent 103 moved to (19, 0)
# Agent 161 at (7, 7) is moving.
# Agent 161 moved to (8, 6)
# Agent 115 at (14, 15) is moving.
# Agent 115 moved to (13, 14)
# Wolf 115 ate Sheep 6 at (13, 14)
# Wolf 115 reproduced at (14, 15)
# Agent 97 at (10, 2) is moving.
# Agent 97 moved to (9, 1)
# Agent 74 at (3, 19) is moving.
# Agent 74 moved to (2, 18)
# Agent 76 at (17, 11) is moving.
# Agent 76 moved to (16, 12)
# Sheep 76 reproduced at (16, 11)
# Agent 61 at (2, 9) is moving.
# Agent 61 moved to (1, 9)
# Agent 60 at (12, 0) is moving.
# Agent 60 moved to (12, 1)
# Agent 55 at (10, 9) is moving.
# Agent 55 moved to (10, 8)
# Agent 52 at (16, 1) is moving.
# Agent 52 moved to (16, 2)
# Agent 136 at (12, 0) is moving.
# Agent 136 moved to (13, 1)
# Agent 26 at (17, 10) is moving.
# Agent 26 moved to (16, 9)
# Agent 67 at (8, 15) is moving.
# Agent 67 moved to (9, 15)
# Agent 21 at (1, 18) is moving.
# Agent 21 moved to (1, 17)
# Agent 35 at (1, 10) is moving.
# Agent 35 moved to (0, 11)
# Agent 150 at (18, 14) is moving.
# Agent 150 moved to (18, 15)
# Agent 10 at (4, 7) is moving.
# Agent 10 moved to (5, 6)
# Agent 85 at (3, 8) is moving.
# Agent 85 moved to (4, 8)
# Agent 151 at (14, 17) is moving.
# Agent 151 moved to (15, 16)
# Agent 24 at (4, 3) is moving.
# Agent 24 moved to (5, 3)
# Agent 34 at (1, 6) is moving.
# Agent 34 moved to (2, 5)
# Agent 19 at (9, 19) is moving.
# Agent 19 moved to (8, 0)
# Agent 187 at (8, 15) is moving.
# Agent 187 moved to (8, 16)
# Agent 28 at (13, 12) is moving.
# Agent 28 moved to (12, 12)
# Agent 16 at (11, 6) is moving.
# Agent 16 moved to (10, 6)
# Agent 49 at (18, 19) is moving.
# Agent 49 moved to (19, 0)
# Agent 68 at (12, 14) is moving.
# Agent 68 moved to (13, 14)
# Agent 57 at (8, 16) is moving.
# Agent 57 moved to (9, 16)
# Agent 90 at (6, 16) is moving.
# Agent 90 moved to (5, 16)
# Agent 18 at (17, 13) is moving.
# Agent 18 moved to (18, 14)
# Agent 14 at (18, 10) is moving.
# Agent 14 moved to (18, 9)
# Agent 185 at (1, 11) is moving.
# Agent 185 moved to (1, 12)
# Agent 98 at (5, 8) is moving.
# Agent 98 moved to (6, 9)
# Agent 7 at (13, 10) is moving.
# Agent 7 moved to (12, 11)
# Agent 189 at (0, 15) is moving.
# Agent 189 moved to (1, 14)
# Agent 86 at (18, 9) is moving.
# Agent 86 moved to (18, 10)
# Agent 43 at (11, 9) is moving.
# Agent 43 moved to (10, 8)
# Agent 72 at (9, 0) is moving.
# Agent 72 moved to (10, 0)
# Agent 29 at (12, 2) is moving.
# Agent 29 moved to (13, 3)
# Agent 132 at (19, 18) is moving.
# Agent 132 moved to (18, 19)
# Agent 30 at (9, 17) is moving.
# Agent 30 moved to (10, 18)
# Agent 2 at (3, 9) is moving.
# Agent 2 moved to (4, 10)
# Sheep 2 reproduced at (3, 10)
# Agent 37 at (13, 9) is moving.
# Agent 37 moved to (13, 10)
# Agent 25 at (17, 12) is moving.
# Agent 25 moved to (18, 12)
# Agent 63 at (10, 8) is moving.
# Agent 63 moved to (9, 8)
# Agent 169 at (17, 14) is moving.
# Agent 169 moved to (18, 14)
# Agent 65 at (11, 15) is moving.
# Agent 65 moved to (12, 15)
# Agent 83 at (17, 1) is moving.
# Agent 83 moved to (16, 1)
# Agent 62 at (15, 3) is moving.
# Agent 62 moved to (15, 2)
# Agent 100 at (19, 15) is moving.
# Agent 100 moved to (19, 14)
# Agent 175 at (2, 9) is moving.
# Agent 175 moved to (3, 9)
# Agent 78 at (2, 10) is moving.
# Agent 78 moved to (1, 9)
# Agent 131 at (7, 3) is moving.
# Agent 131 moved to (6, 3)
# Agent 40 at (19, 6) is moving.
# Agent 40 moved to (19, 7)
# Sheep 40 reproduced at (0, 8)
# Agent 36 at (12, 1) is moving.
# Agent 36 moved to (11, 1)
# Agent 41 at (19, 1) is moving.
# Agent 41 moved to (0, 0)
# Agent 188 at (19, 8) is moving.
# Agent 188 moved to (19, 7)
# Agent 5 at (18, 3) is moving.
# Agent 5 moved to (19, 4)
# Agent 3 at (14, 8) is moving.
# Agent 3 moved to (15, 7)
# Agent 56 at (11, 14) is moving.
# Agent 56 moved to (11, 13)
# Agent 73 at (11, 10) is moving.
# Agent 73 moved to (12, 10)
# Agent 172 at (7, 6) is moving.
# Agent 172 moved to (6, 5)
# Agent 133 at (12, 16) is moving.
# Agent 133 moved to (12, 17)
# Agent 64 at (7, 18) is moving.
# Agent 64 moved to (7, 17)
# Agent 81 at (1, 8) is moving.
# Agent 81 moved to (1, 9)
# Agent 148 at (3, 8) is moving.
# Agent 148 moved to (4, 9)
# Agent 20 at (4, 8) is moving.
# Agent 20 moved to (5, 7)
# Agent 77 at (4, 11) is moving.
# Agent 77 moved to (3, 11)
# Agent 170 at (0, 18) is moving.
# Agent 170 moved to (0, 17)
# Agent 59 at (18, 10) is moving.
# Agent 59 moved to (19, 10)
# Agent 149 at (2, 17) is moving.
# Agent 149 moved to (2, 16)
# Agent 95 at (18, 19) is moving.
# Agent 95 moved to (17, 19)
# Agent 177 at (11, 8) is moving.
# Agent 177 moved to (10, 9)
# ...
# Agent 908 at (5, 6) is moving.
# Agent 908 moved to (6, 6)
# Agent 815 at (9, 3) is moving.
# Agent 815 moved to (10, 3)
# Agent 538 at (13, 18) is moving.
# Agent 538 moved to (12, 18)
# Agent 511 at (6, 14) is moving.
# Agent 511 moved to (7, 13)
# Agent 603 at (11, 10) is moving.
# Agent 603 moved to (12, 10)
# Agent 687 at (5, 0) is moving.
# Agent 687 moved to (6, 19)
# Agent 783 at (8, 7) is moving.
# Agent 783 moved to (7, 7)
# Agent 661 at (9, 1) is moving.
# Agent 661 moved to (8, 2)
# Agent 380 at (7, 15) is moving.
# Agent 380 moved to (8, 15)
# Agent 544 at (17, 17) is moving.
# Agent 544 moved to (17, 18)
# Agent 462 at (8, 18) is moving.
# Agent 462 moved to (8, 19)
# Agent 461 at (9, 15) is moving.
# Agent 461 moved to (8, 14)
# Agent 855 at (13, 15) is moving.
# Agent 855 moved to (12, 15)
# Agent 596 at (0, 18) is moving.
# Agent 596 moved to (1, 18)
# Agent 442 at (15, 10) is moving.
# Agent 442 moved to (16, 11)
# Agent 903 at (1, 17) is moving.
# Agent 903 moved to (2, 16)
# Agent 456 at (6, 12) is moving.
# Agent 456 moved to (5, 12)
# Agent 797 at (9, 5) is moving.
# Agent 797 moved to (9, 4)
# Agent 736 at (13, 0) is moving.
# Agent 736 moved to (14, 19)
# Agent 521 at (17, 18) is moving.
# Agent 521 moved to (16, 18)
# Sheep 521 reproduced at (17, 19)
# Agent 437 at (8, 3) is moving.
# Agent 437 moved to (8, 4)
# Agent 715 at (1, 7) is moving.
# Agent 715 moved to (0, 6)
# Agent 719 at (3, 4) is moving.
# Agent 719 moved to (4, 3)
# Agent 554 at (10, 9) is moving.
# Agent 554 moved to (9, 8)
# Agent 927 at (10, 3) is moving.
# Agent 927 moved to (10, 2)
# Sheep 927 reproduced at (11, 2)
# Agent 690 at (19, 7) is moving.
# Agent 690 moved to (18, 7)
# Agent 910 at (9, 5) is moving.
# Agent 910 moved to (9, 4)
# Agent 909 at (1, 15) is moving.
# Agent 909 moved to (0, 15)
# Agent 378 at (5, 12) is moving.
# Agent 378 moved to (5, 13)
# Agent 421 at (6, 12) is moving.
# Agent 421 moved to (6, 13)
# Agent 424 at (13, 19) is moving.
# Agent 424 moved to (14, 19)
# Sheep 424 reproduced at (15, 19)
# Agent 479 at (17, 1) is moving.
# Agent 479 moved to (18, 1)
# Agent 498 at (19, 18) is moving.
# Agent 498 moved to (18, 18)
# Agent 598 at (14, 8) is moving.
# Agent 598 moved to (15, 8)
# Agent 531 at (12, 10) is moving.
# Agent 531 moved to (12, 9)
# Agent 865 at (1, 3) is moving.
# Agent 865 moved to (2, 3)
# Agent 471 at (14, 8) is moving.
# Agent 471 moved to (14, 9)
# Agent 493 at (19, 14) is moving.
# Agent 493 moved to (18, 15)
# Agent 914 at (11, 3) is moving.
# Agent 914 moved to (12, 3)
# Sheep 914 reproduced at (11, 3)
# Agent 419 at (11, 14) is moving.
# Agent 419 moved to (10, 15)
# Agent 932 at (10, 0) is moving.
# Agent 932 moved to (9, 19)
# Agent 856 at (16, 1) is moving.
# Agent 856 moved to (17, 1)
# Agent 682 at (12, 7) is moving.
# Agent 682 moved to (11, 8)
# Agent 576 at (6, 19) is moving.
# Agent 576 moved to (7, 19)
# Agent 895 at (10, 2) is moving.
# Agent 895 moved to (11, 1)
# Agent 449 at (11, 3) is moving.
# Agent 449 moved to (10, 2)
# Agent 470 at (19, 18) is moving.
# Agent 470 moved to (19, 17)
# Agent 881 at (14, 16) is moving.
# Agent 881 moved to (14, 15)
# Agent 823 at (7, 17) is moving.
# Agent 823 moved to (7, 18)
# Agent 917 at (10, 1) is moving.
# Agent 917 moved to (11, 1)
# Agent 642 at (15, 0) is moving.
# Agent 642 moved to (15, 19)
# Agent 902 at (11, 2) is moving.
# Agent 902 moved to (11, 1)
# Agent 575 at (16, 18) is moving.
# Agent 575 moved to (15, 19)
# Agent 484 at (19, 12) is moving.
# Agent 484 moved to (18, 12)
# Agent 656 at (16, 2) is moving.
# Agent 656 moved to (16, 1)
# Agent 760 at (19, 12) is moving.
# Agent 760 moved to (0, 11)
# Agent 829 at (5, 0) is moving.
# Agent 829 moved to (4, 19)
# Agent 739 at (18, 0) is moving.
# Agent 739 moved to (17, 19)
# Agent 759 at (13, 0) is moving.
# Agent 759 moved to (13, 1)
# Agent 586 at (14, 15) is moving.
# Agent 586 moved to (14, 16)
# Agent 731 at (9, 16) is moving.
# Agent 731 moved to (8, 15)
# Agent 885 at (1, 2) is moving.
# Agent 885 moved to (0, 2)
# Agent 737 at (9, 14) is moving.
# Agent 737 moved to (8, 14)
# Agent 396 at (18, 9) is moving.
# Agent 396 moved to (17, 10)
# Agent 488 at (14, 16) is moving.
# Agent 488 moved to (15, 15)
# Agent 657 at (14, 12) is moving.
# Agent 657 moved to (15, 12)
# Agent 675 at (14, 4) is moving.
# Agent 675 moved to (15, 4)
# Agent 618 at (17, 2) is moving.
# Agent 618 moved to (16, 1)
# Agent 447 at (18, 11) is moving.
# Agent 447 moved to (17, 11)
# Agent 616 at (19, 6) is moving.
# Agent 616 moved to (19, 5)
# Agent 525 at (18, 5) is moving.
# Agent 525 moved to (17, 5)
# Agent 560 at (15, 4) is moving.
# Agent 560 moved to (14, 3)
# Agent 595 at (2, 11) is moving.
# Agent 595 moved to (3, 11)
# Agent 838 at (18, 14) is moving.
# Agent 838 moved to (19, 14)
# Agent 429 at (6, 17) is moving.
# Agent 429 moved to (7, 16)
# Agent 600 at (10, 18) is moving.
# Agent 600 moved to (10, 19)
# Agent 372 at (17, 15) is moving.
# Agent 372 moved to (18, 14)
# Agent 746 at (13, 6) is moving.
# Agent 746 moved to (12, 6)
# Agent 407 at (3, 6) is moving.
# Agent 407 moved to (3, 7)
# Agent 892 at (17, 2) is moving.
# Agent 892 moved to (18, 2)
# Agent 899 at (10, 3) is moving.
# Agent 899 moved to (9, 2)
# Agent 654 at (12, 1) is moving.
# Agent 654 moved to (13, 2)
# Agent 459 at (17, 2) is moving.
# Agent 459 moved to (17, 3)
# Agent 636 at (7, 4) is moving.
# Agent 636 moved to (8, 4)
# Agent 700 at (9, 18) is moving.
# Agent 700 moved to (8, 18)
# Agent 469 at (14, 19) is moving.
# Agent 469 moved to (15, 18)
# Agent 787 at (11, 3) is moving.
# Agent 787 moved to (11, 4)
# Sheep 787 reproduced at (10, 4)
# Agent 524 at (9, 6) is moving.
# Agent 524 moved to (9, 7)
# Agent 889 at (8, 15) is moving.
# Agent 889 moved to (8, 14)
# Sheep 889 reproduced at (7, 14)
# Agent 757 at (1, 6) is moving.
# Agent 757 moved to (2, 6)
# Agent 934 at (10, 8) is moving.
# Agent 934 moved to (9, 7)
# Agent 850 at (15, 5) is moving.
# Agent 850 moved to (16, 6)
# Agent 587 at (3, 1) is moving.
# Agent 587 moved to (2, 0)
# Agent 691 at (11, 3) is moving.
# Agent 691 moved to (11, 2)
# Agent 849 at (16, 0) is moving.
# Agent 849 moved to (15, 1)
# Agent 406 at (11, 19) is moving.
# Agent 406 moved to (12, 18)
# Agent 494 at (15, 1) is moving.
# Agent 494 moved to (14, 1)
# Agent 770 at (13, 14) is moving.
# Agent 770 moved to (14, 14)
# Agent 728 at (14, 12) is moving.
# Agent 728 moved to (13, 11)
# Agent 568 at (12, 9) is moving.
# Agent 568 moved to (12, 8)
# Agent 867 at (10, 17) is moving.
# Agent 867 moved to (9, 18)
# Agent 648 at (4, 2) is moving.
# Agent 648 moved to (5, 3)
# Agent 802 at (17, 10) is moving.
# Agent 802 moved to (18, 11)
# Agent 729 at (7, 9) is moving.
# Agent 729 moved to (6, 10)
# Agent 893 at (5, 12) is moving.
# Agent 893 moved to (4, 11)
# Agent 837 at (17, 17) is moving.
# Agent 837 moved to (17, 18)
# Sheep 837 reproduced at (18, 19)
# Agent 712 at (10, 12) is moving.
# Agent 712 moved to (11, 11)
# Agent 645 at (17, 17) is moving.
# Agent 645 moved to (17, 16)
# Agent 871 at (19, 12) is moving.
# Agent 871 moved to (18, 12)
# Agent 516 at (5, 2) is moving.
# Agent 516 moved to (4, 1)
# Agent 482 at (18, 17) is moving.
# Agent 482 moved to (18, 18)
# Agent 819 at (6, 6) is moving.
# Agent 819 moved to (5, 7)
# Agent 778 at (2, 5) is moving.
# Agent 778 moved to (1, 5)
# Agent 723 at (10, 3) is moving.
# Agent 723 moved to (10, 2)
# Agent 385 at (10, 0) is moving.
# Agent 385 moved to (10, 19)
# Agent 751 at (15, 1) is moving.
# Agent 751 moved to (14, 1)
# Agent 529 at (2, 13) is moving.
# Agent 529 moved to (3, 14)
# Agent 868 at (17, 4) is moving.
# Agent 868 moved to (17, 3)
# Agent 785 at (19, 14) is moving.
# Agent 785 moved to (18, 15)
# Agent 608 at (9, 14) is moving.
# Agent 608 moved to (10, 13)
# Agent 879 at (3, 15) is moving.
# Agent 879 moved to (4, 15)
# Agent 733 at (16, 4) is moving.
# Agent 733 moved to (15, 5)
# Agent 620 at (16, 12) is moving.
# Agent 620 moved to (17, 11)
# Agent 448 at (12, 8) is moving.
# Agent 448 moved to (13, 9)
# Agent 835 at (16, 4) is moving.
# Agent 835 moved to (17, 5)
# Agent 391 at (4, 15) is moving.
# Agent 391 moved to (4, 14)
# Agent 905 at (4, 2) is moving.
# Agent 905 moved to (5, 3)
# Agent 541 at (7, 2) is moving.
# Agent 541 moved to (6, 1)
# Agent 627 at (15, 1) is moving.
# Agent 627 moved to (14, 1)
# Agent 397 at (17, 7) is moving.
# Agent 397 moved to (16, 8)
# Agent 772 at (8, 0) is moving.
# Agent 772 moved to (7, 19)
# Agent 918 at (11, 18) is moving.
# Agent 918 moved to (10, 18)
# Agent 806 at (5, 6) is moving.
# Agent 806 moved to (6, 5)
# Agent 727 at (2, 5) is moving.
# Agent 727 moved to (1, 4)
# Agent 401 at (4, 1) is moving.
# Agent 401 moved to (5, 0)
# Agent 831 at (1, 14) is moving.
# Agent 831 moved to (0, 14)
# Agent 602 at (14, 0) is moving.
# Agent 602 moved to (13, 0)
# Agent 478 at (8, 2) is moving.
# Agent 478 moved to (8, 3)
# Agent 730 at (13, 15) is moving.
# Agent 730 moved to (12, 14)
# Agent 766 at (13, 15) is moving.
# Agent 766 moved to (12, 14)
# Agent 936 at (2, 19) is moving.
# Agent 936 moved to (2, 18)
# Agent 929 at (0, 12) is moving.
# Agent 929 moved to (1, 11)
# Agent 846 at (15, 17) is moving.
# Agent 846 moved to (15, 18)
# Agent 518 at (9, 12) is moving.
# Agent 518 moved to (9, 13)
# Agent 573 at (18, 16) is moving.
# Agent 573 moved to (17, 15)
# Agent 475 at (9, 19) is moving.
# Agent 475 moved to (8, 0)
# Agent 481 at (2, 16) is moving.
# Agent 481 moved to (2, 15)
# Agent 877 at (9, 6) is moving.
# Agent 877 moved to (10, 6)
# Agent 762 at (12, 14) is moving.
# Agent 762 moved to (12, 15)
# Agent 685 at (5, 5) is moving.
# Agent 685 moved to (4, 4)
# Agent 425 at (13, 7) is moving.
# Agent 425 moved to (14, 7)
# Agent 900 at (0, 5) is moving.
# Agent 900 moved to (1, 4)
# Agent 874 at (7, 5) is moving.
# Agent 874 moved to (8, 6)
# Agent 581 at (18, 14) is moving.
# Agent 581 moved to (19, 13)
# Agent 426 at (16, 3) is moving.
# Agent 426 moved to (17, 4)
# Agent 913 at (0, 2) is moving.
# Agent 913 moved to (1, 1)
# Agent 376 at (4, 19) is moving.
# Agent 376 moved to (4, 0)
# Agent 663 at (14, 0) is moving.
# Agent 663 moved to (14, 1)
# Agent 898 at (16, 10) is moving.
# Agent 898 moved to (16, 9)
# Agent 830 at (14, 16) is moving.
# Agent 830 moved to (14, 15)
# Agent 942 at (13, 8) is moving.
# Agent 942 moved to (12, 9)
# Agent 747 at (10, 8) is moving.
# Agent 747 moved to (10, 9)
# Agent 501 at (17, 5) is moving.
# Agent 501 moved to (17, 4)
# Agent 572 at (6, 7) is moving.
# Agent 572 moved to (5, 7)
# Agent 599 at (10, 6) is moving.
# Agent 599 moved to (11, 6)
# Agent 941 at (4, 9) is moving.
# Agent 941 moved to (3, 10)
# Agent 878 at (5, 11) is moving.
# Agent 878 moved to (4, 10)
# Agent 683 at (12, 1) is moving.
# Agent 683 moved to (11, 2)
# Agent 692 at (13, 17) is moving.
# Agent 692 moved to (12, 17)
# Agent 810 at (16, 16) is moving.
# Agent 810 moved to (16, 15)
# Agent 943 at (19, 18) is moving.
# Agent 943 moved to (0, 18)
# Agent 450 at (5, 16) is moving.
# Agent 450 moved to (5, 17)
# Agent 699 at (6, 5) is moving.
# Agent 699 moved to (7, 5)
# Agent 825 at (16, 6) is moving.
# Agent 825 moved to (15, 5)
# Agent 676 at (16, 14) is moving.
# Agent 676 moved to (15, 14)
# Agent 522 at (0, 10) is moving.
# Agent 522 moved to (1, 11)
# Agent 512 at (4, 8) is moving.
# Agent 512 moved to (4, 7)
# Agent 508 at (16, 2) is moving.
# Agent 508 moved to (17, 1)
# Agent 662 at (9, 1) is moving.
# Agent 662 moved to (10, 2)
# Agent 551 at (6, 13) is moving.
# Agent 551 moved to (7, 13)
# Agent 812 at (17, 11) is moving.
# Agent 812 moved to (16, 10)
# Agent 832 at (9, 9) is moving.
# Agent 832 moved to (9, 8)
# Agent 477 at (9, 7) is moving.
# Agent 477 moved to (10, 7)
# Agent 754 at (11, 5) is moving.
# Agent 754 moved to (12, 5)
# Agent 556 at (11, 17) is moving.
# Agent 556 moved to (10, 17)
# Agent 796 at (11, 15) is moving.
# Agent 796 moved to (12, 16)
# Agent 800 at (3, 10) is moving.
# Agent 800 moved to (4, 11)
# Agent 928 at (5, 12) is moving.
# Agent 928 moved to (4, 12)
# Agent 686 at (10, 16) is moving.
# Agent 686 moved to (11, 15)
# Agent 555 at (12, 15) is moving.
# Agent 555 moved to (13, 14)
# Agent 545 at (5, 4) is moving.
# Agent 545 moved to (6, 4)
# Agent 801 at (2, 8) is moving.
# Agent 801 moved to (3, 8)
# Agent 840 at (12, 11) is moving.
# Agent 840 moved to (13, 12)
# Agent 906 at (4, 19) is moving.
# Agent 906 moved to (4, 18)
# Agent 597 at (7, 9) is moving.
# Agent 597 moved to (8, 10)
# Agent 884 at (8, 4) is moving.
# Agent 884 moved to (8, 3)
# Agent 491 at (12, 0) is moving.
# Agent 491 moved to (11, 1)
# Agent 532 at (5, 9) is moving.
# Agent 532 moved to (6, 8)
# Agent 472 at (7, 6) is moving.
# Agent 472 moved to (7, 5)
# Agent 789 at (16, 4) is moving.
# Agent 789 moved to (17, 3)
# Agent 890 at (13, 6) is moving.
# Agent 890 moved to (12, 5)
# Agent 816 at (0, 1) is moving.
# Agent 816 moved to (0, 0)
# Sheep 816 reproduced at (1, 1)
# Agent 604 at (11, 12) is moving.
# Agent 604 moved to (11, 11)
# Agent 566 at (17, 0) is moving.
# Agent 566 moved to (18, 0)
# Agent 398 at (9, 4) is moving.
# Agent 398 moved to (9, 3)
# Agent 876 at (11, 6) is moving.
# Agent 876 moved to (11, 7)
# Agent 669 at (7, 1) is moving.
# Agent 669 moved to (7, 0)
# Agent 786 at (3, 18) is moving.
# Agent 786 moved to (4, 19)
# Sheep 786 reproduced at (3, 0)
# Agent 409 at (6, 6) is moving.
# Agent 409 moved to (6, 7)
# Sheep 409 reproduced at (7, 8)
# Agent 891 at (8, 14) is moving.
# Agent 891 moved to (8, 13)
# Agent 641 at (12, 1) is moving.
# Agent 641 moved to (13, 1)
# Agent 417 at (14, 6) is moving.
# Agent 417 moved to (14, 7)
# Agent 571 at (16, 9) is moving.
# Agent 571 moved to (16, 8)
# Agent 854 at (14, 18) is moving.
# Agent 854 moved to (13, 18)
# Agent 387 at (11, 15) is moving.
# Agent 387 moved to (12, 15)
# Sheep 387 reproduced at (12, 14)
# Agent 622 at (13, 14) is moving.
# Agent 622 moved to (14, 13)
# Agent 632 at (12, 15) is moving.
# Agent 632 moved to (11, 16)
# Agent 799 at (0, 3) is moving.
# Agent 799 moved to (1, 2)
# Agent 827 at (7, 0) is moving.
# Agent 827 moved to (8, 0)
# Agent 763 at (8, 16) is moving.
# Agent 763 moved to (9, 17)
# Agent 601 at (15, 17) is moving.
# Agent 601 moved to (16, 17)
# Agent 379 at (15, 6) is moving.
# Agent 379 moved to (15, 5)
# Agent 931 at (16, 4) is moving.
# Agent 931 moved to (17, 4)
# Agent 852 at (9, 0) is moving.
# Agent 852 moved to (10, 19)
# Agent 638 at (16, 0) is moving.
# Agent 638 moved to (16, 19)
# Agent 896 at (11, 15) is moving.
# Agent 896 moved to (11, 16)
# Sheep 896 reproduced at (11, 15)
# Agent 665 at (13, 2) is moving.
# Agent 665 moved to (13, 1)
# Agent 410 at (8, 5) is moving.
# Agent 410 moved to (8, 4)
# Agent 904 at (3, 0) is moving.
# Agent 904 moved to (3, 1)
# Agent 718 at (8, 13) is moving.
# Agent 718 moved to (7, 14)
# Agent 633 at (17, 18) is moving.
# Agent 633 moved to (16, 18)
# Agent 781 at (12, 13) is moving.
# Agent 781 moved to (12, 12)
# Agent 563 at (9, 9) is moving.
# Agent 563 moved to (10, 8)
# Agent 933 at (7, 19) is moving.
# Agent 933 moved to (6, 19)
# Agent 619 at (3, 0) is moving.
# Agent 619 moved to (3, 19)
# Agent 798 at (15, 19) is moving.
# Agent 798 moved to (15, 0)
# Agent 809 at (0, 18) is moving.
# Agent 809 moved to (1, 17)
# Agent 400 at (2, 18) is moving.
# Agent 400 moved to (3, 19)
# Agent 709 at (10, 11) is moving.
# Agent 709 moved to (11, 12)
# Agent 780 at (7, 19) is moving.
# Agent 780 moved to (8, 18)
# Agent 839 at (11, 15) is moving.
# Agent 839 moved to (10, 15)
# Agent 428 at (12, 6) is moving.
# Agent 428 moved to (12, 7)
# Agent 640 at (4, 0) is moving.
# Agent 640 moved to (4, 19)
# Agent 487 at (9, 7) is moving.
# Agent 487 moved to (10, 8)
# Agent 552 at (4, 14) is moving.
# Agent 552 moved to (3, 15)
# Agent 833 at (7, 13) is moving.
# Agent 833 moved to (8, 13)
# Agent 777 at (6, 16) is moving.
# Agent 777 moved to (6, 17)
# Agent 857 at (2, 13) is moving.
# Agent 857 moved to (3, 12)
# Agent 779 at (0, 11) is moving.
# Agent 779 moved to (1, 11)
# Agent 402 at (19, 15) is moving.
# Agent 402 moved to (18, 15)
# Agent 735 at (3, 16) is moving.
# Agent 735 moved to (3, 17)
# Agent 911 at (9, 19) is moving.
# Agent 911 moved to (10, 19)
# Agent 578 at (9, 0) is moving.
# Agent 578 moved to (10, 1)
# Agent 609 at (16, 9) is moving.
# Agent 609 moved to (15, 8)
# Agent 851 at (16, 6) is moving.
# Agent 851 moved to (15, 5)
# Agent 771 at (7, 0) is moving.
# Agent 771 moved to (8, 19)
# Agent 539 at (6, 11) is moving.
# Agent 539 moved to (7, 10)
# Agent 794 at (16, 7) is moving.
# Agent 794 moved to (17, 6)
# Agent 547 at (10, 0) is moving.
# Agent 547 moved to (9, 19)
# Agent 631 at (14, 8) is moving.
# Agent 631 moved to (15, 9)
# Agent 866 at (13, 19) is moving.
# Agent 866 moved to (13, 18)
# Agent 565 at (8, 17) is moving.
# Agent 565 moved to (9, 16)
# Agent 515 at (8, 2) is moving.
# Agent 515 moved to (8, 3)
# Agent 534 at (4, 7) is moving.
# Agent 534 moved to (4, 8)

# %% [markdown]
# ### Data collector
# So far, we have tested the model by checking variables manually. This is not very efficient, and requires us to make complicated loops if we need more than just the end results. Mesa provides a class which can handle the data collection and storage. This class was already added to the model above; `DataCollector`. From the Mesa docs:
#
# "The data collector stores three categories of data: model-level variables, agent-level variables, and tables (which are a catch-all for everything else). Model- and agent-level variables are added to the data collector along with either the name of an attribute that the agents or models have, or a function for collecting some data. Model-level collection functions take a model object as an input, while agent-level collection functions take an agent object as an input. Both then return a value computed from the model or each agent at their current state. When the data collector’s collect method is called, with a model object as its argument, it applies each model-level collection function to the model, and stores the results in a dictionary, associating the current value with the current step of the model. Similarly, the method applies each agent-level collection function to each agent currently in the schedule, associating the resulting value with the step of the model, and the agent’s unique_id."
#
# Simply said, the `DataCollector` adds data to its dictionary when you call `collect()` method. We have added two functions that keep track of the amount of Sheep and Wolf to the `DataCollector` and call collect after each `step()` that the model makes.
#
# Run the following piece of code to see what happens.

# %%
# %matplotlib inline
    
model = WolfSheep()
model.run_model()

data = model.datacollector.get_model_vars_dataframe()
data.plot()
# Out:
# Agent 70 at (12, 6) is moving.
# Agent 70 moved to (11, 5)
# Agent 94 at (9, 15) is moving.
# Agent 94 moved to (10, 15)
# Agent 18 at (2, 16) is moving.
# Agent 18 moved to (3, 16)
# Agent 69 at (6, 16) is moving.
# Agent 69 moved to (6, 17)
# Agent 62 at (5, 2) is moving.
# Agent 62 moved to (4, 3)
# Agent 27 at (8, 2) is moving.
# Agent 27 moved to (8, 3)
# Agent 12 at (9, 6) is moving.
# Agent 12 moved to (9, 5)
# Agent 28 at (7, 17) is moving.
# Agent 28 moved to (8, 17)
# Agent 16 at (5, 12) is moving.
# Agent 16 moved to (4, 13)
# Agent 77 at (19, 14) is moving.
# Agent 77 moved to (18, 15)
# Agent 95 at (14, 14) is moving.
# Agent 95 moved to (14, 13)
# Agent 76 at (1, 9) is moving.
# Agent 76 moved to (1, 10)
# Agent 4 at (19, 4) is moving.
# Agent 4 moved to (0, 3)
# Agent 32 at (10, 2) is moving.
# Agent 32 moved to (10, 1)
# Agent 78 at (14, 4) is moving.
# Agent 78 moved to (13, 4)
# Agent 8 at (13, 14) is moving.
# Agent 8 moved to (12, 15)
# Agent 23 at (11, 10) is moving.
# Agent 23 moved to (12, 11)
# Agent 10 at (9, 7) is moving.
# Agent 10 moved to (9, 8)
# Agent 53 at (18, 18) is moving.
# Agent 53 moved to (19, 19)
# Agent 74 at (19, 17) is moving.
# Agent 74 moved to (0, 18)
# Agent 49 at (10, 2) is moving.
# Agent 49 moved to (11, 1)
# Agent 11 at (1, 16) is moving.
# Agent 11 moved to (2, 17)
# Agent 87 at (4, 5) is moving.
# Agent 87 moved to (5, 6)
# Sheep 87 reproduced at (5, 5)
# Agent 25 at (1, 10) is moving.
# Agent 25 moved to (0, 10)
# Agent 42 at (9, 16) is moving.
# Agent 42 moved to (10, 15)
# Agent 30 at (8, 1) is moving.
# Agent 30 moved to (8, 2)
# Agent 6 at (2, 6) is moving.
# Agent 6 moved to (1, 7)
# Agent 56 at (0, 1) is moving.
# Agent 56 moved to (19, 2)
# Agent 24 at (14, 18) is moving.
# Agent 24 moved to (15, 18)
# Agent 61 at (17, 12) is moving.
# Agent 61 moved to (17, 11)
# Agent 75 at (15, 15) is moving.
# Agent 75 moved to (16, 15)
# Agent 85 at (4, 9) is moving.
# Agent 85 moved to (5, 8)
# Agent 81 at (19, 4) is moving.
# Agent 81 moved to (18, 3)
# Agent 48 at (11, 17) is moving.
# Agent 48 moved to (12, 17)
# Agent 91 at (10, 18) is moving.
# Agent 91 moved to (9, 19)
# Agent 96 at (3, 3) is moving.
# Agent 96 moved to (4, 4)
# Agent 65 at (6, 13) is moving.
# Agent 65 moved to (7, 12)
# Agent 1 at (3, 8) is moving.
# Agent 1 moved to (4, 9)
# Agent 44 at (9, 6) is moving.
# Agent 44 moved to (8, 7)
# Agent 41 at (15, 12) is moving.
# Agent 41 moved to (14, 11)
# Agent 29 at (5, 16) is moving.
# Agent 29 moved to (5, 15)
# Agent 51 at (15, 19) is moving.
# Agent 51 moved to (16, 0)
# Agent 73 at (17, 1) is moving.
# Agent 73 moved to (18, 1)
# Agent 7 at (18, 9) is moving.
# Agent 7 moved to (19, 8)
# Agent 46 at (19, 12) is moving.
# Agent 46 moved to (18, 13)
# Agent 89 at (15, 7) is moving.
# Agent 89 moved to (14, 6)
# Agent 82 at (11, 4) is moving.
# Agent 82 moved to (12, 3)
# Sheep 82 reproduced at (12, 4)
# Agent 55 at (13, 2) is moving.
# Agent 55 moved to (12, 3)
# Agent 17 at (16, 18) is moving.
# Agent 17 moved to (16, 19)
# Agent 57 at (9, 7) is moving.
# Agent 57 moved to (9, 8)
# Agent 20 at (15, 12) is moving.
# Agent 20 moved to (15, 13)
# Agent 63 at (19, 17) is moving.
# Agent 63 moved to (18, 16)
# Sheep 63 reproduced at (17, 16)
# Agent 80 at (7, 10) is moving.
# Agent 80 moved to (7, 11)
# Agent 92 at (19, 17) is moving.
# Agent 92 moved to (0, 17)
# Agent 39 at (10, 4) is moving.
# Agent 39 moved to (11, 5)
# Agent 59 at (10, 19) is moving.
# Agent 59 moved to (9, 0)
# Agent 9 at (2, 6) is moving.
# Agent 9 moved to (2, 5)
# Agent 33 at (6, 12) is moving.
# Agent 33 moved to (5, 11)
# Agent 14 at (13, 5) is moving.
# Agent 14 moved to (14, 4)
# Agent 100 at (8, 11) is moving.
# Agent 100 moved to (9, 10)
# Agent 79 at (12, 14) is moving.
# Agent 79 moved to (13, 13)
# Agent 54 at (19, 10) is moving.
# Agent 54 moved to (18, 11)
# Agent 58 at (18, 6) is moving.
# Agent 58 moved to (17, 7)
# Agent 64 at (1, 8) is moving.
# Agent 64 moved to (1, 7)
# Agent 2 at (2, 3) is moving.
# Agent 2 moved to (3, 3)
# Sheep 2 reproduced at (4, 3)
# Agent 99 at (11, 14) is moving.
# Agent 99 moved to (10, 14)
# Agent 83 at (2, 18) is moving.
# Agent 83 moved to (1, 17)
# Agent 90 at (16, 6) is moving.
# Agent 90 moved to (17, 7)
# Agent 67 at (16, 16) is moving.
# Agent 67 moved to (16, 15)
# Agent 43 at (18, 3) is moving.
# Agent 43 moved to (18, 2)
# Agent 5 at (13, 4) is moving.
# Agent 5 moved to (14, 3)
# Agent 31 at (15, 5) is moving.
# Agent 31 moved to (16, 4)
# Agent 37 at (7, 3) is moving.
# Agent 37 moved to (8, 2)
# Agent 45 at (10, 14) is moving.
# Agent 45 moved to (9, 13)
# Agent 40 at (8, 14) is moving.
# Agent 40 moved to (9, 14)
# Agent 38 at (10, 19) is moving.
# Agent 38 moved to (10, 18)
# Sheep 38 reproduced at (10, 19)
# Agent 36 at (5, 15) is moving.
# Agent 36 moved to (5, 14)
# Agent 26 at (9, 9) is moving.
# Agent 26 moved to (8, 9)
# Agent 60 at (1, 14) is moving.
# Agent 60 moved to (0, 14)
# Sheep 60 reproduced at (0, 13)
# Agent 52 at (15, 4) is moving.
# Agent 52 moved to (16, 4)
# Agent 13 at (17, 0) is moving.
# Agent 13 moved to (16, 19)
# Agent 88 at (10, 19) is moving.
# Agent 88 moved to (9, 19)
# Agent 86 at (13, 19) is moving.
# Agent 86 moved to (13, 18)
# Agent 3 at (19, 0) is moving.
# Agent 3 moved to (0, 19)
# Agent 71 at (15, 10) is moving.
# Agent 71 moved to (16, 11)
# Agent 35 at (19, 17) is moving.
# Agent 35 moved to (19, 16)
# Agent 50 at (4, 5) is moving.
# Agent 50 moved to (4, 6)
# Agent 22 at (15, 19) is moving.
# Agent 22 moved to (16, 18)
# Agent 68 at (6, 7) is moving.
# Agent 68 moved to (5, 6)
# Agent 15 at (17, 1) is moving.
# Agent 15 moved to (16, 1)
# Agent 34 at (5, 8) is moving.
# Agent 34 moved to (5, 7)
# Agent 84 at (6, 13) is moving.
# Agent 84 moved to (5, 13)
# Agent 93 at (15, 3) is moving.
# Agent 93 moved to (14, 3)
# Agent 97 at (6, 18) is moving.
# Agent 97 moved to (6, 19)
# Agent 19 at (15, 8) is moving.
# Agent 19 moved to (14, 8)
# Agent 98 at (17, 5) is moving.
# Agent 98 moved to (16, 6)
# Agent 72 at (12, 12) is moving.
# Agent 72 moved to (11, 11)
# Agent 47 at (1, 12) is moving.
# Agent 47 moved to (2, 12)
# Agent 66 at (1, 5) is moving.
# Agent 66 moved to (2, 5)
# Agent 21 at (19, 0) is moving.
# Agent 21 moved to (18, 19)
# Agent 125 at (7, 4) is moving.
# Agent 125 moved to (8, 5)
# Agent 126 at (8, 17) is moving.
# Agent 126 moved to (8, 18)
# Agent 108 at (5, 1) is moving.
# Agent 108 moved to (6, 1)
# Agent 106 at (6, 3) is moving.
# Agent 106 moved to (7, 2)
# Agent 112 at (8, 3) is moving.
# Agent 112 moved to (9, 3)
# Agent 113 at (9, 5) is moving.
# Agent 113 moved to (10, 5)
# Agent 110 at (18, 3) is moving.
# Agent 110 moved to (19, 3)
# Agent 117 at (17, 5) is moving.
# Agent 117 moved to (18, 5)
# Agent 116 at (11, 8) is moving.
# Agent 116 moved to (10, 8)
# Wolf 116 died at (10, 8)
# Agent 122 at (10, 3) is moving.
# Agent 122 moved to (10, 2)
# Agent 109 at (2, 5) is moving.
# Agent 109 moved to (3, 5)
# Agent 124 at (8, 4) is moving.
# Agent 124 moved to (9, 5)
# Wolf 124 ate Sheep 12 at (9, 5)
# Wolf 124 reproduced at (10, 4)
# Agent 107 at (2, 10) is moving.
# Agent 107 moved to (3, 10)
# Agent 127 at (15, 10) is moving.
# Agent 127 moved to (15, 9)
# Agent 104 at (4, 9) is moving.
# Agent 104 moved to (5, 10)
# Agent 120 at (11, 9) is moving.
# Agent 120 moved to (10, 8)
# Agent 114 at (6, 2) is moving.
# Agent 114 moved to (7, 3)
# Agent 111 at (15, 5) is moving.
# Agent 111 moved to (16, 4)
# Wolf 111 ate Sheep 52 at (16, 4)
# Wolf 111 reproduced at (17, 3)
# Agent 130 at (4, 18) is moving.
# Agent 130 moved to (4, 19)
# Agent 129 at (19, 2) is moving.
# Agent 129 moved to (18, 3)
# Wolf 129 ate Sheep 81 at (18, 3)
# Wolf 129 reproduced at (17, 3)
# Agent 123 at (5, 18) is moving.
# Agent 123 moved to (4, 19)
# Agent 118 at (0, 2) is moving.
# Agent 118 moved to (1, 1)
# Agent 103 at (8, 18) is moving.
# Agent 103 moved to (9, 17)
# Agent 119 at (19, 6) is moving.
# Agent 119 moved to (18, 7)
# Agent 101 at (6, 3) is moving.
# Agent 101 moved to (6, 2)
# Agent 128 at (12, 0) is moving.
# Agent 128 moved to (12, 19)
# Agent 105 at (8, 5) is moving.
# Agent 105 moved to (7, 6)
# Agent 121 at (1, 15) is moving.
# Agent 121 moved to (2, 14)
# Agent 115 at (17, 12) is moving.
# Agent 115 moved to (18, 12)
# Agent 102 at (1, 9) is moving.
# Agent 102 moved to (1, 10)
# Wolf 102 ate Sheep 76 at (1, 10)
# Wolf 102 reproduced at (0, 9)
# Agent 97 at (6, 19) is moving.
# Agent 97 moved to (7, 0)
# Agent 82 at (12, 3) is moving.
# Agent 82 moved to (11, 3)
# Agent 79 at (13, 13) is moving.
# Agent 79 moved to (14, 14)
# Agent 64 at (1, 7) is moving.
# Agent 64 moved to (1, 8)
# Agent 69 at (6, 17) is moving.
# Agent 69 moved to (7, 16)
# Agent 36 at (5, 14) is moving.
# Agent 36 moved to (5, 13)
# Agent 131 at (5, 5) is moving.
# Agent 131 moved to (5, 4)
# Agent 132 at (12, 4) is moving.
# Agent 132 moved to (12, 5)
# Agent 67 at (16, 15) is moving.
# Agent 67 moved to (15, 16)
# Agent 136 at (0, 13) is moving.
# Agent 136 moved to (0, 12)
# Sheep 136 reproduced at (1, 13)
# Agent 1 at (4, 9) is moving.
# Agent 1 moved to (3, 8)
# Agent 7 at (19, 8) is moving.
# Agent 7 moved to (18, 7)
# Agent 95 at (14, 13) is moving.
# Agent 95 moved to (15, 12)
# Agent 98 at (16, 6) is moving.
# Agent 98 moved to (16, 5)
# Agent 19 at (14, 8) is moving.
# Agent 19 moved to (14, 7)
# Agent 32 at (10, 1) is moving.
# Agent 32 moved to (9, 2)
# Agent 87 at (5, 6) is moving.
# Agent 87 moved to (4, 5)
# Agent 58 at (17, 7) is moving.
# Agent 58 moved to (17, 6)
# Agent 55 at (12, 3) is moving.
# Agent 55 moved to (13, 4)
# Agent 14 at (14, 4) is moving.
# Agent 14 moved to (14, 5)
# Agent 72 at (11, 11) is moving.
# Agent 72 moved to (12, 12)
# Agent 135 at (10, 19) is moving.
# Agent 135 moved to (9, 19)
# Agent 51 at (16, 0) is moving.
# Agent 51 moved to (16, 1)
# Agent 3 at (0, 19) is moving.
# Agent 3 moved to (19, 0)
# Agent 91 at (9, 19) is moving.
# Agent 91 moved to (9, 18)
# Agent 40 at (9, 14) is moving.
# Agent 40 moved to (8, 14)
# Agent 78 at (13, 4) is moving.
# Agent 78 moved to (12, 4)
# Agent 30 at (8, 2) is moving.
# Agent 30 moved to (7, 1)
# Agent 37 at (8, 2) is moving.
# Agent 37 moved to (9, 1)
# Agent 16 at (4, 13) is moving.
# Agent 16 moved to (3, 14)
# Agent 68 at (5, 6) is moving.
# Agent 68 moved to (5, 5)
# Agent 100 at (9, 10) is moving.
# Agent 100 moved to (8, 10)
# Agent 77 at (18, 15) is moving.
# Agent 77 moved to (19, 14)
# Agent 39 at (11, 5) is moving.
# Agent 39 moved to (10, 5)
# Sheep 39 reproduced at (10, 6)
# Agent 86 at (13, 18) is moving.
# Agent 86 moved to (14, 18)
# Sheep 86 reproduced at (15, 17)
# Agent 45 at (9, 13) is moving.
# Agent 45 moved to (10, 12)
# Agent 62 at (4, 3) is moving.
# Agent 62 moved to (5, 3)
# Agent 47 at (2, 12) is moving.
# Agent 47 moved to (2, 13)
# Agent 44 at (8, 7) is moving.
# Agent 44 moved to (9, 6)
# Agent 35 at (19, 16) is moving.
# Agent 35 moved to (0, 15)
# Agent 41 at (14, 11) is moving.
# Agent 41 moved to (13, 10)
# Agent 9 at (2, 5) is moving.
# Agent 9 moved to (2, 4)
# Agent 10 at (9, 8) is moving.
# Agent 10 moved to (10, 7)
# Agent 54 at (18, 11) is moving.
# Agent 54 moved to (18, 10)
# Agent 28 at (8, 17) is moving.
# Agent 28 moved to (9, 16)
# Agent 18 at (3, 16) is moving.
# Agent 18 moved to (3, 15)
# Agent 50 at (4, 6) is moving.
# Agent 50 moved to (5, 5)
# Sheep 50 reproduced at (5, 6)
# Agent 93 at (14, 3) is moving.
# Agent 93 moved to (14, 4)
# Agent 63 at (18, 16) is moving.
# Agent 63 moved to (19, 15)
# Agent 31 at (16, 4) is moving.
# Agent 31 moved to (16, 5)
# Agent 85 at (5, 8) is moving.
# Agent 85 moved to (6, 7)
# Agent 60 at (0, 14) is moving.
# Agent 60 moved to (0, 15)
# Agent 24 at (15, 18) is moving.
# Agent 24 moved to (14, 17)
# Agent 66 at (2, 5) is moving.
# Agent 66 moved to (3, 6)
# Agent 17 at (16, 19) is moving.
# Agent 17 moved to (17, 0)
# Agent 48 at (12, 17) is moving.
# Agent 48 moved to (11, 16)
# Agent 29 at (5, 15) is moving.
# Agent 29 moved to (6, 15)
# Agent 133 at (17, 16) is moving.
# Agent 133 moved to (18, 16)
# Agent 43 at (18, 2) is moving.
# Agent 43 moved to (18, 3)
# Agent 21 at (18, 19) is moving.
# Agent 21 moved to (17, 0)
# Agent 13 at (16, 19) is moving.
# Agent 13 moved to (17, 18)
# Agent 46 at (18, 13) is moving.
# Agent 46 moved to (17, 13)
# Agent 90 at (17, 7) is moving.
# Agent 90 moved to (17, 6)
# Agent 22 at (16, 18) is moving.
# Agent 22 moved to (15, 19)
# Agent 23 at (12, 11) is moving.
# Agent 23 moved to (11, 11)
# Agent 34 at (5, 7) is moving.
# Agent 34 moved to (5, 6)
# Agent 2 at (3, 3) is moving.
# Agent 2 moved to (3, 2)
# Agent 61 at (17, 11) is moving.
# Agent 61 moved to (18, 12)
# Agent 49 at (11, 1) is moving.
# Agent 49 moved to (10, 0)
# Agent 99 at (10, 14) is moving.
# Agent 99 moved to (9, 14)
# Agent 88 at (9, 19) is moving.
# Agent 88 moved to (9, 0)
# Agent 73 at (18, 1) is moving.
# Agent 73 moved to (18, 2)
# Agent 15 at (16, 1) is moving.
# Agent 15 moved to (15, 1)
# Agent 71 at (16, 11) is moving.
# Agent 71 moved to (16, 12)
# Agent 96 at (4, 4) is moving.
# Agent 96 moved to (3, 3)
# Agent 11 at (2, 17) is moving.
# Agent 11 moved to (1, 18)
# Agent 94 at (10, 15) is moving.
# Agent 94 moved to (11, 15)
# Agent 134 at (4, 3) is moving.
# Agent 134 moved to (4, 4)
# Sheep 134 reproduced at (3, 3)
# Agent 75 at (16, 15) is moving.
# Agent 75 moved to (17, 15)
# Agent 25 at (0, 10) is moving.
# Agent 25 moved to (19, 10)
# Agent 26 at (8, 9) is moving.
# Agent 26 moved to (7, 10)
# Agent 65 at (7, 12) is moving.
# Agent 65 moved to (7, 13)
# Agent 4 at (0, 3) is moving.
# Agent 4 moved to (1, 4)
# Agent 80 at (7, 11) is moving.
# Agent 80 moved to (8, 12)
# Agent 6 at (1, 7) is moving.
# Agent 6 moved to (0, 6)
# Agent 57 at (9, 8) is moving.
# Agent 57 moved to (10, 7)
# Agent 33 at (5, 11) is moving.
# Agent 33 moved to (5, 10)
# Agent 5 at (14, 3) is moving.
# Agent 5 moved to (15, 4)
# Agent 74 at (0, 18) is moving.
# Agent 74 moved to (1, 17)
# Agent 42 at (10, 15) is moving.
# Agent 42 moved to (9, 14)
# Agent 83 at (1, 17) is moving.
# Agent 83 moved to (0, 18)
# Agent 20 at (15, 13) is moving.
# Agent 20 moved to (16, 14)
# Agent 89 at (14, 6) is moving.
# Agent 89 moved to (14, 5)
# Agent 53 at (19, 19) is moving.
# Agent 53 moved to (19, 0)
# Agent 84 at (5, 13) is moving.
# Agent 84 moved to (6, 14)
# Agent 56 at (19, 2) is moving.
# Agent 56 moved to (19, 1)
# Agent 38 at (10, 18) is moving.
# Agent 38 moved to (10, 17)
# Agent 27 at (8, 3) is moving.
# Agent 27 moved to (7, 2)
# Agent 59 at (9, 0) is moving.
# Agent 59 moved to (8, 0)
# Agent 92 at (0, 17) is moving.
# Agent 92 moved to (1, 18)
# Agent 70 at (11, 5) is moving.
# Agent 70 moved to (10, 6)
# Agent 8 at (12, 15) is moving.
# Agent 8 moved to (13, 14)
# Agent 113 at (10, 5) is moving.
# Agent 113 moved to (9, 4)
# Agent 140 at (0, 9) is moving.
# Agent 140 moved to (19, 10)
# Wolf 140 ate Sheep 25 at (19, 10)
# Wolf 140 reproduced at (18, 9)
# Agent 103 at (9, 17) is moving.
# Agent 103 moved to (10, 18)
# Agent 122 at (10, 2) is moving.
# Agent 122 moved to (9, 1)
# Wolf 122 ate Sheep 37 at (9, 1)
# Wolf 122 reproduced at (8, 1)
# Agent 107 at (3, 10) is moving.
# Agent 107 moved to (3, 9)
# Agent 129 at (18, 3) is moving.
# Agent 129 moved to (19, 2)
# Agent 124 at (9, 5) is moving.
# Agent 124 moved to (8, 4)
# Agent 110 at (19, 3) is moving.
# Agent 110 moved to (18, 2)
# Wolf 110 ate Sheep 73 at (18, 2)
# Wolf 110 reproduced at (19, 2)
# Agent 119 at (18, 7) is moving.
# Agent 119 moved to (19, 7)
# Agent 138 at (17, 3) is moving.
# Agent 138 moved to (18, 4)
# Agent 126 at (8, 18) is moving.
# Agent 126 moved to (9, 19)
# Wolf 126 ate Sheep 135 at (9, 19)
# Wolf 126 reproduced at (9, 18)
# Agent 114 at (7, 3) is moving.
# Agent 114 moved to (8, 2)
# Agent 115 at (18, 12) is moving.
# Agent 115 moved to (18, 13)
# Agent 120 at (10, 8) is moving.
# Agent 120 moved to (10, 7)
# Wolf 120 ate Sheep 57 at (10, 7)
# Wolf 120 reproduced at (9, 8)
# Agent 112 at (9, 3) is moving.
# Agent 112 moved to (8, 2)
# Agent 128 at (12, 19) is moving.
# Agent 128 moved to (12, 0)
# Agent 137 at (10, 4) is moving.
# Agent 137 moved to (10, 3)
# Agent 139 at (17, 3) is moving.
# Agent 139 moved to (16, 3)
# Agent 102 at (1, 10) is moving.
# Agent 102 moved to (2, 11)
# Agent 123 at (4, 19) is moving.
# Agent 123 moved to (4, 18)
# Agent 101 at (6, 2) is moving.
# Agent 101 moved to (5, 1)
# Agent 111 at (16, 4) is moving.
# Agent 111 moved to (17, 4)
# Agent 130 at (4, 19) is moving.
# Agent 130 moved to (5, 0)
# Agent 105 at (7, 6) is moving.
# Agent 105 moved to (8, 6)
# Agent 121 at (2, 14) is moving.
# Agent 121 moved to (3, 13)
# Wolf 121 died at (3, 13)
# Agent 109 at (3, 5) is moving.
# Agent 109 moved to (4, 6)
# Agent 117 at (18, 5) is moving.
# Agent 117 moved to (18, 4)
# Agent 106 at (7, 2) is moving.
# Agent 106 moved to (6, 1)
# Agent 118 at (1, 1) is moving.
# Agent 118 moved to (0, 1)
# Agent 125 at (8, 5) is moving.
# Agent 125 moved to (7, 4)
# Agent 108 at (6, 1) is moving.
# Agent 108 moved to (5, 1)
# Agent 127 at (15, 9) is moving.
# Agent 127 moved to (16, 10)
# Agent 104 at (5, 10) is moving.
# Agent 104 moved to (5, 11)
# Agent 72 at (12, 12) is moving.
# Agent 72 moved to (11, 13)
# Sheep 72 reproduced at (12, 14)
# Agent 47 at (2, 13) is moving.
# Agent 47 moved to (2, 14)
# Agent 91 at (9, 18) is moving.
# Agent 91 moved to (8, 17)
# Agent 63 at (19, 15) is moving.
# Agent 63 moved to (19, 14)
# Agent 39 at (10, 5) is moving.
# Agent 39 moved to (11, 5)
# Agent 15 at (15, 1) is moving.
# Agent 15 moved to (15, 2)
# Agent 134 at (4, 4) is moving.
# Agent 134 moved to (4, 3)
# Agent 23 at (11, 11) is moving.
# Agent 23 moved to (12, 10)
# Agent 87 at (4, 5) is moving.
# Agent 87 moved to (4, 6)
# Agent 40 at (8, 14) is moving.
# Agent 40 moved to (7, 14)
# Agent 89 at (14, 5) is moving.
# Agent 89 moved to (14, 4)
# Agent 145 at (3, 3) is moving.
# Agent 145 moved to (2, 3)
# Agent 58 at (17, 6) is moving.
# Agent 58 moved to (16, 7)
# Agent 131 at (5, 4) is moving.
# Agent 131 moved to (4, 5)
# Agent 17 at (17, 0) is moving.
# Agent 17 moved to (16, 0)
# Agent 82 at (11, 3) is moving.
# Agent 82 moved to (11, 4)
# Agent 132 at (12, 5) is moving.
# Agent 132 moved to (13, 4)
# Agent 96 at (3, 3) is moving.
# Agent 96 moved to (2, 4)
# Agent 85 at (6, 7) is moving.
# Agent 85 moved to (5, 6)
# Agent 79 at (14, 14) is moving.
# Agent 79 moved to (13, 15)
# Sheep 79 reproduced at (14, 16)
# Agent 95 at (15, 12) is moving.
# Agent 95 moved to (16, 12)
# Agent 56 at (19, 1) is moving.
# Agent 56 moved to (18, 0)
# Agent 11 at (1, 18) is moving.
# Agent 11 moved to (1, 19)
# Agent 5 at (15, 4) is moving.
# Agent 5 moved to (15, 3)
# Agent 41 at (13, 10) is moving.
# Agent 41 moved to (12, 10)
# Agent 133 at (18, 16) is moving.
# Agent 133 moved to (19, 17)
# Agent 10 at (10, 7) is moving.
# Agent 10 moved to (11, 8)
# Agent 34 at (5, 6) is moving.
# Agent 34 moved to (5, 7)
# Agent 13 at (17, 18) is moving.
# Agent 13 moved to (16, 19)
# Agent 98 at (16, 5) is moving.
# Agent 98 moved to (17, 4)
# Sheep 98 reproduced at (18, 4)
# Agent 141 at (1, 13) is moving.
# Agent 141 moved to (0, 14)
# Agent 33 at (5, 10) is moving.
# Agent 33 moved to (4, 10)
# Agent 74 at (1, 17) is moving.
# Agent 74 moved to (1, 18)
# Agent 28 at (9, 16) is moving.
# Agent 28 moved to (10, 15)
# Agent 49 at (10, 0) is moving.
# Agent 49 moved to (11, 1)
# Agent 16 at (3, 14) is moving.
# Agent 16 moved to (2, 13)
# Agent 92 at (1, 18) is moving.
# Agent 92 moved to (0, 19)
# Agent 144 at (5, 6) is moving.
# Agent 144 moved to (5, 7)
# Agent 24 at (14, 17) is moving.
# Agent 24 moved to (13, 16)
# Agent 65 at (7, 13) is moving.
# Agent 65 moved to (7, 14)
# Agent 30 at (7, 1) is moving.
# Agent 30 moved to (6, 1)
# Agent 26 at (7, 10) is moving.
# Agent 26 moved to (8, 11)
# Agent 21 at (17, 0) is moving.
# Agent 21 moved to (16, 0)
# Agent 29 at (6, 15) is moving.
# Agent 29 moved to (6, 14)
# Agent 59 at (8, 0) is moving.
# Agent 59 moved to (8, 19)
# Agent 94 at (11, 15) is moving.
# Agent 94 moved to (12, 15)
# Agent 44 at (9, 6) is moving.
# Agent 44 moved to (9, 7)
# Agent 69 at (7, 16) is moving.
# Agent 69 moved to (7, 17)
# Agent 61 at (18, 12) is moving.
# Agent 61 moved to (17, 13)
# Sheep 61 reproduced at (17, 14)
# Agent 54 at (18, 10) is moving.
# Agent 54 moved to (18, 9)
# Agent 60 at (0, 15) is moving.
# Agent 60 moved to (0, 16)
# Agent 70 at (10, 6) is moving.
# Agent 70 moved to (9, 7)
# Agent 48 at (11, 16) is moving.
# Agent 48 moved to (10, 17)
# Agent 27 at (7, 2) is moving.
# Agent 27 moved to (6, 3)
# Agent 43 at (18, 3) is moving.
# Agent 43 moved to (19, 3)
# Agent 19 at (14, 7) is moving.
# Agent 19 moved to (14, 6)
# Sheep 19 reproduced at (13, 6)
# Agent 99 at (9, 14) is moving.
# Agent 99 moved to (8, 14)
# Agent 83 at (0, 18) is moving.
# Agent 83 moved to (19, 17)
# Agent 66 at (3, 6) is moving.
# Agent 66 moved to (4, 5)
# Agent 143 at (15, 17) is moving.
# Agent 143 moved to (16, 16)
# Agent 86 at (14, 18) is moving.
# Agent 86 moved to (13, 17)
# Sheep 86 reproduced at (14, 16)
# Agent 68 at (5, 5) is moving.
# Agent 68 moved to (4, 5)
# Agent 42 at (9, 14) is moving.
# Agent 42 moved to (10, 15)
# Agent 9 at (2, 4) is moving.
# Agent 9 moved to (2, 5)
# Agent 71 at (16, 12) is moving.
# Agent 71 moved to (16, 11)
# Agent 4 at (1, 4) is moving.
# Agent 4 moved to (0, 4)
# Agent 93 at (14, 4) is moving.
# Agent 93 moved to (13, 5)
# Agent 36 at (5, 13) is moving.
# Agent 36 moved to (4, 13)
# Agent 8 at (13, 14) is moving.
# Agent 8 moved to (14, 15)
# Agent 62 at (5, 3) is moving.
# Agent 62 moved to (4, 2)
# Agent 3 at (19, 0) is moving.
# Agent 3 moved to (18, 0)
# Agent 2 at (3, 2) is moving.
# Agent 2 moved to (3, 1)
# Agent 84 at (6, 14) is moving.
# Agent 84 moved to (7, 13)
# Agent 55 at (13, 4) is moving.
# Agent 55 moved to (12, 5)
# Agent 7 at (18, 7) is moving.
# Agent 7 moved to (19, 7)
# Agent 32 at (9, 2) is moving.
# Agent 32 moved to (10, 2)
# Agent 35 at (0, 15) is moving.
# Agent 35 moved to (1, 14)
# Agent 142 at (10, 6) is moving.
# Agent 142 moved to (11, 7)
# Agent 136 at (0, 12) is moving.
# Agent 136 moved to (1, 12)
# Agent 53 at (19, 0) is moving.
# Agent 53 moved to (0, 1)
# Agent 64 at (1, 8) is moving.
# Agent 64 moved to (2, 8)
# Agent 75 at (17, 15) is moving.
# Agent 75 moved to (18, 15)
# Agent 45 at (10, 12) is moving.
# Agent 45 moved to (9, 11)
# Agent 100 at (8, 10) is moving.
# Agent 100 moved to (7, 9)
# Agent 67 at (15, 16) is moving.
# Agent 67 moved to (15, 17)
# Agent 18 at (3, 15) is moving.
# Agent 18 moved to (2, 15)
# Agent 1 at (3, 8) is moving.
# Agent 1 moved to (4, 8)
# Agent 6 at (0, 6) is moving.
# Agent 6 moved to (19, 7)
# Agent 50 at (5, 5) is moving.
# Agent 50 moved to (4, 5)
# Sheep 50 reproduced at (5, 5)
# Agent 90 at (17, 6) is moving.
# Agent 90 moved to (17, 7)
# Agent 78 at (12, 4) is moving.
# Agent 78 moved to (12, 5)
# Agent 14 at (14, 5) is moving.
# Agent 14 moved to (13, 4)
# Agent 31 at (16, 5) is moving.
# Agent 31 moved to (16, 6)
# Agent 51 at (16, 1) is moving.
# Agent 51 moved to (15, 1)
# Agent 88 at (9, 0) is moving.
# Agent 88 moved to (10, 1)
# Agent 46 at (17, 13) is moving.
# Agent 46 moved to (16, 12)
# Agent 77 at (19, 14) is moving.
# Agent 77 moved to (18, 13)
# Agent 22 at (15, 19) is moving.
# Agent 22 moved to (16, 19)
# Agent 20 at (16, 14) is moving.
# Agent 20 moved to (15, 15)
# Agent 80 at (8, 12) is moving.
# Agent 80 moved to (9, 12)
# Agent 38 at (10, 17) is moving.
# Agent 38 moved to (9, 17)
# Agent 97 at (7, 0) is moving.
# Agent 97 moved to (7, 19)
# Agent 105 at (8, 6) is moving.
# Agent 105 moved to (7, 6)
# Agent 149 at (9, 18) is moving.
# Agent 149 moved to (9, 17)
# Wolf 149 ate Sheep 38 at (9, 17)
# Wolf 149 reproduced at (9, 16)
# Agent 147 at (8, 1) is moving.
# Agent 147 moved to (8, 2)
# Wolf 147 died at (8, 2)
# Agent 137 at (10, 3) is moving.
# Agent 137 moved to (10, 4)
# Agent 110 at (18, 2) is moving.
# Agent 110 moved to (17, 3)
# Agent 140 at (19, 10) is moving.
# Agent 140 moved to (0, 10)
# Agent 112 at (8, 2) is moving.
# Agent 112 moved to (7, 1)
# Agent 117 at (18, 4) is moving.
# Agent 117 moved to (17, 5)
# Agent 126 at (9, 19) is moving.
# Agent 126 moved to (9, 18)
# Agent 106 at (6, 1) is moving.
# Agent 106 moved to (7, 1)
# Agent 119 at (19, 7) is moving.
# Agent 119 moved to (0, 8)
# Agent 102 at (2, 11) is moving.
# Agent 102 moved to (1, 12)
# Wolf 102 ate Sheep 136 at (1, 12)
# Wolf 102 reproduced at (2, 11)
# Agent 129 at (19, 2) is moving.
# Agent 129 moved to (0, 3)
# Agent 146 at (18, 9) is moving.
# Agent 146 moved to (17, 8)
# Agent 150 at (9, 8) is moving.
# Agent 150 moved to (8, 9)
# Agent 122 at (9, 1) is moving.
# Agent 122 moved to (9, 0)
# Agent 124 at (8, 4) is moving.
# Agent 124 moved to (8, 5)
# Agent 139 at (16, 3) is moving.
# Agent 139 moved to (16, 2)
# Agent 128 at (12, 0) is moving.
# Agent 128 moved to (13, 1)
# Agent 125 at (7, 4) is moving.
# Agent 125 moved to (8, 4)
# Agent 111 at (17, 4) is moving.
# Agent 111 moved to (17, 3)
# Agent 115 at (18, 13) is moving.
# Agent 115 moved to (17, 14)
# Wolf 115 ate Sheep 154 at (17, 14)
# Wolf 115 reproduced at (16, 15)
# Wolf 115 died at (17, 14)
# Agent 148 at (19, 2) is moving.
# Agent 148 moved to (19, 1)
# Agent 138 at (18, 4) is moving.
# Agent 138 moved to (19, 4)
# Agent 113 at (9, 4) is moving.
# Agent 113 moved to (8, 4)
# Agent 114 at (8, 2) is moving.
# Agent 114 moved to (9, 1)
# Agent 109 at (4, 6) is moving.
# Agent 109 moved to (5, 5)
# Wolf 109 ate Sheep 157 at (5, 5)
# Wolf 109 reproduced at (5, 4)
# Agent 101 at (5, 1) is moving.
# Agent 101 moved to (6, 2)
# Agent 123 at (4, 18) is moving.
# Agent 123 moved to (5, 18)
# Agent 104 at (5, 11) is moving.
# Agent 104 moved to (6, 12)
# Agent 127 at (16, 10) is moving.
# Agent 127 moved to (17, 10)
# Agent 120 at (10, 7) is moving.
# Agent 120 moved to (11, 7)
# Wolf 120 ate Sheep 142 at (11, 7)
# Wolf 120 reproduced at (10, 8)
# Agent 118 at (0, 1) is moving.
# Agent 118 moved to (19, 2)
# Agent 130 at (5, 0) is moving.
# Agent 130 moved to (6, 1)
# Wolf 130 ate Sheep 30 at (6, 1)
# Wolf 130 reproduced at (6, 0)
# Agent 108 at (5, 1) is moving.
# Agent 108 moved to (6, 1)
# Agent 107 at (3, 9) is moving.
# Agent 107 moved to (2, 8)
# Wolf 107 ate Sheep 64 at (2, 8)
# Wolf 107 reproduced at (3, 7)
# Wolf 107 died at (2, 8)
# Agent 103 at (10, 18) is moving.
# Agent 103 moved to (9, 19)
# Agent 35 at (1, 14) is moving.
# Agent 35 moved to (1, 13)
# Agent 21 at (16, 0) is moving.
# Agent 21 moved to (17, 0)
# Agent 31 at (16, 6) is moving.
# Agent 31 moved to (16, 5)
# Agent 6 at (19, 7) is moving.
# Agent 6 moved to (0, 7)
# Agent 85 at (5, 6) is moving.
# Agent 85 moved to (5, 7)
# Agent 45 at (9, 11) is moving.
# Agent 45 moved to (9, 12)
# Agent 59 at (8, 19) is moving.
# Agent 59 moved to (7, 18)
# Agent 78 at (12, 5) is moving.
# Agent 78 moved to (12, 6)
# Agent 23 at (12, 10) is moving.
# Agent 23 moved to (11, 9)
# Agent 100 at (7, 9) is moving.
# Agent 100 moved to (8, 8)
# Agent 28 at (10, 15) is moving.
# Agent 28 moved to (10, 16)
# Agent 53 at (0, 1) is moving.
# Agent 53 moved to (0, 2)
# Agent 74 at (1, 18) is moving.
# Agent 74 moved to (0, 17)
# Agent 70 at (9, 7) is moving.
# Agent 70 moved to (10, 7)
# Agent 86 at (13, 17) is moving.
# Agent 86 moved to (13, 16)
# Sheep 86 reproduced at (14, 16)
# Agent 77 at (18, 13) is moving.
# Agent 77 moved to (17, 13)
# Agent 98 at (17, 4) is moving.
# Agent 98 moved to (18, 5)
# Agent 75 at (18, 15) is moving.
# Agent 75 moved to (17, 14)
# Agent 79 at (13, 15) is moving.
# Agent 79 moved to (12, 16)
# Agent 65 at (7, 14) is moving.
# Agent 65 moved to (8, 13)
# Agent 13 at (16, 19) is moving.
# Agent 13 moved to (17, 19)
# Agent 46 at (16, 12) is moving.
# Agent 46 moved to (17, 13)
# Agent 82 at (11, 4) is moving.
# Agent 82 moved to (10, 5)
# Agent 5 at (15, 3) is moving.
# Agent 5 moved to (16, 2)
# Agent 87 at (4, 6) is moving.
# Agent 87 moved to (5, 5)
# Agent 11 at (1, 19) is moving.
# Agent 11 moved to (1, 18)
# Agent 143 at (16, 16) is moving.
# Agent 143 moved to (17, 16)
# Agent 36 at (4, 13) is moving.
# Agent 36 moved to (3, 13)
# Agent 20 at (15, 15) is moving.
# Agent 20 moved to (16, 14)
# Agent 91 at (8, 17) is moving.
# Agent 91 moved to (9, 17)
# Agent 80 at (9, 12) is moving.
# Agent 80 moved to (8, 12)
# Agent 40 at (7, 14) is moving.
# Agent 40 moved to (8, 15)
# Agent 7 at (19, 7) is moving.
# Agent 7 moved to (19, 8)
# Agent 15 at (15, 2) is moving.
# Agent 15 moved to (16, 1)
# Agent 47 at (2, 14) is moving.
# Agent 47 moved to (3, 13)
# Sheep 47 reproduced at (2, 13)
# Agent 18 at (2, 15) is moving.
# Agent 18 moved to (1, 15)
# Agent 43 at (19, 3) is moving.
# Agent 43 moved to (0, 3)
# Agent 3 at (18, 0) is moving.
# Agent 3 moved to (17, 19)
# Agent 67 at (15, 17) is moving.
# Agent 67 moved to (14, 16)
# Agent 83 at (19, 17) is moving.
# Agent 83 moved to (18, 17)
# Agent 33 at (4, 10) is moving.
# Agent 33 moved to (4, 9)
# Sheep 33 reproduced at (3, 8)
# Agent 32 at (10, 2) is moving.
# Agent 32 moved to (11, 3)
# Agent 26 at (8, 11) is moving.
# Agent 26 moved to (8, 10)
# Agent 134 at (4, 3) is moving.
# Agent 134 moved to (4, 2)
# Agent 27 at (6, 3) is moving.
# Agent 27 moved to (5, 3)
# Agent 90 at (17, 7) is moving.
# Agent 90 moved to (16, 7)
# Agent 42 at (10, 15) is moving.
# Agent 42 moved to (11, 16)
# Agent 1 at (4, 8) is moving.
# Agent 1 moved to (4, 7)
# Sheep 1 reproduced at (5, 6)
# Agent 39 at (11, 5) is moving.
# Agent 39 moved to (10, 5)
# Agent 9 at (2, 5) is moving.
# Agent 9 moved to (3, 4)
# Agent 49 at (11, 1) is moving.
# Agent 49 moved to (12, 1)
# Agent 72 at (11, 13) is moving.
# Agent 72 moved to (12, 13)
# Agent 94 at (12, 15) is moving.
# Agent 94 moved to (11, 15)
# Agent 62 at (4, 2) is moving.
# Agent 62 moved to (5, 2)
# Agent 145 at (2, 3) is moving.
# Agent 145 moved to (1, 2)
# Agent 97 at (7, 19) is moving.
# Agent 97 moved to (6, 18)
# Agent 58 at (16, 7) is moving.
# Agent 58 moved to (16, 8)
# Agent 151 at (12, 14) is moving.
# Agent 151 moved to (12, 13)
# Agent 22 at (16, 19) is moving.
# Agent 22 moved to (16, 18)
# Agent 131 at (4, 5) is moving.
# Agent 131 moved to (3, 6)
# Agent 93 at (13, 5) is moving.
# Agent 93 moved to (12, 4)
# Agent 155 at (13, 6) is moving.
# Agent 155 moved to (12, 7)
# Agent 17 at (16, 0) is moving.
# Agent 17 moved to (17, 1)
# Agent 29 at (6, 14) is moving.
# Agent 29 moved to (7, 13)
# Agent 89 at (14, 4) is moving.
# Agent 89 moved to (13, 3)
# Agent 10 at (11, 8) is moving.
# Agent 10 moved to (12, 8)
# Agent 133 at (19, 17) is moving.
# Agent 133 moved to (18, 18)
# Agent 55 at (12, 5) is moving.
# Agent 55 moved to (13, 6)
# Agent 132 at (13, 4) is moving.
# Agent 132 moved to (13, 3)
# Agent 68 at (4, 5) is moving.
# Agent 68 moved to (4, 4)
# Agent 84 at (7, 13) is moving.
# Agent 84 moved to (6, 12)
# Agent 50 at (4, 5) is moving.
# Agent 50 moved to (4, 6)
# Agent 66 at (4, 5) is moving.
# Agent 66 moved to (5, 5)
# Agent 95 at (16, 12) is moving.
# Agent 95 moved to (17, 11)
# Agent 16 at (2, 13) is moving.
# Agent 16 moved to (1, 14)
# Agent 99 at (8, 14) is moving.
# Agent 99 moved to (9, 13)
# Agent 4 at (0, 4) is moving.
# Agent 4 moved to (19, 4)
# Agent 60 at (0, 16) is moving.
# Agent 60 moved to (19, 17)
# Sheep 60 reproduced at (0, 18)
# Agent 48 at (10, 17) is moving.
# Agent 48 moved to (9, 16)
# Sheep 48 reproduced at (8, 15)
# Agent 96 at (2, 4) is moving.
# Agent 96 moved to (3, 3)
# Agent 24 at (13, 16) is moving.
# Agent 24 moved to (14, 15)
# Agent 8 at (14, 15) is moving.
# Agent 8 moved to (15, 14)
# Agent 41 at (12, 10) is moving.
# Agent 41 moved to (11, 10)
# Agent 54 at (18, 9) is moving.
# Agent 54 moved to (18, 8)
# Agent 61 at (17, 13) is moving.
# Agent 61 moved to (16, 12)
# Agent 56 at (18, 0) is moving.
# Agent 56 moved to (19, 19)
# Agent 152 at (14, 16) is moving.
# Agent 152 moved to (15, 17)
# Agent 44 at (9, 7) is moving.
# Agent 44 moved to (8, 6)
# Agent 153 at (18, 4) is moving.
# Agent 153 moved to (19, 3)
# Agent 141 at (0, 14) is moving.
# Agent 141 moved to (1, 15)
# Agent 156 at (14, 16) is moving.
# Agent 156 moved to (15, 17)
# Agent 19 at (14, 6) is moving.
# Agent 19 moved to (15, 6)
# Agent 34 at (5, 7) is moving.
# Agent 34 moved to (5, 6)
# Agent 63 at (19, 14) is moving.
# Agent 63 moved to (19, 15)
# Agent 88 at (10, 1) is moving.
# Agent 88 moved to (9, 1)
# Agent 144 at (5, 7) is moving.
# Agent 144 moved to (4, 6)
# Agent 14 at (13, 4) is moving.
# Agent 14 moved to (13, 3)
# Agent 71 at (16, 11) is moving.
# Agent 71 moved to (17, 10)
# Agent 51 at (15, 1) is moving.
# Agent 51 moved to (15, 0)
# Agent 69 at (7, 17) is moving.
# Agent 69 moved to (6, 18)
# Agent 92 at (0, 19) is moving.
# Agent 92 moved to (19, 19)
# Sheep 92 reproduced at (18, 18)
# Agent 2 at (3, 1) is moving.
# Agent 2 moved to (2, 1)
# Agent 164 at (3, 7) is moving.
# Agent 164 moved to (4, 7)
# Wolf 164 ate Sheep 1 at (4, 7)
# Wolf 164 reproduced at (5, 6)
# Agent 123 at (5, 18) is moving.
# Agent 123 moved to (5, 19)
# Agent 161 at (5, 4) is moving.
# Agent 161 moved to (6, 5)
# Agent 158 at (9, 16) is moving.
# Agent 158 moved to (10, 17)
# Agent 117 at (17, 5) is moving.
# Agent 117 moved to (16, 6)
# Agent 105 at (7, 6) is moving.
# Agent 105 moved to (8, 5)
# Wolf 105 died at (8, 5)
# Agent 122 at (9, 0) is moving.
# Agent 122 moved to (8, 1)
# Agent 114 at (9, 1) is moving.
# Agent 114 moved to (8, 2)
# Agent 113 at (8, 4) is moving.
# Agent 113 moved to (9, 5)
# Agent 162 at (10, 8) is moving.
# Agent 162 moved to (10, 9)
# Agent 160 at (16, 15) is moving.
# Agent 160 moved to (17, 15)
# Agent 150 at (8, 9) is moving.
# Agent 150 moved to (8, 8)
# Wolf 150 ate Sheep 100 at (8, 8)
# Wolf 150 reproduced at (9, 8)
# Agent 138 at (19, 4) is moving.
# Agent 138 moved to (18, 3)
# Agent 163 at (6, 0) is moving.
# Agent 163 moved to (6, 19)
# Agent 140 at (0, 10) is moving.
# Agent 140 moved to (0, 9)
# Agent 118 at (19, 2) is moving.
# Agent 118 moved to (18, 3)
# Agent 102 at (1, 12) is moving.
# Agent 102 moved to (2, 12)
# Agent 104 at (6, 12) is moving.
# Agent 104 moved to (6, 11)
# Agent 137 at (10, 4) is moving.
# Agent 137 moved to (11, 4)
# Agent 120 at (11, 7) is moving.
# Agent 120 moved to (12, 6)
# Wolf 120 ate Sheep 78 at (12, 6)
# Wolf 120 reproduced at (13, 7)
# Agent 159 at (2, 11) is moving.
# Agent 159 moved to (3, 12)
# Agent 127 at (17, 10) is moving.
# Agent 127 moved to (18, 9)
# Agent 108 at (6, 1) is moving.
# Agent 108 moved to (5, 0)
# Agent 106 at (7, 1) is moving.
# Agent 106 moved to (6, 1)
# Agent 124 at (8, 5) is moving.
# Agent 124 moved to (7, 6)
# Agent 129 at (0, 3) is moving.
# Agent 129 moved to (0, 2)
# Wolf 129 ate Sheep 53 at (0, 2)
# Wolf 129 reproduced at (0, 1)
# Agent 101 at (6, 2) is moving.
# Agent 101 moved to (6, 1)
# Agent 130 at (6, 1) is moving.
# Agent 130 moved to (7, 2)
# Agent 110 at (17, 3) is moving.
# Agent 110 moved to (17, 2)
# Agent 149 at (9, 17) is moving.
# Agent 149 moved to (10, 18)
# Agent 146 at (17, 8) is moving.
# Agent 146 moved to (16, 9)
# Agent 109 at (5, 5) is moving.
# Agent 109 moved to (5, 4)
# Agent 125 at (8, 4) is moving.
# Agent 125 moved to (9, 5)
# Agent 126 at (9, 18) is moving.
# Agent 126 moved to (9, 17)
# Wolf 126 ate Sheep 91 at (9, 17)
# Wolf 126 reproduced at (10, 16)
# Agent 139 at (16, 2) is moving.
# Agent 139 moved to (16, 1)
# Wolf 139 ate Sheep 15 at (16, 1)
# Wolf 139 reproduced at (17, 0)
# Agent 103 at (9, 19) is moving.
# Agent 103 moved to (8, 0)
# Agent 148 at (19, 1) is moving.
# Agent 148 moved to (18, 2)
# Agent 112 at (7, 1) is moving.
# Agent 112 moved to (8, 0)
# Agent 111 at (17, 3) is moving.
# Agent 111 moved to (16, 3)
# Agent 119 at (0, 8) is moving.
# Agent 119 moved to (1, 7)
# Agent 128 at (13, 1) is moving.
# Agent 128 moved to (14, 0)
# Agent 35 at (1, 13) is moving.
# Agent 35 moved to (1, 12)
# Agent 82 at (10, 5) is moving.
# Agent 82 moved to (10, 6)
# Agent 132 at (13, 3) is moving.
# Agent 132 moved to (13, 4)
# Agent 4 at (19, 4) is moving.
# Agent 4 moved to (18, 5)
# Agent 56 at (19, 19) is moving.
# Agent 56 moved to (19, 0)
# Agent 51 at (15, 0) is moving.
# Agent 51 moved to (16, 1)
# Agent 60 at (19, 17) is moving.
# Agent 60 moved to (18, 17)
# Agent 11 at (1, 18) is moving.
# Agent 11 moved to (1, 17)
# Agent 33 at (4, 9) is moving.
# Agent 33 moved to (5, 10)
# Agent 31 at (16, 5) is moving.
# Agent 31 moved to (16, 6)
# Agent 54 at (18, 8) is moving.
# Agent 54 moved to (19, 8)
# Agent 90 at (16, 7) is moving.
# Agent 90 moved to (17, 7)
# Agent 171 at (18, 18) is moving.
# Agent 171 moved to (17, 18)
# Agent 93 at (12, 4) is moving.
# Agent 93 moved to (13, 4)
# Agent 94 at (11, 15) is moving.
# Agent 94 moved to (12, 15)
# Agent 5 at (16, 2) is moving.
# Agent 5 moved to (15, 3)
# Agent 92 at (19, 19) is moving.
# Agent 92 moved to (19, 18)
# Agent 79 at (12, 16) is moving.
# Agent 79 moved to (13, 17)
# Agent 61 at (16, 12) is moving.
# Agent 61 moved to (15, 11)
# Agent 144 at (4, 6) is moving.
# Agent 144 moved to (4, 7)
# Agent 40 at (8, 15) is moving.
# Agent 40 moved to (7, 14)
# Agent 62 at (5, 2) is moving.
# Agent 62 moved to (5, 1)
# Agent 131 at (3, 6) is moving.
# Agent 131 moved to (2, 5)
# Agent 14 at (13, 3) is moving.
# Agent 14 moved to (12, 2)
# Agent 17 at (17, 1) is moving.
# Agent 17 moved to (17, 0)
# Agent 9 at (3, 4) is moving.
# Agent 9 moved to (3, 3)
# Agent 152 at (15, 17) is moving.
# Agent 152 moved to (15, 16)
# Agent 74 at (0, 17) is moving.
# Agent 74 moved to (0, 18)
# Agent 21 at (17, 0) is moving.
# Agent 21 moved to (16, 0)
# Agent 99 at (9, 13) is moving.
# Agent 99 moved to (10, 14)
# Agent 59 at (7, 18) is moving.
# Agent 59 moved to (6, 18)
# Agent 47 at (3, 13) is moving.
# Agent 47 moved to (2, 13)
# Agent 39 at (10, 5) is moving.
# Agent 39 moved to (10, 6)
# Agent 83 at (18, 17) is moving.
# Agent 83 moved to (19, 17)
# Agent 87 at (5, 5) is moving.
# Agent 87 moved to (4, 5)
# Agent 86 at (13, 16) is moving.
# Agent 86 moved to (12, 17)
# Agent 45 at (9, 12) is moving.
# Agent 45 moved to (9, 13)
# Agent 169 at (0, 18) is moving.
# Agent 169 moved to (0, 19)
# Agent 16 at (1, 14) is moving.
# Agent 16 moved to (0, 15)
# Agent 29 at (7, 13) is moving.
# Agent 29 moved to (6, 12)
# Agent 168 at (5, 6) is moving.
# Agent 168 moved to (5, 7)
# Agent 6 at (0, 7) is moving.
# Agent 6 moved to (0, 6)
# Agent 96 at (3, 3) is moving.
# Agent 96 moved to (2, 3)
# Agent 18 at (1, 15) is moving.
# Agent 18 moved to (2, 14)
# Agent 88 at (9, 1) is moving.
# Agent 88 moved to (8, 0)
# Agent 24 at (14, 15) is moving.
# Agent 24 moved to (13, 16)
# Agent 66 at (5, 5) is moving.
# Agent 66 moved to (6, 5)
# Agent 34 at (5, 6) is moving.
# Agent 34 moved to (4, 5)
# Sheep 34 reproduced at (5, 4)
# Agent 69 at (6, 18) is moving.
# Agent 69 moved to (7, 17)
# Agent 7 at (19, 8) is moving.
# Agent 7 moved to (19, 9)
# Agent 65 at (8, 13) is moving.
# Agent 65 moved to (8, 12)
# Agent 80 at (8, 12) is moving.
# Agent 80 moved to (7, 13)
# Agent 44 at (8, 6) is moving.
# Agent 44 moved to (9, 6)
# Agent 95 at (17, 11) is moving.
# Agent 95 moved to (18, 10)
# Agent 134 at (4, 2) is moving.
# Agent 134 moved to (4, 3)
# Agent 8 at (15, 14) is moving.
# Agent 8 moved to (16, 15)
# Agent 141 at (1, 15) is moving.
# Agent 141 moved to (1, 16)
# Agent 41 at (11, 10) is moving.
# Agent 41 moved to (12, 11)
# Agent 151 at (12, 13) is moving.
# Agent 151 moved to (12, 14)
# Agent 167 at (3, 8) is moving.
# Agent 167 moved to (2, 8)
# Agent 153 at (19, 3) is moving.
# Agent 153 moved to (0, 4)
# Agent 85 at (5, 7) is moving.
# Agent 85 moved to (4, 6)
# Agent 22 at (16, 18) is moving.
# Agent 22 moved to (15, 18)
# Agent 77 at (17, 13) is moving.
# Agent 77 moved to (18, 12)
# Agent 155 at (12, 7) is moving.
# Agent 155 moved to (11, 7)
# Agent 46 at (17, 13) is moving.
# Agent 46 moved to (17, 12)
# Agent 71 at (17, 10) is moving.
# Agent 71 moved to (18, 9)
# Agent 3 at (17, 19) is moving.
# Agent 3 moved to (18, 0)
# Agent 70 at (10, 7) is moving.
# Agent 70 moved to (9, 8)
# Agent 58 at (16, 8) is moving.
# Agent 58 moved to (16, 9)
# Agent 28 at (10, 16) is moving.
# Agent 28 moved to (9, 15)
# Agent 72 at (12, 13) is moving.
# Agent 72 moved to (13, 12)
# Agent 43 at (0, 3) is moving.
# Agent 43 moved to (0, 2)
# Agent 10 at (12, 8) is moving.
# Agent 10 moved to (13, 9)
# Agent 42 at (11, 16) is moving.
# Agent 42 moved to (11, 17)
# Agent 13 at (17, 19) is moving.
# Agent 13 moved to (16, 19)
# Agent 68 at (4, 4) is moving.
# Agent 68 moved to (4, 5)
# Agent 75 at (17, 14) is moving.
# Agent 75 moved to (18, 13)
# Agent 67 at (14, 16) is moving.
# Agent 67 moved to (15, 15)
# Agent 36 at (3, 13) is moving.
# Agent 36 moved to (4, 14)
# Agent 165 at (14, 16) is moving.
# Agent 165 moved to (13, 17)
# Agent 156 at (15, 17) is moving.
# Agent 156 moved to (15, 16)
# Sheep 156 reproduced at (16, 17)
# Agent 170 at (8, 15) is moving.
# Agent 170 moved to (7, 15)
# Agent 50 at (4, 6) is moving.
# Agent 50 moved to (3, 6)
# Agent 133 at (18, 18) is moving.
# Agent 133 moved to (19, 18)
# Agent 84 at (6, 12) is moving.
# Agent 84 moved to (7, 12)
# Agent 27 at (5, 3) is moving.
# Agent 27 moved to (6, 4)
# Agent 143 at (17, 16) is moving.
# Agent 143 moved to (16, 17)
# Agent 26 at (8, 10) is moving.
# Agent 26 moved to (9, 10)
# Agent 145 at (1, 2) is moving.
# Agent 145 moved to (2, 1)
# Agent 2 at (2, 1) is moving.
# Agent 2 moved to (3, 2)
# Agent 98 at (18, 5) is moving.
# Agent 98 moved to (17, 4)
# Agent 48 at (9, 16) is moving.
# Agent 48 moved to (8, 17)
# Agent 166 at (2, 13) is moving.
# Agent 166 moved to (2, 12)
# Agent 20 at (16, 14) is moving.
# Agent 20 moved to (15, 14)
# Agent 32 at (11, 3) is moving.
# Agent 32 moved to (11, 2)
# Agent 49 at (12, 1) is moving.
# Agent 49 moved to (11, 2)
# Agent 89 at (13, 3) is moving.
# Agent 89 moved to (12, 3)
# Agent 55 at (13, 6) is moving.
# Agent 55 moved to (13, 7)
# Agent 63 at (19, 15) is moving.
# Agent 63 moved to (18, 16)
# Agent 19 at (15, 6) is moving.
# Agent 19 moved to (15, 5)
# Agent 97 at (6, 18) is moving.
# Agent 97 moved to (6, 19)
# Agent 23 at (11, 9) is moving.
# Agent 23 moved to (10, 10)
# Agent 110 at (17, 2) is moving.
# Agent 110 moved to (18, 1)
# Agent 158 at (10, 17) is moving.
# Agent 158 moved to (11, 17)
# Wolf 158 ate Sheep 42 at (11, 17)
# Wolf 158 reproduced at (11, 16)
# Agent 127 at (18, 9) is moving.
# Agent 127 moved to (18, 10)
# Wolf 127 ate Sheep 95 at (18, 10)
# Wolf 127 reproduced at (18, 11)
# Agent 112 at (8, 0) is moving.
# Agent 112 moved to (7, 1)
# Agent 109 at (5, 4) is moving.
# Agent 109 moved to (5, 5)
# Agent 106 at (6, 1) is moving.
# Agent 106 moved to (7, 2)
# Agent 111 at (16, 3) is moving.
# Agent 111 moved to (17, 2)
# Agent 177 at (17, 0) is moving.
# Agent 177 moved to (18, 19)
# Agent 102 at (2, 12) is moving.
# Agent 102 moved to (2, 13)
# Wolf 102 ate Sheep 47 at (2, 13)
# Wolf 102 reproduced at (3, 14)
# Agent 120 at (12, 6) is moving.
# Agent 120 moved to (11, 7)
# Wolf 120 ate Sheep 155 at (11, 7)
# Wolf 120 reproduced at (12, 6)
# Agent 163 at (6, 19) is moving.
# Agent 163 moved to (5, 18)
# Wolf 163 died at (5, 18)
# Agent 113 at (9, 5) is moving.
# Agent 113 moved to (10, 5)
# Agent 148 at (18, 2) is moving.
# Agent 148 moved to (19, 3)
# Agent 123 at (5, 19) is moving.
# Agent 123 moved to (6, 18)
# Wolf 123 ate Sheep 59 at (6, 18)
# Wolf 123 reproduced at (5, 17)
# Agent 138 at (18, 3) is moving.
# Agent 138 moved to (18, 2)
# Agent 118 at (18, 3) is moving.
# Agent 118 moved to (17, 3)
# Agent 150 at (8, 8) is moving.
# Agent 150 moved to (8, 9)
# Agent 164 at (4, 7) is moving.
# Agent 164 moved to (5, 6)
# Agent 137 at (11, 4) is moving.
# Agent 137 moved to (12, 4)
# Agent 101 at (6, 1) is moving.
# Agent 101 moved to (5, 2)
# Agent 160 at (17, 15) is moving.
# Agent 160 moved to (18, 16)
# Wolf 160 ate Sheep 63 at (18, 16)
# Wolf 160 reproduced at (17, 15)
# Agent 103 at (8, 0) is moving.
# Agent 103 moved to (9, 19)
# Agent 129 at (0, 2) is moving.
# Agent 129 moved to (19, 2)
# Wolf 129 died at (19, 2)
# Agent 139 at (16, 1) is moving.
# Agent 139 moved to (17, 0)
# Wolf 139 ate Sheep 17 at (17, 0)
# Wolf 139 reproduced at (18, 19)
# Agent 174 at (13, 7) is moving.
# Agent 174 moved to (12, 6)
# Wolf 174 died at (12, 6)
# Agent 173 at (9, 8) is moving.
# Agent 173 moved to (10, 9)
# Agent 159 at (3, 12) is moving.
# Agent 159 moved to (3, 13)
# Agent 114 at (8, 2) is moving.
# Agent 114 moved to (7, 3)
# Agent 125 at (9, 5) is moving.
# Agent 125 moved to (9, 4)
# Agent 108 at (5, 0) is moving.
# Agent 108 moved to (5, 1)
# Wolf 108 ate Sheep 62 at (5, 1)
# Wolf 108 reproduced at (6, 0)
# Agent 104 at (6, 11) is moving.
# Agent 104 moved to (5, 11)
# Agent 128 at (14, 0) is moving.
# Agent 128 moved to (15, 0)
# Agent 161 at (6, 5) is moving.
# Agent 161 moved to (5, 4)
# Wolf 161 ate Sheep 178 at (5, 4)
# Wolf 161 reproduced at (5, 3)
# Agent 124 at (7, 6) is moving.
# Agent 124 moved to (6, 7)
# Agent 122 at (8, 1) is moving.
# Agent 122 moved to (7, 1)
# Agent 172 at (5, 6) is moving.
# Agent 172 moved to (5, 5)
# Agent 149 at (10, 18) is moving.
# Agent 149 moved to (10, 19)
# Agent 146 at (16, 9) is moving.
# Agent 146 moved to (16, 10)
# Wolf 146 died at (16, 10)
# Agent 140 at (0, 9) is moving.
# Agent 140 moved to (1, 10)
# Agent 117 at (16, 6) is moving.
# Agent 117 moved to (15, 5)
# Wolf 117 ate Sheep 19 at (15, 5)
# Wolf 117 reproduced at (14, 5)
# Agent 130 at (7, 2) is moving.
# Agent 130 moved to (8, 1)
# Agent 162 at (10, 9) is moving.
# Agent 162 moved to (10, 8)
# Agent 119 at (1, 7) is moving.
# Agent 119 moved to (2, 8)
# Wolf 119 ate Sheep 167 at (2, 8)
# Wolf 119 reproduced at (3, 7)
# Agent 176 at (10, 16) is moving.
# Agent 176 moved to (11, 16)
# Agent 126 at (9, 17) is moving.
# Agent 126 moved to (10, 17)
# Agent 175 at (0, 1) is moving.
# Agent 175 moved to (0, 0)
# Agent 40 at (7, 14) is moving.
# Agent 40 moved to (7, 15)
# Agent 67 at (15, 15) is moving.
# Agent 67 moved to (15, 16)
# Agent 14 at (12, 2) is moving.
# Agent 14 moved to (11, 2)
# Agent 41 at (12, 11) is moving.
# Agent 41 moved to (11, 10)
# Agent 43 at (0, 2) is moving.
# Agent 43 moved to (1, 1)
# Agent 144 at (4, 7) is moving.
# Agent 144 moved to (5, 8)
# Agent 33 at (5, 10) is moving.
# Agent 33 moved to (4, 9)
# Agent 31 at (16, 6) is moving.
# Agent 31 moved to (15, 7)
# Agent 20 at (15, 14) is moving.
# Agent 20 moved to (14, 13)
# Agent 58 at (16, 9) is moving.
# Agent 58 moved to (16, 10)
# Agent 80 at (7, 13) is moving.
# Agent 80 moved to (8, 14)
# Agent 21 at (16, 0) is moving.
# Agent 21 moved to (17, 1)
# Agent 79 at (13, 17) is moving.
# Agent 79 moved to (13, 16)
# Agent 83 at (19, 17) is moving.
# Agent 83 moved to (18, 18)
# Agent 5 at (15, 3) is moving.
# Agent 5 moved to (14, 3)
# Agent 94 at (12, 15) is moving.
# Agent 94 moved to (13, 16)
# Agent 71 at (18, 9) is moving.
# Agent 71 moved to (19, 9)
# Agent 134 at (4, 3) is moving.
# Agent 134 moved to (3, 4)
# Agent 28 at (9, 15) is moving.
# Agent 28 moved to (8, 16)
# Agent 131 at (2, 5) is moving.
# Agent 131 moved to (1, 5)
# Agent 168 at (5, 7) is moving.
# Agent 168 moved to (6, 6)
# Agent 34 at (4, 5) is moving.
# Agent 34 moved to (3, 4)
# Agent 16 at (0, 15) is moving.
# Agent 16 moved to (1, 15)
# Agent 99 at (10, 14) is moving.
# Agent 99 moved to (11, 14)
# Agent 152 at (15, 16) is moving.
# Agent 152 moved to (14, 16)
# Agent 169 at (0, 19) is moving.
# Agent 169 moved to (19, 0)
# Agent 151 at (12, 14) is moving.
# Agent 151 moved to (12, 13)
# Agent 27 at (6, 4) is moving.
# Agent 27 moved to (5, 5)
# Agent 88 at (8, 0) is moving.
# Agent 88 moved to (9, 19)
# Agent 132 at (13, 4) is moving.
# Agent 132 moved to (12, 3)
# Agent 96 at (2, 3) is moving.
# Agent 96 moved to (3, 3)
# Sheep 96 reproduced at (3, 4)
# Agent 18 at (2, 14) is moving.
# Agent 18 moved to (2, 15)
# Agent 85 at (4, 6) is moving.
# Agent 85 moved to (4, 7)
# Agent 98 at (17, 4) is moving.
# Agent 98 moved to (17, 3)
# Agent 7 at (19, 9) is moving.
# Agent 7 moved to (18, 8)
# Agent 87 at (4, 5) is moving.
# Agent 87 moved to (3, 4)
# Agent 61 at (15, 11) is moving.
# Agent 61 moved to (16, 12)
# Agent 45 at (9, 13) is moving.
# Agent 45 moved to (9, 14)
# Agent 54 at (19, 8) is moving.
# Agent 54 moved to (0, 8)
# Agent 179 at (16, 17) is moving.
# Agent 179 moved to (15, 17)
# Agent 170 at (7, 15) is moving.
# Agent 170 moved to (7, 14)
# Agent 50 at (3, 6) is moving.
# Agent 50 moved to (4, 6)
# Agent 39 at (10, 6) is moving.
# Agent 39 moved to (11, 5)
# Agent 74 at (0, 18) is moving.
# Agent 74 moved to (1, 18)
# Agent 92 at (19, 18) is moving.
# Agent 92 moved to (19, 19)
# Agent 51 at (16, 1) is moving.
# Agent 51 moved to (15, 2)
# Agent 86 at (12, 17) is moving.
# Agent 86 moved to (12, 18)
# Agent 143 at (16, 17) is moving.
# Agent 143 moved to (15, 18)
# Agent 69 at (7, 17) is moving.
# Agent 69 moved to (8, 17)
# Sheep 69 reproduced at (7, 18)
# Agent 70 at (9, 8) is moving.
# Agent 70 moved to (10, 7)
# Agent 4 at (18, 5) is moving.
# Agent 4 moved to (18, 4)
# Agent 36 at (4, 14) is moving.
# Agent 36 moved to (3, 14)
# Agent 55 at (13, 7) is moving.
# Agent 55 moved to (14, 6)
# Agent 75 at (18, 13) is moving.
# Agent 75 moved to (18, 12)
# Agent 29 at (6, 12) is moving.
# Agent 29 moved to (5, 11)
# Agent 65 at (8, 12) is moving.
# Agent 65 moved to (9, 13)
# Agent 90 at (17, 7) is moving.
# Agent 90 moved to (18, 6)
# Agent 153 at (0, 4) is moving.
# Agent 153 moved to (19, 3)
# Agent 35 at (1, 12) is moving.
# Agent 35 moved to (0, 11)
# Agent 44 at (9, 6) is moving.
# Agent 44 moved to (10, 6)
# Agent 156 at (15, 16) is moving.
# Agent 156 moved to (16, 15)
# Agent 60 at (18, 17) is moving.
# Agent 60 moved to (17, 17)
# Agent 145 at (2, 1) is moving.
# Agent 145 moved to (3, 0)
# Agent 24 at (13, 16) is moving.
# Agent 24 moved to (14, 15)
# Agent 32 at (11, 2) is moving.
# Agent 32 moved to (12, 2)
# Agent 171 at (17, 18) is moving.
# Agent 171 moved to (18, 19)
# Agent 133 at (19, 18) is moving.
# Agent 133 moved to (18, 18)
# Agent 23 at (10, 10) is moving.
# Agent 23 moved to (9, 10)
# Agent 166 at (2, 12) is moving.
# Agent 166 moved to (1, 11)
# Agent 93 at (13, 4) is moving.
# Agent 93 moved to (14, 3)
# Agent 2 at (3, 2) is moving.
# Agent 2 moved to (2, 2)
# Agent 48 at (8, 17) is moving.
# Agent 48 moved to (7, 18)
# Agent 8 at (16, 15) is moving.
# Agent 8 moved to (17, 16)
# Agent 56 at (19, 0) is moving.
# Agent 56 moved to (18, 19)
# Agent 72 at (13, 12) is moving.
# Agent 72 moved to (12, 11)
# Agent 6 at (0, 6) is moving.
# Agent 6 moved to (1, 6)
# Agent 89 at (12, 3) is moving.
# Agent 89 moved to (11, 4)
# Sheep 89 reproduced at (11, 5)
# Agent 22 at (15, 18) is moving.
# Agent 22 moved to (14, 19)
# Agent 84 at (7, 12) is moving.
# Agent 84 moved to (7, 13)
# Agent 165 at (13, 17) is moving.
# Agent 165 moved to (14, 18)
# Agent 26 at (9, 10) is moving.
# Agent 26 moved to (8, 11)
# Agent 10 at (13, 9) is moving.
# Agent 10 moved to (14, 8)
# ...
# Agent 329 moved to (12, 3)
# Agent 335 at (14, 10) is moving.
# Agent 335 moved to (13, 9)
# Agent 180 at (11, 13) is moving.
# Agent 180 moved to (10, 14)
# Agent 114 at (6, 4) is moving.
# Agent 114 moved to (7, 3)
# Agent 345 at (10, 14) is moving.
# Agent 345 moved to (9, 15)
# Agent 222 at (6, 7) is moving.
# Agent 222 moved to (5, 8)
# Agent 317 at (8, 6) is moving.
# Agent 317 moved to (7, 5)
# Agent 278 at (13, 12) is moving.
# Agent 278 moved to (14, 11)
# Agent 352 at (8, 12) is moving.
# Agent 352 moved to (8, 13)
# Agent 352 at (8, 13) is moving.
# Agent 352 moved to (7, 12)
# Agent 114 at (7, 3) is moving.
# Agent 114 moved to (7, 2)
# Agent 365 at (14, 12) is moving.
# Agent 365 moved to (15, 13)
# Agent 345 at (9, 15) is moving.
# Agent 345 moved to (8, 14)
# Agent 236 at (12, 3) is moving.
# Agent 236 moved to (11, 4)
# Agent 329 at (12, 3) is moving.
# Agent 329 moved to (13, 2)
# Agent 278 at (14, 11) is moving.
# Agent 278 moved to (15, 10)
# Agent 222 at (5, 8) is moving.
# Agent 222 moved to (4, 9)
# Agent 317 at (7, 5) is moving.
# Agent 317 moved to (6, 5)
# Wolf 317 died at (6, 5)
# Agent 351 at (6, 6) is moving.
# Agent 351 moved to (6, 7)
# Agent 337 at (15, 16) is moving.
# Agent 337 moved to (16, 17)
# Wolf 337 died at (16, 17)
# Agent 272 at (6, 9) is moving.
# Agent 272 moved to (7, 10)
# Agent 297 at (9, 15) is moving.
# Agent 297 moved to (8, 15)
# Agent 335 at (13, 9) is moving.
# Agent 335 moved to (14, 8)
# Agent 180 at (10, 14) is moving.
# Agent 180 moved to (10, 15)
# Agent 348 at (19, 5) is moving.
# Agent 348 moved to (18, 5)
# Agent 365 at (15, 13) is moving.
# Agent 365 moved to (15, 14)
# Agent 180 at (10, 15) is moving.
# Agent 180 moved to (9, 16)
# Agent 348 at (18, 5) is moving.
# Agent 348 moved to (19, 4)
# Agent 272 at (7, 10) is moving.
# Agent 272 moved to (6, 10)
# Agent 329 at (13, 2) is moving.
# Agent 329 moved to (12, 1)
# Agent 114 at (7, 2) is moving.
# Agent 114 moved to (8, 2)
# Wolf 114 died at (8, 2)
# Agent 278 at (15, 10) is moving.
# Agent 278 moved to (14, 11)
# Agent 236 at (11, 4) is moving.
# Agent 236 moved to (12, 3)
# Agent 335 at (14, 8) is moving.
# Agent 335 moved to (15, 7)
# Agent 222 at (4, 9) is moving.
# Agent 222 moved to (3, 9)
# Agent 352 at (7, 12) is moving.
# Agent 352 moved to (6, 12)
# Agent 345 at (8, 14) is moving.
# Agent 345 moved to (8, 15)
# Agent 351 at (6, 7) is moving.
# Agent 351 moved to (5, 6)
# Agent 297 at (8, 15) is moving.
# Agent 297 moved to (7, 14)
# Wolf 297 died at (7, 14)
# Agent 278 at (14, 11) is moving.
# Agent 278 moved to (13, 12)
# Agent 329 at (12, 1) is moving.
# Agent 329 moved to (11, 1)
# Agent 335 at (15, 7) is moving.
# Agent 335 moved to (16, 6)
# Agent 345 at (8, 15) is moving.
# Agent 345 moved to (9, 16)
# Wolf 345 died at (9, 16)
# Agent 351 at (5, 6) is moving.
# Agent 351 moved to (6, 7)
# Agent 180 at (9, 16) is moving.
# Agent 180 moved to (10, 16)
# Agent 236 at (12, 3) is moving.
# Agent 236 moved to (11, 4)
# Agent 272 at (6, 10) is moving.
# Agent 272 moved to (7, 10)
# Agent 348 at (19, 4) is moving.
# Agent 348 moved to (19, 3)
# Agent 222 at (3, 9) is moving.
# Agent 222 moved to (3, 8)
# Agent 352 at (6, 12) is moving.
# Agent 352 moved to (7, 12)
# Agent 365 at (15, 14) is moving.
# Agent 365 moved to (14, 14)
# Agent 278 at (13, 12) is moving.
# Agent 278 moved to (14, 11)
# Agent 222 at (3, 8) is moving.
# Agent 222 moved to (4, 8)
# Agent 272 at (7, 10) is moving.
# Agent 272 moved to (6, 9)
# Agent 365 at (14, 14) is moving.
# Agent 365 moved to (14, 13)
# Wolf 365 died at (14, 13)
# Agent 351 at (6, 7) is moving.
# Agent 351 moved to (6, 6)
# Agent 236 at (11, 4) is moving.
# Agent 236 moved to (12, 3)
# Agent 348 at (19, 3) is moving.
# Agent 348 moved to (18, 2)
# Agent 352 at (7, 12) is moving.
# Agent 352 moved to (8, 11)
# Agent 329 at (11, 1) is moving.
# Agent 329 moved to (12, 2)
# Agent 180 at (10, 16) is moving.
# Agent 180 moved to (10, 17)
# Agent 335 at (16, 6) is moving.
# Agent 335 moved to (15, 7)
# Agent 352 at (8, 11) is moving.
# Agent 352 moved to (8, 12)
# Agent 278 at (14, 11) is moving.
# Agent 278 moved to (15, 11)
# Agent 180 at (10, 17) is moving.
# Agent 180 moved to (11, 18)
# Agent 236 at (12, 3) is moving.
# Agent 236 moved to (13, 3)
# Agent 351 at (6, 6) is moving.
# Agent 351 moved to (7, 6)
# Agent 335 at (15, 7) is moving.
# Agent 335 moved to (16, 8)
# Agent 329 at (12, 2) is moving.
# Agent 329 moved to (11, 1)
# Agent 348 at (18, 2) is moving.
# Agent 348 moved to (17, 3)
# Agent 222 at (4, 8) is moving.
# Agent 222 moved to (3, 8)
# Agent 272 at (6, 9) is moving.
# Agent 272 moved to (5, 8)
# Agent 278 at (15, 11) is moving.
# Agent 278 moved to (14, 12)
# Agent 351 at (7, 6) is moving.
# Agent 351 moved to (6, 6)
# Agent 335 at (16, 8) is moving.
# Agent 335 moved to (15, 7)
# Agent 222 at (3, 8) is moving.
# Agent 222 moved to (2, 9)
# Wolf 222 died at (2, 9)
# Agent 272 at (5, 8) is moving.
# Agent 272 moved to (6, 7)
# Agent 236 at (13, 3) is moving.
# Agent 236 moved to (12, 4)
# Agent 352 at (8, 12) is moving.
# Agent 352 moved to (9, 11)
# Agent 329 at (11, 1) is moving.
# Agent 329 moved to (12, 1)
# Agent 180 at (11, 18) is moving.
# Agent 180 moved to (10, 18)
# Wolf 180 died at (10, 18)
# Agent 348 at (17, 3) is moving.
# Agent 348 moved to (17, 2)
# Agent 335 at (15, 7) is moving.
# Agent 335 moved to (16, 8)
# Agent 272 at (6, 7) is moving.
# Agent 272 moved to (7, 6)
# Agent 278 at (14, 12) is moving.
# Agent 278 moved to (14, 11)
# Agent 352 at (9, 11) is moving.
# Agent 352 moved to (10, 10)
# Agent 348 at (17, 2) is moving.
# Agent 348 moved to (18, 2)
# Agent 351 at (6, 6) is moving.
# Agent 351 moved to (5, 7)
# Agent 329 at (12, 1) is moving.
# Agent 329 moved to (11, 0)
# Agent 236 at (12, 4) is moving.
# Agent 236 moved to (13, 5)
# Agent 236 at (13, 5) is moving.
# Agent 236 moved to (14, 4)
# Agent 352 at (10, 10) is moving.
# Agent 352 moved to (10, 11)
# Agent 272 at (7, 6) is moving.
# Agent 272 moved to (8, 5)
# Agent 348 at (18, 2) is moving.
# Agent 348 moved to (18, 1)
# Wolf 348 died at (18, 1)
# Agent 335 at (16, 8) is moving.
# Agent 335 moved to (15, 9)
# Agent 278 at (14, 11) is moving.
# Agent 278 moved to (14, 10)
# Agent 351 at (5, 7) is moving.
# Agent 351 moved to (6, 8)
# Agent 329 at (11, 0) is moving.
# Agent 329 moved to (11, 19)
# Agent 351 at (6, 8) is moving.
# Agent 351 moved to (7, 9)
# Agent 329 at (11, 19) is moving.
# Agent 329 moved to (10, 18)
# Agent 272 at (8, 5) is moving.
# Agent 272 moved to (7, 6)
# Agent 335 at (15, 9) is moving.
# Agent 335 moved to (16, 10)
# Agent 236 at (14, 4) is moving.
# Agent 236 moved to (14, 5)
# Wolf 236 died at (14, 5)
# Agent 278 at (14, 10) is moving.
# Agent 278 moved to (15, 11)
# Agent 352 at (10, 11) is moving.
# Agent 352 moved to (9, 11)
# Agent 352 at (9, 11) is moving.
# Agent 352 moved to (8, 11)
# Agent 335 at (16, 10) is moving.
# Agent 335 moved to (15, 10)
# Agent 278 at (15, 11) is moving.
# Agent 278 moved to (14, 11)
# Agent 272 at (7, 6) is moving.
# Agent 272 moved to (7, 7)
# Wolf 272 died at (7, 7)
# Agent 351 at (7, 9) is moving.
# Agent 351 moved to (6, 8)
# Agent 329 at (10, 18) is moving.
# Agent 329 moved to (9, 17)
# Agent 351 at (6, 8) is moving.
# Agent 351 moved to (5, 7)
# Agent 335 at (15, 10) is moving.
# Agent 335 moved to (14, 9)
# Agent 278 at (14, 11) is moving.
# Agent 278 moved to (13, 10)
# Agent 329 at (9, 17) is moving.
# Agent 329 moved to (9, 18)
# Agent 352 at (8, 11) is moving.
# Agent 352 moved to (7, 10)
# Agent 335 at (14, 9) is moving.
# Agent 335 moved to (13, 8)
# Agent 352 at (7, 10) is moving.
# Agent 352 moved to (8, 11)
# Agent 278 at (13, 10) is moving.
# Agent 278 moved to (13, 11)
# Agent 351 at (5, 7) is moving.
# Agent 351 moved to (5, 8)
# Agent 329 at (9, 18) is moving.
# Agent 329 moved to (8, 19)
# Agent 335 at (13, 8) is moving.
# Agent 335 moved to (14, 9)
# Agent 352 at (8, 11) is moving.
# Agent 352 moved to (8, 12)
# Agent 351 at (5, 8) is moving.
# Agent 351 moved to (4, 8)
# Agent 329 at (8, 19) is moving.
# Agent 329 moved to (9, 18)
# Agent 278 at (13, 11) is moving.
# Agent 278 moved to (12, 11)
# Wolf 278 died at (12, 11)
# Agent 335 at (14, 9) is moving.
# Agent 335 moved to (15, 8)
# Agent 329 at (9, 18) is moving.
# Agent 329 moved to (10, 18)
# Agent 352 at (8, 12) is moving.
# Agent 352 moved to (7, 11)
# Agent 351 at (4, 8) is moving.
# Agent 351 moved to (4, 7)
# Wolf 351 died at (4, 7)
# Agent 352 at (7, 11) is moving.
# Agent 352 moved to (6, 12)
# Agent 335 at (15, 8) is moving.
# Agent 335 moved to (15, 9)
# Agent 329 at (10, 18) is moving.
# Agent 329 moved to (9, 18)
# Agent 335 at (15, 9) is moving.
# Agent 335 moved to (14, 9)
# Agent 329 at (9, 18) is moving.
# Agent 329 moved to (8, 18)
# Agent 352 at (6, 12) is moving.
# Agent 352 moved to (5, 13)
# Agent 352 at (5, 13) is moving.
# Agent 352 moved to (4, 14)
# Agent 329 at (8, 18) is moving.
# Agent 329 moved to (9, 17)
# Agent 335 at (14, 9) is moving.
# Agent 335 moved to (14, 10)
# Agent 335 at (14, 10) is moving.
# Agent 335 moved to (13, 9)
# Agent 352 at (4, 14) is moving.
# Agent 352 moved to (5, 13)
# Agent 329 at (9, 17) is moving.
# Agent 329 moved to (10, 16)
# Agent 329 at (10, 16) is moving.
# Agent 329 moved to (9, 17)
# Agent 352 at (5, 13) is moving.
# Agent 352 moved to (4, 14)
# Agent 335 at (13, 9) is moving.
# Agent 335 moved to (12, 10)
# Agent 335 at (12, 10) is moving.
# Agent 335 moved to (12, 11)
# Agent 352 at (4, 14) is moving.
# Agent 352 moved to (5, 13)
# Agent 329 at (9, 17) is moving.
# Agent 329 moved to (8, 18)
# Agent 335 at (12, 11) is moving.
# Agent 335 moved to (11, 12)
# Agent 329 at (8, 18) is moving.
# Agent 329 moved to (8, 17)
# Agent 352 at (5, 13) is moving.
# Agent 352 moved to (4, 13)
# Agent 335 at (11, 12) is moving.
# Agent 335 moved to (12, 13)
# Agent 329 at (8, 17) is moving.
# Agent 329 moved to (8, 16)
# Agent 352 at (4, 13) is moving.
# Agent 352 moved to (5, 14)
# Agent 352 at (5, 14) is moving.
# Agent 352 moved to (6, 15)
# Agent 329 at (8, 16) is moving.
# Agent 329 moved to (9, 17)
# Agent 335 at (12, 13) is moving.
# Agent 335 moved to (13, 13)
# Agent 329 at (9, 17) is moving.
# Agent 329 moved to (9, 18)
# Agent 335 at (13, 13) is moving.
# Agent 335 moved to (13, 14)
# Agent 352 at (6, 15) is moving.
# Agent 352 moved to (7, 14)
# Agent 352 at (7, 14) is moving.
# Agent 352 moved to (6, 13)
# Agent 329 at (9, 18) is moving.
# Agent 329 moved to (9, 19)
# Agent 335 at (13, 14) is moving.
# Agent 335 moved to (12, 15)
# Agent 329 at (9, 19) is moving.
# Agent 329 moved to (8, 0)
# Agent 335 at (12, 15) is moving.
# Agent 335 moved to (13, 16)
# Agent 352 at (6, 13) is moving.
# Agent 352 moved to (6, 14)
# Agent 335 at (13, 16) is moving.
# Agent 335 moved to (14, 15)
# Agent 352 at (6, 14) is moving.
# Agent 352 moved to (7, 13)
# Agent 329 at (8, 0) is moving.
# Agent 329 moved to (8, 1)
# Agent 335 at (14, 15) is moving.
# Agent 335 moved to (13, 15)
# Agent 352 at (7, 13) is moving.
# Agent 352 moved to (8, 14)
# Agent 329 at (8, 1) is moving.
# Agent 329 moved to (9, 0)
# Agent 335 at (13, 15) is moving.
# Agent 335 moved to (13, 16)
# Agent 352 at (8, 14) is moving.
# Agent 352 moved to (7, 13)
# Agent 329 at (9, 0) is moving.
# Agent 329 moved to (10, 0)
# Agent 329 at (10, 0) is moving.
# Agent 329 moved to (9, 19)
# Agent 352 at (7, 13) is moving.
# Agent 352 moved to (8, 12)
# Agent 335 at (13, 16) is moving.
# Agent 335 moved to (12, 15)
# Agent 335 at (12, 15) is moving.
# Agent 335 moved to (11, 16)
# Agent 329 at (9, 19) is moving.
# Agent 329 moved to (8, 19)
# Agent 352 at (8, 12) is moving.
# Agent 352 moved to (7, 11)
# Agent 329 at (8, 19) is moving.
# Agent 329 moved to (8, 18)
# Agent 352 at (7, 11) is moving.
# Agent 352 moved to (8, 10)
# Agent 335 at (11, 16) is moving.
# Agent 335 moved to (12, 16)
# Agent 352 at (8, 10) is moving.
# Agent 352 moved to (9, 11)
# Agent 329 at (8, 18) is moving.
# Agent 329 moved to (7, 19)
# Agent 335 at (12, 16) is moving.
# Agent 335 moved to (11, 15)
# Agent 329 at (7, 19) is moving.
# Agent 329 moved to (7, 0)
# Agent 335 at (11, 15) is moving.
# Agent 335 moved to (12, 15)
# Agent 352 at (9, 11) is moving.
# Agent 352 moved to (8, 11)
# Agent 352 at (8, 11) is moving.
# Agent 352 moved to (8, 12)
# Agent 329 at (7, 0) is moving.
# Agent 329 moved to (6, 0)
# Agent 335 at (12, 15) is moving.
# Agent 335 moved to (12, 16)
# Agent 352 at (8, 12) is moving.
# Agent 352 moved to (8, 11)
# Agent 329 at (6, 0) is moving.
# Agent 329 moved to (5, 19)
# Agent 335 at (12, 16) is moving.
# Agent 335 moved to (11, 15)
# Agent 329 at (5, 19) is moving.
# Agent 329 moved to (6, 18)
# Agent 335 at (11, 15) is moving.
# Agent 335 moved to (12, 16)
# Agent 352 at (8, 11) is moving.
# Agent 352 moved to (7, 11)
# Agent 352 at (7, 11) is moving.
# Agent 352 moved to (6, 11)
# Agent 329 at (6, 18) is moving.
# Agent 329 moved to (6, 19)
# Agent 335 at (12, 16) is moving.
# Agent 335 moved to (11, 17)
# Agent 335 at (11, 17) is moving.
# Agent 335 moved to (12, 17)
# Agent 352 at (6, 11) is moving.
# Agent 352 moved to (7, 11)
# Agent 329 at (6, 19) is moving.
# Agent 329 moved to (5, 0)
# Agent 335 at (12, 17) is moving.
# Agent 335 moved to (13, 18)
# Agent 352 at (7, 11) is moving.
# Agent 352 moved to (6, 12)
# Agent 329 at (5, 0) is moving.
# Agent 329 moved to (6, 19)
# Agent 329 at (6, 19) is moving.
# Agent 329 moved to (5, 18)
# Agent 335 at (13, 18) is moving.
# Agent 335 moved to (14, 18)
# Agent 352 at (6, 12) is moving.
# Agent 352 moved to (5, 13)
# Agent 352 at (5, 13) is moving.
# Agent 352 moved to (5, 14)
# Agent 329 at (5, 18) is moving.
# Agent 329 moved to (4, 17)
# Agent 335 at (14, 18) is moving.
# Agent 335 moved to (15, 17)
# Agent 335 at (15, 17) is moving.
# Agent 335 moved to (16, 17)
# Agent 329 at (4, 17) is moving.
# Agent 329 moved to (4, 18)
# Agent 352 at (5, 14) is moving.
# Agent 352 moved to (4, 14)
# Agent 329 at (4, 18) is moving.
# Agent 329 moved to (5, 17)
# Agent 335 at (16, 17) is moving.
# Agent 335 moved to (16, 16)
# Agent 352 at (4, 14) is moving.
# Agent 352 moved to (5, 13)
# Agent 329 at (5, 17) is moving.
# Agent 329 moved to (6, 16)
# Agent 335 at (16, 16) is moving.
# Agent 335 moved to (15, 17)
# Agent 352 at (5, 13) is moving.
# Agent 352 moved to (4, 14)
# Agent 329 at (6, 16) is moving.
# Agent 329 moved to (5, 15)
# Agent 335 at (15, 17) is moving.
# Agent 335 moved to (14, 16)
# Agent 352 at (4, 14) is moving.
# Agent 352 moved to (4, 13)
# Agent 335 at (14, 16) is moving.
# Agent 335 moved to (14, 15)
# Agent 329 at (5, 15) is moving.
# Agent 329 moved to (4, 16)
# Agent 352 at (4, 13) is moving.
# Agent 352 moved to (5, 12)
# Wolf 352 died at (5, 12)
# Agent 329 at (4, 16) is moving.
# Agent 329 moved to (3, 16)
# Agent 335 at (14, 15) is moving.
# Agent 335 moved to (13, 15)
# Agent 335 at (13, 15) is moving.
# Agent 335 moved to (14, 16)
# Agent 329 at (3, 16) is moving.
# Agent 329 moved to (2, 16)
# Agent 329 at (2, 16) is moving.
# Agent 329 moved to (1, 15)
# Agent 335 at (14, 16) is moving.
# Agent 335 moved to (13, 16)
# Agent 329 at (1, 15) is moving.
# Agent 329 moved to (2, 16)
# Agent 335 at (13, 16) is moving.
# Agent 335 moved to (14, 17)
# Agent 335 at (14, 17) is moving.
# Agent 335 moved to (15, 16)
# Agent 329 at (2, 16) is moving.
# Agent 329 moved to (1, 17)
# Agent 329 at (1, 17) is moving.
# Agent 329 moved to (0, 16)
# Agent 335 at (15, 16) is moving.
# Agent 335 moved to (15, 15)
# Wolf 335 died at (15, 15)
# Agent 329 at (0, 16) is moving.
# Agent 329 moved to (19, 16)
# Agent 329 at (19, 16) is moving.
# Agent 329 moved to (18, 15)
# Agent 329 at (18, 15) is moving.
# Agent 329 moved to (19, 15)
# Agent 329 at (19, 15) is moving.
# Agent 329 moved to (19, 14)
# Agent 329 at (19, 14) is moving.
# Agent 329 moved to (0, 15)
# Agent 329 at (0, 15) is moving.
# Agent 329 moved to (19, 14)
# Agent 329 at (19, 14) is moving.
# Agent 329 moved to (19, 15)
# Agent 329 at (19, 15) is moving.
# Agent 329 moved to (19, 16)
# Agent 329 at (19, 16) is moving.
# Agent 329 moved to (19, 17)
# Agent 329 at (19, 17) is moving.
# Agent 329 moved to (18, 18)
# Agent 329 at (18, 18) is moving.
# Agent 329 moved to (17, 17)
# Agent 329 at (17, 17) is moving.
# Agent 329 moved to (18, 17)
# Agent 329 at (18, 17) is moving.
# Agent 329 moved to (18, 18)
# Agent 329 at (18, 18) is moving.
# Agent 329 moved to (17, 19)
# Agent 329 at (17, 19) is moving.
# Agent 329 moved to (16, 19)
# Agent 329 at (16, 19) is moving.
# Agent 329 moved to (16, 0)
# Agent 329 at (16, 0) is moving.
# Agent 329 moved to (16, 19)
# Agent 329 at (16, 19) is moving.
# Agent 329 moved to (16, 0)
# Agent 329 at (16, 0) is moving.
# Agent 329 moved to (16, 19)
# Agent 329 at (16, 19) is moving.
# Agent 329 moved to (17, 0)
# Agent 329 at (17, 0) is moving.
# Agent 329 moved to (18, 0)
# Agent 329 at (18, 0) is moving.
# Agent 329 moved to (19, 19)
# Wolf 329 died at (19, 19)
# <Axes: >

# %% [markdown]
# See if you can make a similar plot which displays the average number of sheep a wolf has eaten over its lifetime for each `step()` in the model. You will need to change the `step()` method of the wolf so that it counts every sheep it has eaten, and you will need to change the `DataCollector` to log this data. You can then use `model.datacollector.get_agent_vars_dataframe()` to get your data.
#
# Take a look at the [Mesa Read The Docs](https://mesa.readthedocs.io/en/latest/tutorials/intro_tutorial.html#collecting-data) for more details.

# %% [markdown]
# ### Visualisation
# Mesa provides you with an interactive visualisation toolkit. This is done through a local server that uses JavaScript to draw  everything in a browser window. An advantage of this is that we can run models step by step, spotting patterns, behaviors, bugs, developing new intuitions, hypotheses or insights. It is also a very good way to explain a model to your roommates or grandparents.
#
# We have provided you with a seperate `server.py` that shows you how you could visualise this model, as the visualisation will not cooperate with notebooks. Feel free to take a look and change elements to get accustomed to how the visualisation module works. For more information, visit [this link](https://mesa.readthedocs.io/en/latest/tutorials/visualization_tutorial.html#building-your-own-visualization-component).
#
# Run this model by issuing the following command in the command line (in your 1-mesa folder):
#
# `> ipython server.py`
#
# NOTE: Keep in mind that the "Frames Per Second" setting does not take into account the time it takes to build a frame. This means that when your simulation takes more time to build a frame than it takes the visualisation to display it, and you press stop, the visualisation will continue untill it has displayed all the frames that it should have displayed in the first place. To prevent this from happening, do not set "Frames Per Second" too high.

# %% [markdown]
# ### Mesa best practices
# To ensure that our models are easily accessible and maintainable, Mesa provides us with some general principles. These principles can be found [here](https://mesa.readthedocs.io/en/latest/best-practices.html), but the main take-away is that you should structure your files. The model class for example, should be located in `model.py` and generally, the agents should be located in `agent.py`.

# %%
# !python server.py
# Out:
# Traceback (most recent call last):
#   File "d:\code-repo\abm\ABM_Assignments\ABM-Notebooks-0-1\1-mesa\server.py", line 10, in <module>
#     from model import WolfSheep, Wolf
# ImportError: cannot import name 'WolfSheep' from 'model' (d:\code-repo\abm\ABM_Assignments\ABM-Notebooks-0-1\1-mesa\model.py)
